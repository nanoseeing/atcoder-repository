# %%
from contextlib import contextmanager
import time

@contextmanager
def timer(name):
    t0 = time.time()
    yield
    print(f"[{name}] done in {(time.time() - t0) * 1000:.1f} msec")

# %%
from collections import deque
import bisect
from pathlib import Path
import numpy as np
import z3
from itertools import product

# %%
def calc_mu_sigma(k, e, vs):
    mu = (k-vs)*e + vs*(1-e)
    sigma = k*e*(1-e)
    return mu, sigma

def is_out_of_range(y, x, N):
    return not ((0 <= x < N) and (0 <= y < N))

def get_div_arr(n):
    d =  (n-1) // 4 + 1
    r = 4 * d - n
    ret = [4] * (d-r)
    ret += [3] * r
    sum_ret = [0]
    for i in range(len(ret)):
        sum_ret.append(sum_ret[i] + ret[i])
    return sum_ret

def print_grid_from_coordinates(coordinates):
    x_list = []
    y_list = []
    for coordinate in coordinates:
        y, x = coordinate
        x_list.append(x)
        y_list.append(y)
    x_max = max(x_list)
    y_max = max(y_list)
    disp_grid = [["." for _ in range(x_max+1)] for _ in range(y_max+1)]
    for coordinate in coordinates:
        ty, tx = coordinate
        disp_grid[ty][tx] = "#"
    for line in disp_grid:
        print("".join(line))

def print_grid_from_map(g):
    for l in g:
        print(" ".join(map(str, l)))

# %%
class Env:

    def __init__(self, file_path):
        with open(file_path, mode="r") as f:
            lines = f.readlines()
            N, M, ESP = lines[0].split()
            N, M, ESP = int(N), int(M), float(ESP)
            GRID = []
            lines = lines[1:]
            for _line in lines[:M]:
                _line = _line.split()
                ps = []
                for i in range(int(_line[0])):
                    ps.append((int(_line[2 * i + 1]), int(_line[2 * i + 2])))
                GRID.append(ps)
            lines = lines[2*M:]
            ANS_GRID = []
            for _line in lines[:N]:
                ANS_GRID.append(list(map(int, _line.split())))
        
        self.N = N
        self.M = M
        self.esp = ESP
        self.grids = GRID
        self.ans_grid = ANS_GRID

        self.total_size = sum(len(g) for g in self.grids)
        self._score = 0
        self.score = 10 ** 9

        cnt = 0
        for x in range(N):
            for y in range(N):
                if self.ans_grid[y][x] > 0:
                    cnt += 1
        self.ans_point_size = cnt
    
    def query1(self, coordinate):
        y, x = coordinate
        self._score += 1
        return self.ans_grid[y][x]

    def query2(self, coordinates):
        k = len(coordinates)
        vs = sum(self.ans_grid[y][x] for y, x in coordinates)
        mu, sigma = calc_mu_sigma(k, self.esp, vs)
        rng = np.random.default_rng()
        r = rng.normal(mu, sigma)
        self._score += 1 / np.sqrt(k)
        return max(0, round(r))

    def answer(self, coordinates):
        is_ok = self.total_size == sum(self.ans_grid[y][x] for y, x in coordinates)
        if is_ok:
            self.score = self._score
        else:
            self._score += 1
        return is_ok

# %%
class BFSSolver:
    """
        幅優先探索で貪欲的に確定する
        RESULT: 127.69
    """

    def __init__(self, N, total_oil_num):
        self.N = N
        self.grid_count = [[-1 for _ in range(N)] for _ in range(N)]
        self.grid_response = [[False for _ in range(N)] for _ in range(N)]
        self.grid_distance = [[0 for _ in range(N)] for _ in range(N)]
        for x in range(N):
            for y in range(N):
                self.grid_distance[y][x] = min(x + 1, y + 1, N - x, N - y)

        self.total_count = 0
        self.total_oil_nums = total_oil_num

        self.next_grids = set()

    def is_ok(self):
        return self.total_count == self.total_oil_nums

    def get_plus_grids(self):
        ret = []
        for x in range(self.N):
            for y in range(self.N):
                if self.grid_count[y][x] == -1:
                    continue
                if self.grid_count[y][x] > 0:
                    ret.append((y, x))
        return ret

    def response(self, y, x, val):
        self.grid_count[y][x] = val
        self.grid_response[y][x] = True
        if val > 0:
            self.total_count += val
            for dy, dx in [[0, 1], [1, 0], [0, -1], [-1, 0]]:
                ny, nx = y + dy, x + dx
                if not (0 <= nx < self.N and 0 <= ny < self.N):
                    continue
                if not self.grid_response[ny][nx]:
                    self.next_grids.add((ny, nx))
        self._update_distance(y, x)

    def get_next_search_point(self):
        if self.next_grids:
            return self.next_grids.pop()
        else:
            return self._get_far_point_from_wall()

    def _update_distance(self, y, x):
        searched = [[False for _ in range(self.N)] for _ in range(self.N)]
        self.grid_distance[y][x] = 0
        start = [(y, x)]
        search_q = deque(start)
        while search_q:
            py, px = search_q.popleft()
            searched[py][px] = True
            if searched[py][px]:
                continue
            for dy, dx in [[0, 1], [1, 0], [0, -1], [-1, 0]]:
                ny, nx = py + dy, px + dx
                if not (0 <= nx < self.N and 0 <= ny < self.N):
                    continue
                if self.grid_distance[ny][nx] == 0 or searched[ny][nx]:
                    continue
                search_q.append((ny, nx))
                self.grid_distance[ny][nx] = min(
                    self.grid_distance[ny][nx], self.grid_distance[py][px] + 1
                )

    def _get_far_point_from_wall(self):
        max_val = max(max(l for l in self.grid_distance))
        for x in range(self.N):
            for y in range(self.N):
                if self.grid_response[y][x]:
                    continue
                if self.grid_distance[y][x] == max_val:
                    return y, x

# %%
import threading

import ctypes
import time

# カスタムスレッドクラス
class twe(threading.Thread):
    def __init__(self, group=None, target=None, name=None, args=(), kwargs={}):
        threading.Thread.__init__(self, group=group, target=target, name=name)
        self.args = args
        self.kwargs = kwargs
        return
    
    def run(self):
        self._target(*self.args, **self.kwargs)

    def get_id(self):
        if hasattr(self, '_thread_id'):
            return self._thread_id
        for id, thread in threading._active.items():
            if thread is self:
                return id
    
    # 強制終了させる関数
    def raise_exception(self):
        thread_id = self.get_id()
        resu = ctypes.pythonapi.PyThreadState_SetAsyncExc(ctypes.c_long(thread_id), ctypes.py_object(SystemExit))
        if resu > 1:
            ctypes.pythonapi.PyThreadState_SetAsyncExc(ctypes.c_long(thread_id), 0)
            print('Failure in raising exception')

# %%
class SMTSolver():

    def __init__(self, env:Env):
        placements_grid_set = {}
        for m in range(env.M):
            now_grid_set = [[set() for _ in range(env.N)] for _ in range(env.N)]
            target_grids = env.grids[m]
            for x in range(env.N):
                for y in range(env.N):
                    tmp_grids = []
                    is_ok = True
                    for coordinate in target_grids:
                        ny, nx = coordinate[0] + y, coordinate[1] + x
                        if is_out_of_range(ny, nx, env.N):
                            is_ok = False
                            break
                        tmp_grids.append((ny, nx))
                    if not is_ok:
                        continue
                    for coordinate in tmp_grids:
                        ty, tx = coordinate
                        now_grid_set[ty][tx].add((y, x))
            placements_grid_set[m] = now_grid_set
        
        self.placements_grid_set = placements_grid_set

        var_x = {}
        total_grid = {}

        for m, y, x in product(list(range(env.M)), list(range(env.N)), list(range(env.N))):
            var_x[m, y, x] = z3.Bool(f"var_x{m, y, x}")
        for y, x in product(list(range(env.N)), list(range(env.N))):
            total_grid[y, x] = z3.Int(f"total_grid{y, x}")
        
        self.var_x = var_x
        self.total_grid = total_grid

        self.env = env

    def solve(self, querys):
        z3_solver = z3.Solver()
        env = self.env

        # 配列外参照になる場合はダメ
        for m, y, x in product(list(range(env.M)), list(range(env.N)), list(range(env.N))):
            target_grids = env.grids[m]
            for coordinate in target_grids:
                ny, nx = coordinate[0] + y, coordinate[1] + x
                if is_out_of_range(ny, nx, env.N):
                    z3_solver.add(self.var_x[m,y,x]==False)

        # 配置はどれか1つを選択しなければならない
        for m in range(env.M):
            now_vars = []
            for y, x in product(list(range(env.N)), list(range(env.N))):
                ind = y*env.N + x
                self.var_x[m, y, x] = z3.Bool(f"var_x{m, y, x}")
                now_vars.append(self.var_x[m, y, x])
            z3_solver.add(z3.Sum(now_vars) == 1)

        # 配置した箇所に対応するグリッドが加算される
        for y, x in product(list(range(env.N)), list(range(env.N))):
            bool_vars = []
            for m in range(env.M):
                for ty, tx in self.placements_grid_set[m][y][x]:
                    bool_vars.append(self.var_x[m ,ty, tx])
            z3_solver.add(self.total_grid[y, x] == z3.Sum(bool_vars))
        
        # 制約を満たす
        for query in querys:
            coordinate, resp = query
            y, x = coordinate
            z3_solver.add(self.total_grid[y, x] == resp)
        
        # 解を求める
        z3_solver.set('timeout', 350)
        with timer("solve"):
            if not z3_solver.check() == z3.sat:
                return None
            model = z3_solver.model()

        placement_ans = []
        for m, y, x in product(list(range(env.M)), list(range(env.N)), list(range(env.N))):
            if model.eval(self.var_x[m, y, x]):
                placement_ans.append((m, y, x))

        point_ans = set()
        for m, y, x in placement_ans:
            target_grids = env.grids[m]
            for coordinate in target_grids:
                ny, nx = coordinate[0] + y, coordinate[1] + x
                point_ans.add((ny, nx))
        

        return point_ans

# %%
def judge_run_smt(env):
    return True
    th = [(10, 6), (11, 5), (12, 4), (13, 4), (14, 3), (15, 2)]
    return any(env.N <= n and env.M <= m for n, m in th)

# %%
smt_solved_result = []

def solve(env: Env):
    TIME_OUT = 15

    smt_level = [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.60, 0.75, 1.0]
    start_time = time.time()
    bsf_solver = BFSSolver(env.N, total_oil_num=env.total_size)
    querys = []
    for i in range(1, 1000):

        # --- BFS Solver --- #
        y, x = bsf_solver.get_next_search_point()
        resp = env.query1((y, x))
        bsf_solver.response(y, x, resp)
        querys.append(((y, x), resp))
        if bsf_solver.is_ok():
            env.answer(bsf_solver.get_plus_grids())
            # print("GRID OK")
            break

        # --- SMT Solver --- #
        if not judge_run_smt(env):
            continue
        if time.time() - start_time > TIME_OUT:
            # 実行時間3秒以内に収めるため
            continue
        if i >= env.N**2 * smt_level[0]:
            smt_solver = SMTSolver(env)
            point_ans = smt_solver.solve(querys)
            if point_ans is None:
                continue
            if env.answer(point_ans):
                smt_solved_result.append((env.N, env.M, smt_level[0], env.score, env.ans_point_size))
                print("SOLVER OK!!!!")
                break
            smt_level.pop(0)

# %%
import random

scores = []
n_size = []
ans_points = []

def main():
    random.seed(0)
    for test_num in range(1000):
        env = Env(file_path = Path(f"./in/{test_num:0>4}.txt"))
        n_size.append(env.N**2)
        ans_points.append(env.ans_point_size)
        solve(env)
        scores.append(env.score)
main()
# Out:
# [solve] done in 357.0 msec
# [solve] done in 351.5 msec
# [solve] done in 356.0 msec
# [solve] done in 327.1 msec
# [solve] done in 355.7 msec
# [solve] done in 356.4 msec
# [solve] done in 355.7 msec
# [solve] done in 357.0 msec
# [solve] done in 357.0 msec
# [solve] done in 355.7 msec
# [solve] done in 356.2 msec
# [solve] done in 355.9 msec
# [solve] done in 356.9 msec
# [solve] done in 357.0 msec
# [solve] done in 356.6 msec
# [solve] done in 357.0 msec
# [solve] done in 355.3 msec
# [solve] done in 355.0 msec
# [solve] done in 361.0 msec
# [solve] done in 358.6 msec
# [solve] done in 356.9 msec
# [solve] done in 356.9 msec
# [solve] done in 356.0 msec
# [solve] done in 356.2 msec
# [solve] done in 356.2 msec
# [solve] done in 356.1 msec
# [solve] done in 357.2 msec
# [solve] done in 355.0 msec
# [solve] done in 356.1 msec
# [solve] done in 356.7 msec
# [solve] done in 358.0 msec
# [solve] done in 357.9 msec
# [solve] done in 98.1 msec
# SOLVER OK!!!!
# [solve] done in 104.3 msec
# [solve] done in 126.2 msec
# [solve] done in 134.1 msec
# [solve] done in 129.6 msec
# [solve] done in 144.2 msec
# [solve] done in 156.0 msec
# [solve] done in 178.1 msec
# [solve] done in 173.4 msec
# [solve] done in 126.1 msec
# SOLVER OK!!!!
# [solve] done in 167.2 msec
# [solve] done in 217.8 msec
# [solve] done in 191.4 msec
# [solve] done in 307.3 msec
# [solve] done in 355.0 msec
# [solve] done in 354.3 msec
# [solve] done in 355.0 msec
# [solve] done in 353.8 msec
# [solve] done in 355.3 msec
# [solve] done in 355.1 msec
# [solve] done in 353.8 msec
# [solve] done in 354.3 msec
# [solve] done in 353.8 msec
# [solve] done in 357.9 msec
# [solve] done in 355.2 msec
# [solve] done in 355.7 msec
# [solve] done in 354.7 msec
# [solve] done in 356.1 msec
# [solve] done in 354.9 msec
# [solve] done in 357.0 msec
# [solve] done in 360.1 msec
# [solve] done in 354.3 msec
# [solve] done in 355.0 msec
# [solve] done in 357.6 msec
# [solve] done in 355.4 msec
# [solve] done in 359.4 msec
# [solve] done in 354.8 msec
# [solve] done in 354.5 msec
# [solve] done in 356.5 msec
# [solve] done in 365.0 msec
# [solve] done in 356.4 msec
# [solve] done in 122.1 msec
# [solve] done in 142.7 msec
# [solve] done in 141.0 msec
# [solve] done in 158.1 msec
# [solve] done in 139.0 msec
# [solve] done in 157.5 msec
# [solve] done in 175.1 msec
# [solve] done in 195.1 msec
# [solve] done in 191.4 msec
# [solve] done in 162.0 msec
# [solve] done in 212.2 msec
# [solve] done in 259.7 msec
# [solve] done in 120.6 msec
# [solve] done in 120.9 msec
# [solve] done in 146.9 msec
# [solve] done in 160.6 msec
# [solve] done in 179.9 msec
# [solve] done in 184.9 msec
# [solve] done in 220.6 msec
# [solve] done in 209.0 msec
# [solve] done in 221.0 msec
# [solve] done in 211.7 msec
# [solve] done in 273.7 msec
# [solve] done in 263.7 msec
# SOLVER OK!!!!
# [solve] done in 356.0 msec
# [solve] done in 355.9 msec
# [solve] done in 356.8 msec
# [solve] done in 355.8 msec
# [solve] done in 354.8 msec
# [solve] done in 357.7 msec
# [solve] done in 356.1 msec
# [solve] done in 356.3 msec
# [solve] done in 356.0 msec
# [solve] done in 355.7 msec
# [solve] done in 354.8 msec
# [solve] done in 355.6 msec
# [solve] done in 355.9 msec
# [solve] done in 355.3 msec
# [solve] done in 354.3 msec
# [solve] done in 355.6 msec
# [solve] done in 354.9 msec
# [solve] done in 356.3 msec
# [solve] done in 356.4 msec
# [solve] done in 355.9 msec
# [solve] done in 355.4 msec
# [solve] done in 356.5 msec
# [solve] done in 357.3 msec
# [solve] done in 356.2 msec
# [solve] done in 356.9 msec
# [solve] done in 355.1 msec
# [solve] done in 356.7 msec
# [solve] done in 355.9 msec
# [solve] done in 356.9 msec
# [solve] done in 355.9 msec
# [solve] done in 356.0 msec
# [solve] done in 354.8 msec
# [solve] done in 355.3 msec
# [solve] done in 355.9 msec
# [solve] done in 357.7 msec
# [solve] done in 167.2 msec
# [solve] done in 183.2 msec
# [solve] done in 206.8 msec
# [solve] done in 234.3 msec
# [solve] done in 290.0 msec
# [solve] done in 175.0 msec
# [solve] done in 192.9 msec
# [solve] done in 229.3 msec
# [solve] done in 181.9 msec
# [solve] done in 227.0 msec
# [solve] done in 268.7 msec
# SOLVER OK!!!!
# [solve] done in 282.3 msec
# [solve] done in 353.2 msec
# [solve] done in 354.8 msec
# [solve] done in 354.4 msec
# [solve] done in 355.1 msec
# [solve] done in 354.8 msec
# [solve] done in 354.2 msec
# [solve] done in 356.6 msec
# [solve] done in 353.6 msec
# [solve] done in 355.8 msec
# [solve] done in 354.5 msec
# [solve] done in 354.2 msec
# [solve] done in 355.6 msec
# [solve] done in 356.2 msec
# [solve] done in 354.9 msec
# [solve] done in 355.5 msec
# [solve] done in 353.1 msec
# [solve] done in 355.0 msec
# [solve] done in 355.2 msec
# [solve] done in 354.4 msec
# [solve] done in 356.2 msec
# [solve] done in 356.1 msec
# [solve] done in 354.6 msec
# [solve] done in 356.3 msec
# [solve] done in 355.0 msec
# [solve] done in 356.2 msec
# [solve] done in 353.2 msec
# [solve] done in 223.2 msec
# [solve] done in 275.1 msec
# [solve] done in 278.6 msec
# [solve] done in 343.6 msec
# [solve] done in 354.8 msec
# [solve] done in 289.2 msec
# [solve] done in 295.6 msec
# [solve] done in 357.1 msec
# [solve] done in 355.2 msec
# [solve] done in 323.1 msec
# [solve] done in 354.8 msec
# [solve] done in 291.1 msec
# [solve] done in 358.0 msec
# [solve] done in 354.8 msec
# [solve] done in 354.9 msec
# [solve] done in 356.1 msec
# [solve] done in 357.6 msec
# [solve] done in 355.9 msec
# [solve] done in 356.9 msec
# [solve] done in 356.0 msec
# [solve] done in 354.8 msec
# [solve] done in 354.8 msec
# [solve] done in 355.6 msec
# [solve] done in 355.9 msec
# [solve] done in 355.0 msec
# [solve] done in 355.9 msec
# [solve] done in 355.2 msec
# [solve] done in 356.0 msec
# [solve] done in 355.4 msec
# [solve] done in 357.0 msec
# [solve] done in 354.9 msec
# [solve] done in 356.8 msec
# [solve] done in 356.4 msec
# [solve] done in 356.5 msec
# [solve] done in 70.2 msec
# SOLVER OK!!!!
# [solve] done in 356.1 msec
# [solve] done in 356.1 msec
# [solve] done in 356.1 msec
# [solve] done in 360.1 msec
# [solve] done in 358.2 msec
# [solve] done in 358.1 msec
# [solve] done in 359.3 msec
# [solve] done in 363.1 msec
# [solve] done in 357.8 msec
# [solve] done in 356.3 msec
# [solve] done in 356.2 msec
# [solve] done in 356.7 msec
# [solve] done in 356.8 msec
# [solve] done in 356.4 msec
# [solve] done in 356.2 msec
# [solve] done in 354.2 msec
# [solve] done in 356.4 msec
# [solve] done in 356.5 msec
# [solve] done in 356.4 msec
# [solve] done in 356.1 msec
# [solve] done in 355.9 msec
# [solve] done in 354.4 msec
# [solve] done in 356.5 msec
# [solve] done in 355.1 msec
# [solve] done in 355.9 msec
# [solve] done in 358.0 msec
# [solve] done in 355.9 msec
# [solve] done in 354.6 msec
# [solve] done in 358.2 msec
# [solve] done in 355.6 msec
# [solve] done in 355.9 msec
# [solve] done in 354.8 msec
# [solve] done in 355.8 msec
# [solve] done in 356.4 msec
# [solve] done in 355.9 msec
# [solve] done in 354.4 msec
# [solve] done in 356.5 msec
# [solve] done in 355.2 msec
# [solve] done in 356.3 msec
# [solve] done in 354.9 msec
# [solve] done in 354.7 msec
# [solve] done in 356.2 msec
# [solve] done in 354.7 msec
# [solve] done in 356.1 msec
# [solve] done in 355.9 msec
# [solve] done in 357.3 msec
# [solve] done in 260.4 msec
# [solve] done in 354.2 msec
# [solve] done in 354.5 msec
# [solve] done in 355.8 msec
# [solve] done in 355.7 msec
# [solve] done in 356.6 msec
# [solve] done in 354.7 msec
# [solve] done in 356.5 msec
# [solve] done in 354.5 msec
# [solve] done in 356.3 msec
# [solve] done in 354.3 msec
# [solve] done in 355.0 msec
# [solve] done in 354.9 msec
# [solve] done in 354.2 msec
# [solve] done in 355.1 msec
# [solve] done in 358.6 msec
# [solve] done in 355.3 msec
# [solve] done in 354.8 msec
# [solve] done in 354.3 msec
# [solve] done in 355.2 msec
# [solve] done in 355.9 msec
# [solve] done in 354.8 msec
# [solve] done in 356.8 msec
# [solve] done in 355.1 msec
# [solve] done in 357.9 msec
# [solve] done in 355.7 msec
# [solve] done in 357.3 msec
# [solve] done in 354.7 msec
# [solve] done in 354.8 msec
# [solve] done in 354.8 msec
# [solve] done in 355.9 msec
# [solve] done in 354.7 msec
# [solve] done in 355.9 msec
# [solve] done in 356.0 msec
# [solve] done in 355.9 msec
# [solve] done in 356.9 msec
# [solve] done in 354.6 msec
# [solve] done in 354.9 msec
# [solve] done in 357.0 msec
# [solve] done in 354.9 msec
# [solve] done in 356.5 msec
# [solve] done in 356.4 msec
# [solve] done in 354.7 msec
# [solve] done in 356.4 msec
# [solve] done in 356.9 msec
# [solve] done in 356.1 msec
# [solve] done in 356.1 msec
# [solve] done in 354.9 msec
# [solve] done in 355.8 msec
# [solve] done in 355.4 msec
# [solve] done in 356.9 msec
# [solve] done in 356.2 msec
# [solve] done in 354.6 msec
# [solve] done in 356.3 msec
# [solve] done in 357.2 msec
# [solve] done in 355.8 msec
# [solve] done in 356.0 msec
# [solve] done in 358.3 msec
# [solve] done in 354.6 msec
# [solve] done in 354.7 msec
# [solve] done in 354.8 msec
# [solve] done in 356.0 msec
# [solve] done in 354.2 msec
# [solve] done in 355.0 msec
# [solve] done in 357.0 msec
# [solve] done in 355.8 msec
# [solve] done in 355.3 msec
# [solve] done in 362.5 msec
# [solve] done in 357.1 msec
# [solve] done in 355.8 msec
# [solve] done in 356.1 msec
# [solve] done in 356.3 msec
# [solve] done in 356.0 msec
# [solve] done in 355.7 msec
# [solve] done in 357.8 msec
# [solve] done in 355.5 msec
# [solve] done in 356.8 msec
# [solve] done in 357.8 msec
# [solve] done in 358.1 msec
# [solve] done in 355.2 msec
# [solve] done in 356.9 msec
# [solve] done in 356.0 msec
# [solve] done in 356.0 msec
# [solve] done in 355.8 msec
# [solve] done in 356.9 msec
# [solve] done in 355.1 msec
# [solve] done in 355.8 msec
# [solve] done in 354.9 msec
# [solve] done in 353.7 msec
# [solve] done in 354.7 msec
# [solve] done in 354.9 msec
# [solve] done in 354.4 msec
# [solve] done in 356.0 msec
# [solve] done in 354.8 msec
# [solve] done in 356.1 msec
# [solve] done in 356.2 msec
# [solve] done in 355.9 msec
# [solve] done in 356.0 msec
# [solve] done in 356.5 msec
# [solve] done in 354.9 msec
# [solve] done in 354.5 msec
# [solve] done in 355.0 msec
# [solve] done in 50.0 msec
# SOLVER OK!!!!
# [solve] done in 355.2 msec
# [solve] done in 357.5 msec
# [solve] done in 354.3 msec
# [solve] done in 357.4 msec
# [solve] done in 361.9 msec
# [solve] done in 355.9 msec
# [solve] done in 354.9 msec
# [solve] done in 357.0 msec
# [solve] done in 354.6 msec
# [solve] done in 355.8 msec
# [solve] done in 355.2 msec
# [solve] done in 356.1 msec
# [solve] done in 354.7 msec
# [solve] done in 355.5 msec
# [solve] done in 42.3 msec
# [solve] done in 54.0 msec
# SOLVER OK!!!!
# [solve] done in 65.0 msec
# [solve] done in 71.5 msec
# [solve] done in 67.7 msec
# [solve] done in 59.0 msec
# [solve] done in 68.1 msec
# [solve] done in 75.8 msec
# [solve] done in 79.2 msec
# [solve] done in 78.4 msec
# [solve] done in 88.0 msec
# [solve] done in 91.2 msec
# [solve] done in 127.1 msec
# [solve] done in 332.7 msec
# SOLVER OK!!!!
# [solve] done in 152.4 msec
# [solve] done in 290.1 msec
# [solve] done in 354.5 msec
# [solve] done in 353.5 msec
# [solve] done in 360.6 msec
# [solve] done in 356.9 msec
# [solve] done in 358.2 msec
# [solve] done in 356.2 msec
# [solve] done in 358.5 msec
# [solve] done in 354.9 msec
# [solve] done in 357.7 msec
# [solve] done in 358.8 msec
# [solve] done in 355.9 msec
# [solve] done in 355.8 msec
# [solve] done in 356.3 msec
# [solve] done in 355.4 msec
# [solve] done in 354.4 msec
# [solve] done in 356.3 msec
# [solve] done in 355.9 msec
# [solve] done in 355.4 msec
# [solve] done in 360.0 msec
# [solve] done in 353.9 msec
# [solve] done in 356.9 msec
# [solve] done in 360.7 msec
# [solve] done in 361.0 msec
# [solve] done in 357.2 msec
# [solve] done in 358.1 msec
# [solve] done in 358.8 msec
# [solve] done in 356.4 msec
# [solve] done in 357.7 msec
# [solve] done in 356.7 msec
# [solve] done in 357.5 msec
# [solve] done in 357.6 msec
# [solve] done in 356.8 msec
# [solve] done in 359.1 msec
# [solve] done in 356.9 msec
# [solve] done in 357.3 msec
# [solve] done in 372.3 msec
# [solve] done in 358.4 msec
# [solve] done in 367.4 msec
# [solve] done in 358.4 msec
# [solve] done in 365.1 msec
# [solve] done in 357.9 msec
# [solve] done in 359.6 msec
# [solve] done in 355.8 msec
# [solve] done in 365.9 msec
# [solve] done in 358.3 msec
# [solve] done in 358.8 msec
# [solve] done in 360.6 msec
# [solve] done in 357.9 msec
# [solve] done in 358.1 msec
# [solve] done in 369.2 msec
# [solve] done in 357.8 msec
# [solve] done in 358.3 msec
# [solve] done in 359.9 msec
# [solve] done in 355.7 msec
# [solve] done in 354.8 msec
# [solve] done in 356.7 msec
# [solve] done in 357.3 msec
# [solve] done in 357.5 msec
# [solve] done in 358.6 msec
# [solve] done in 356.6 msec
# [solve] done in 357.1 msec
# [solve] done in 355.9 msec
# [solve] done in 356.9 msec
# [solve] done in 355.7 msec
# [solve] done in 356.5 msec
# [solve] done in 356.9 msec
# [solve] done in 355.2 msec
# [solve] done in 357.8 msec
# [solve] done in 357.0 msec
# [solve] done in 354.8 msec
# [solve] done in 356.3 msec
# [solve] done in 355.2 msec
# [solve] done in 354.6 msec
# [solve] done in 356.2 msec
# [solve] done in 356.4 msec
# [solve] done in 354.8 msec
# [solve] done in 357.0 msec
# [solve] done in 355.6 msec
# [solve] done in 355.2 msec
# [solve] done in 353.9 msec
# [solve] done in 356.0 msec
# [solve] done in 354.3 msec
# [solve] done in 355.9 msec
# [solve] done in 357.1 msec
# [solve] done in 356.1 msec
# [solve] done in 357.0 msec
# [solve] done in 355.0 msec
# [solve] done in 355.3 msec
# [solve] done in 354.7 msec
# [solve] done in 358.1 msec
# [solve] done in 358.3 msec
# [solve] done in 356.5 msec
# [solve] done in 359.2 msec
# [solve] done in 357.3 msec
# [solve] done in 357.8 msec
# [solve] done in 358.1 msec
# [solve] done in 356.7 msec
# [solve] done in 357.8 msec
# [solve] done in 358.9 msec
# [solve] done in 365.8 msec
# [solve] done in 357.2 msec
# [solve] done in 356.7 msec
# [solve] done in 357.1 msec
# [solve] done in 358.9 msec
# [solve] done in 363.2 msec
# [solve] done in 178.2 msec
# [solve] done in 244.1 msec
# [solve] done in 296.1 msec
# [solve] done in 356.0 msec
# [solve] done in 355.0 msec
# [solve] done in 358.1 msec
# [solve] done in 351.9 msec
# [solve] done in 353.6 msec
# [solve] done in 355.9 msec
# [solve] done in 354.3 msec
# [solve] done in 354.1 msec
# [solve] done in 355.9 msec
# [solve] done in 353.3 msec
# [solve] done in 355.9 msec
# [solve] done in 354.8 msec
# [solve] done in 354.3 msec
# [solve] done in 355.7 msec
# [solve] done in 355.9 msec
# [solve] done in 356.0 msec
# [solve] done in 355.7 msec
# [solve] done in 354.0 msec
# [solve] done in 354.9 msec
# [solve] done in 358.0 msec
# [solve] done in 356.1 msec
# [solve] done in 354.2 msec
# [solve] done in 355.1 msec
# [solve] done in 354.7 msec
# [solve] done in 355.1 msec
# [solve] done in 356.3 msec
# [solve] done in 354.6 msec
# [solve] done in 354.6 msec
# [solve] done in 356.0 msec
# [solve] done in 355.3 msec
# [solve] done in 44.7 msec
# [solve] done in 60.0 msec
# [solve] done in 53.7 msec
# [solve] done in 76.3 msec
# [solve] done in 57.8 msec
# [solve] done in 68.9 msec
# [solve] done in 76.6 msec
# [solve] done in 35.0 msec
# [solve] done in 28.0 msec
# [solve] done in 41.1 msec
# [solve] done in 35.9 msec
# [solve] done in 44.1 msec
# SOLVER OK!!!!
# [solve] done in 226.0 msec
# [solve] done in 281.7 msec
# [solve] done in 356.1 msec
# [solve] done in 354.9 msec
# [solve] done in 354.3 msec
# [solve] done in 353.4 msec
# [solve] done in 353.9 msec
# [solve] done in 354.9 msec
# [solve] done in 354.3 msec
# [solve] done in 353.9 msec
# [solve] done in 356.0 msec
# [solve] done in 353.7 msec
# [solve] done in 356.1 msec
# [solve] done in 353.4 msec
# [solve] done in 355.2 msec
# [solve] done in 355.5 msec
# [solve] done in 354.1 msec
# [solve] done in 355.5 msec
# [solve] done in 354.6 msec
# [solve] done in 356.4 msec
# [solve] done in 354.7 msec
# [solve] done in 359.7 msec
# [solve] done in 356.1 msec
# [solve] done in 357.3 msec
# [solve] done in 357.3 msec
# [solve] done in 355.3 msec
# [solve] done in 79.1 msec
# [solve] done in 131.0 msec
# [solve] done in 121.6 msec
# [solve] done in 151.9 msec
# SOLVER OK!!!!
# [solve] done in 355.7 msec
# [solve] done in 357.4 msec
# [solve] done in 359.8 msec
# [solve] done in 356.9 msec
# [solve] done in 357.9 msec
# [solve] done in 358.0 msec
# [solve] done in 362.9 msec
# [solve] done in 356.8 msec
# [solve] done in 358.2 msec
# [solve] done in 357.0 msec
# [solve] done in 356.4 msec
# [solve] done in 358.4 msec
# [solve] done in 355.2 msec
# [solve] done in 357.1 msec
# [solve] done in 357.2 msec
# [solve] done in 356.1 msec
# [solve] done in 355.7 msec
# [solve] done in 354.7 msec
# [solve] done in 355.9 msec
# [solve] done in 357.9 msec
# [solve] done in 354.2 msec
# [solve] done in 355.2 msec
# [solve] done in 355.9 msec
# [solve] done in 354.9 msec
# [solve] done in 357.2 msec
# [solve] done in 355.9 msec
# [solve] done in 354.9 msec
# [solve] done in 356.9 msec
# [solve] done in 354.5 msec
# [solve] done in 357.0 msec
# [solve] done in 354.7 msec
# [solve] done in 355.3 msec
# [solve] done in 358.1 msec
# [solve] done in 356.0 msec
# [solve] done in 356.0 msec
# [solve] done in 356.0 msec
# [solve] done in 355.5 msec
# [solve] done in 129.2 msec
# SOLVER OK!!!!
# [solve] done in 24.1 msec
# [solve] done in 31.9 msec
# [solve] done in 33.5 msec
# [solve] done in 41.1 msec
# [solve] done in 53.2 msec
# [solve] done in 71.9 msec
# [solve] done in 134.5 msec
# [solve] done in 159.4 msec
# SOLVER OK!!!!
# [solve] done in 357.6 msec
# [solve] done in 355.3 msec
# [solve] done in 356.1 msec
# [solve] done in 355.7 msec
# [solve] done in 355.8 msec
# [solve] done in 355.4 msec
# [solve] done in 355.0 msec
# [solve] done in 354.7 msec
# [solve] done in 355.1 msec
# [solve] done in 356.0 msec
# [solve] done in 355.5 msec
# [solve] done in 356.0 msec
# [solve] done in 354.0 msec
# [solve] done in 356.5 msec
# [solve] done in 354.8 msec
# [solve] done in 355.8 msec
# [solve] done in 354.2 msec
# [solve] done in 356.9 msec
# [solve] done in 354.6 msec
# [solve] done in 354.5 msec
# [solve] done in 354.9 msec
# [solve] done in 356.5 msec
# [solve] done in 357.2 msec
# [solve] done in 355.0 msec
# [solve] done in 355.2 msec
# [solve] done in 356.2 msec
# [solve] done in 354.3 msec
# [solve] done in 355.9 msec
# [solve] done in 356.0 msec
# [solve] done in 356.1 msec
# [solve] done in 356.5 msec
# [solve] done in 208.0 msec
# [solve] done in 289.3 msec
# [solve] done in 293.7 msec
# [solve] done in 355.1 msec
# [solve] done in 321.0 msec
# [solve] done in 354.2 msec
# [solve] done in 355.0 msec
# [solve] done in 354.3 msec
# [solve] done in 355.1 msec
# [solve] done in 355.2 msec
# [solve] done in 354.7 msec
# [solve] done in 352.8 msec
# [solve] done in 355.9 msec
# [solve] done in 331.1 msec
# SOLVER OK!!!!
# [solve] done in 24.1 msec
# [solve] done in 28.0 msec
# [solve] done in 27.5 msec
# SOLVER OK!!!!
# [solve] done in 14.2 msec
# [solve] done in 19.1 msec
# SOLVER OK!!!!
# [solve] done in 368.9 msec
# [solve] done in 359.9 msec
# [solve] done in 358.0 msec
# [solve] done in 358.2 msec
# [solve] done in 364.8 msec
# [solve] done in 373.9 msec
# [solve] done in 359.2 msec
# [solve] done in 359.1 msec
# [solve] done in 359.0 msec
# [solve] done in 357.9 msec
# [solve] done in 361.2 msec
# [solve] done in 361.3 msec
# [solve] done in 361.9 msec
# [solve] done in 360.2 msec
# [solve] done in 360.2 msec
# [solve] done in 362.7 msec
# [solve] done in 371.2 msec
# [solve] done in 171.7 msec
# [solve] done in 180.8 msec
# [solve] done in 262.0 msec
# [solve] done in 234.9 msec
# [solve] done in 189.0 msec
# [solve] done in 268.7 msec
# [solve] done in 231.1 msec
# [solve] done in 289.1 msec
# [solve] done in 355.9 msec
# [solve] done in 329.0 msec
# [solve] done in 355.2 msec
# [solve] done in 350.4 msec
# [solve] done in 300.0 msec
# SOLVER OK!!!!
# [solve] done in 58.9 msec
# [solve] done in 70.6 msec
# [solve] done in 80.7 msec
# [solve] done in 87.2 msec
# [solve] done in 76.7 msec
# [solve] done in 88.7 msec
# SOLVER OK!!!!
# [solve] done in 364.7 msec
# [solve] done in 358.1 msec
# [solve] done in 358.8 msec
# [solve] done in 358.4 msec
# [solve] done in 357.1 msec
# [solve] done in 360.1 msec
# [solve] done in 372.0 msec
# [solve] done in 373.5 msec
# [solve] done in 357.0 msec
# [solve] done in 356.9 msec
# [solve] done in 413.8 msec
# [solve] done in 359.0 msec
# [solve] done in 463.7 msec
# [solve] done in 357.3 msec
# [solve] done in 365.8 msec
# [solve] done in 370.8 msec
# [solve] done in 354.9 msec
# [solve] done in 358.1 msec
# [solve] done in 358.2 msec
# [solve] done in 357.2 msec
# [solve] done in 356.7 msec
# [solve] done in 358.4 msec
# [solve] done in 357.9 msec
# [solve] done in 356.3 msec
# [solve] done in 357.3 msec
# [solve] done in 355.3 msec
# [solve] done in 356.5 msec
# [solve] done in 355.1 msec
# [solve] done in 360.2 msec
# [solve] done in 355.4 msec
# [solve] done in 357.9 msec
# [solve] done in 359.4 msec
# [solve] done in 356.9 msec
# [solve] done in 357.3 msec
# [solve] done in 363.0 msec
# [solve] done in 358.2 msec
# [solve] done in 358.1 msec
# [solve] done in 357.0 msec
# [solve] done in 355.6 msec
# [solve] done in 357.0 msec
# [solve] done in 357.9 msec
# [solve] done in 356.9 msec
# [solve] done in 355.3 msec
# [solve] done in 354.9 msec
# [solve] done in 357.2 msec
# [solve] done in 356.1 msec
# [solve] done in 356.8 msec
# [solve] done in 355.6 msec
# [solve] done in 358.4 msec
# [solve] done in 361.8 msec
# [solve] done in 359.5 msec
# [solve] done in 355.6 msec
# [solve] done in 357.9 msec
# [solve] done in 358.2 msec
# [solve] done in 356.1 msec
# [solve] done in 353.8 msec
# [solve] done in 353.7 msec
# [solve] done in 353.1 msec
# [solve] done in 354.6 msec
# [solve] done in 354.8 msec
# [solve] done in 355.0 msec
# [solve] done in 356.3 msec
# [solve] done in 355.7 msec
# [solve] done in 354.8 msec
# [solve] done in 355.7 msec
# [solve] done in 355.0 msec
# [solve] done in 355.2 msec
# [solve] done in 354.4 msec
# [solve] done in 354.9 msec
# [solve] done in 356.1 msec
# [solve] done in 39.2 msec
# [solve] done in 49.2 msec
# SOLVER OK!!!!
# [solve] done in 97.0 msec
# [solve] done in 141.3 msec
# SOLVER OK!!!!
# [solve] done in 35.9 msec
# [solve] done in 88.8 msec
# SOLVER OK!!!!
# [solve] done in 355.0 msec
# [solve] done in 355.7 msec
# [solve] done in 357.9 msec
# [solve] done in 356.8 msec
# [solve] done in 356.9 msec
# [solve] done in 357.0 msec
# [solve] done in 355.6 msec
# [solve] done in 358.6 msec
# [solve] done in 356.1 msec
# [solve] done in 356.9 msec
# [solve] done in 357.0 msec
# [solve] done in 356.1 msec
# [solve] done in 357.0 msec
# [solve] done in 357.0 msec
# [solve] done in 357.0 msec
# [solve] done in 156.9 msec
# [solve] done in 167.9 msec
# [solve] done in 175.0 msec
# [solve] done in 204.9 msec
# [solve] done in 176.8 msec
# [solve] done in 186.7 msec
# [solve] done in 206.8 msec
# [solve] done in 177.2 msec
# [solve] done in 223.0 msec
# [solve] done in 221.2 msec
# [solve] done in 222.1 msec
# [solve] done in 336.2 msec
# [solve] done in 358.9 msec
# [solve] done in 359.0 msec
# [solve] done in 359.9 msec
# [solve] done in 356.3 msec
# [solve] done in 359.8 msec
# [solve] done in 359.0 msec
# [solve] done in 356.1 msec
# [solve] done in 357.9 msec
# [solve] done in 356.1 msec
# [solve] done in 359.0 msec
# [solve] done in 357.9 msec
# [solve] done in 357.0 msec
# [solve] done in 359.0 msec
# [solve] done in 356.1 msec
# [solve] done in 356.0 msec
# [solve] done in 357.4 msec
# [solve] done in 375.6 msec
# [solve] done in 360.2 msec
# [solve] done in 360.3 msec
# [solve] done in 360.7 msec
# [solve] done in 364.9 msec
# [solve] done in 358.7 msec
# [solve] done in 360.3 msec
# [solve] done in 364.1 msec
# [solve] done in 363.0 msec
# [solve] done in 358.8 msec
# [solve] done in 360.9 msec
# [solve] done in 354.8 msec
# [solve] done in 355.8 msec
# [solve] done in 355.5 msec
# [solve] done in 355.4 msec
# [solve] done in 356.6 msec
# [solve] done in 356.1 msec
# [solve] done in 359.2 msec
# [solve] done in 354.8 msec
# [solve] done in 355.8 msec
# [solve] done in 357.5 msec
# [solve] done in 355.7 msec
# [solve] done in 355.1 msec
# [solve] done in 356.7 msec
# [solve] done in 355.1 msec
# [solve] done in 355.3 msec
# [solve] done in 355.8 msec
# [solve] done in 358.2 msec
# [solve] done in 358.1 msec
# [solve] done in 356.2 msec
# [solve] done in 356.1 msec
# [solve] done in 355.8 msec
# [solve] done in 360.0 msec
# [solve] done in 355.6 msec
# [solve] done in 358.5 msec
# [solve] done in 358.0 msec
# [solve] done in 358.1 msec
# [solve] done in 356.4 msec
# [solve] done in 359.1 msec
# [solve] done in 356.4 msec
# [solve] done in 355.3 msec
# [solve] done in 355.7 msec
# [solve] done in 357.9 msec
# [solve] done in 358.2 msec
# [solve] done in 362.5 msec
# [solve] done in 362.1 msec
# [solve] done in 357.9 msec
# [solve] done in 361.9 msec
# [solve] done in 359.3 msec
# [solve] done in 377.0 msec
# [solve] done in 360.9 msec
# [solve] done in 363.1 msec
# [solve] done in 363.9 msec
# [solve] done in 359.5 msec
# [solve] done in 361.9 msec
# [solve] done in 225.0 msec
# [solve] done in 321.8 msec
# [solve] done in 337.4 msec
# [solve] done in 356.1 msec
# [solve] done in 356.7 msec
# [solve] done in 354.3 msec
# [solve] done in 353.9 msec
# [solve] done in 355.2 msec
# [solve] done in 354.1 msec
# [solve] done in 355.5 msec
# [solve] done in 358.7 msec
# [solve] done in 354.6 msec
# [solve] done in 354.8 msec
# [solve] done in 354.7 msec
# [solve] done in 355.9 msec
# [solve] done in 353.9 msec
# [solve] done in 355.0 msec
# [solve] done in 355.5 msec
# [solve] done in 356.4 msec
# [solve] done in 355.0 msec
# [solve] done in 355.3 msec
# [solve] done in 355.9 msec
# [solve] done in 353.8 msec
# [solve] done in 355.2 msec
# [solve] done in 354.1 msec
# [solve] done in 355.1 msec
# [solve] done in 355.7 msec
# [solve] done in 354.3 msec
# [solve] done in 354.7 msec
# [solve] done in 356.1 msec
# [solve] done in 356.1 msec
# [solve] done in 354.1 msec
# [solve] done in 355.2 msec
# [solve] done in 355.2 msec
# [solve] done in 354.2 msec
# [solve] done in 356.4 msec
# [solve] done in 356.0 msec
# [solve] done in 150.7 msec
# [solve] done in 284.1 msec
# [solve] done in 190.3 msec
# [solve] done in 190.9 msec
# [solve] done in 201.1 msec
# [solve] done in 351.9 msec
# [solve] done in 251.3 msec
# [solve] done in 355.4 msec
# [solve] done in 355.1 msec
# [solve] done in 308.5 msec
# [solve] done in 315.4 msec
# [solve] done in 354.8 msec
# [solve] done in 327.8 msec
# [solve] done in 355.6 msec
# [solve] done in 358.0 msec
# [solve] done in 354.4 msec
# [solve] done in 356.9 msec
# [solve] done in 355.1 msec
# [solve] done in 355.6 msec
# [solve] done in 355.8 msec
# [solve] done in 358.4 msec
# [solve] done in 354.2 msec
# [solve] done in 356.1 msec
# [solve] done in 355.7 msec
# [solve] done in 357.0 msec
# [solve] done in 356.0 msec
# [solve] done in 356.3 msec
# [solve] done in 71.2 msec
# [solve] done in 109.0 msec
# [solve] done in 280.8 msec
# SOLVER OK!!!!
# [solve] done in 355.9 msec
# [solve] done in 353.8 msec
# [solve] done in 354.9 msec
# [solve] done in 355.0 msec
# [solve] done in 353.9 msec
# [solve] done in 353.8 msec
# [solve] done in 354.9 msec
# [solve] done in 356.1 msec
# [solve] done in 353.6 msec
# [solve] done in 353.4 msec
# [solve] done in 354.5 msec
# [solve] done in 353.5 msec
# [solve] done in 356.0 msec
# [solve] done in 355.5 msec
# [solve] done in 353.7 msec
# [solve] done in 356.0 msec
# [solve] done in 355.0 msec
# [solve] done in 353.6 msec
# [solve] done in 354.9 msec
# [solve] done in 354.7 msec
# [solve] done in 51.0 msec
# [solve] done in 65.6 msec
# [solve] done in 72.1 msec
# [solve] done in 67.6 msec
# [solve] done in 54.1 msec
# [solve] done in 104.9 msec
# SOLVER OK!!!!
# [solve] done in 29.9 msec
# [solve] done in 28.9 msec
# [solve] done in 37.2 msec
# [solve] done in 36.7 msec
# [solve] done in 25.0 msec
# [solve] done in 28.9 msec
# [solve] done in 36.3 msec
# [solve] done in 22.5 msec
# [solve] done in 24.1 msec
# [solve] done in 31.8 msec
# [solve] done in 60.4 msec
# [solve] done in 104.2 msec
# SOLVER OK!!!!
# [solve] done in 62.8 msec
# [solve] done in 354.5 msec
# [solve] done in 168.9 msec
# SOLVER OK!!!!
# [solve] done in 357.2 msec
# [solve] done in 357.7 msec
# [solve] done in 356.8 msec
# [solve] done in 357.1 msec
# [solve] done in 357.7 msec
# [solve] done in 361.3 msec
# [solve] done in 358.8 msec
# [solve] done in 359.4 msec
# [solve] done in 363.1 msec
# [solve] done in 357.9 msec
# [solve] done in 357.1 msec
# [solve] done in 358.3 msec
# [solve] done in 360.2 msec
# [solve] done in 357.9 msec
# [solve] done in 358.9 msec
# [solve] done in 356.9 msec
# [solve] done in 357.0 msec
# [solve] done in 357.3 msec
# [solve] done in 356.9 msec
# [solve] done in 356.1 msec
# [solve] done in 355.7 msec
# [solve] done in 355.7 msec
# [solve] done in 357.1 msec
# [solve] done in 357.9 msec
# [solve] done in 359.1 msec
# [solve] done in 357.3 msec
# [solve] done in 356.1 msec
# [solve] done in 355.9 msec
# [solve] done in 356.9 msec
# [solve] done in 357.1 msec
# [solve] done in 355.0 msec
# [solve] done in 355.9 msec
# [solve] done in 355.9 msec
# [solve] done in 357.1 msec
# [solve] done in 357.2 msec
# [solve] done in 360.0 msec
# [solve] done in 354.7 msec
# [solve] done in 355.3 msec
# [solve] done in 358.7 msec
# [solve] done in 354.6 msec
# [solve] done in 356.9 msec
# [solve] done in 355.7 msec
# [solve] done in 359.8 msec
# [solve] done in 361.1 msec
# [solve] done in 363.9 msec
# [solve] done in 360.0 msec
# [solve] done in 359.7 msec
# [solve] done in 357.5 msec
# [solve] done in 364.2 msec
# [solve] done in 362.3 msec
# [solve] done in 358.2 msec
# [solve] done in 363.8 msec
# [solve] done in 358.7 msec
# [solve] done in 360.2 msec
# [solve] done in 360.9 msec
# [solve] done in 358.0 msec
# [solve] done in 359.8 msec
# [solve] done in 356.4 msec
# [solve] done in 358.1 msec
# [solve] done in 362.2 msec
# [solve] done in 357.8 msec
# [solve] done in 357.4 msec
# [solve] done in 357.4 msec
# [solve] done in 359.8 msec
# [solve] done in 356.5 msec
# [solve] done in 355.6 msec
# [solve] done in 356.7 msec
# [solve] done in 357.8 msec
# [solve] done in 355.1 msec
# [solve] done in 357.0 msec
# [solve] done in 357.0 msec
# [solve] done in 358.2 msec
# [solve] done in 356.8 msec
# [solve] done in 356.9 msec
# [solve] done in 357.7 msec
# [solve] done in 356.7 msec
# [solve] done in 357.2 msec
# [solve] done in 357.6 msec
# [solve] done in 357.4 msec
# [solve] done in 357.0 msec
# [solve] done in 357.1 msec
# [solve] done in 359.0 msec
# [solve] done in 354.8 msec
# [solve] done in 356.0 msec
# [solve] done in 357.1 msec
# [solve] done in 359.3 msec
# [solve] done in 356.3 msec
# [solve] done in 356.2 msec
# [solve] done in 355.8 msec
# [solve] done in 357.9 msec
# [solve] done in 355.5 msec
# [solve] done in 355.0 msec
# [solve] done in 355.0 msec
# [solve] done in 355.9 msec
# [solve] done in 357.2 msec
# [solve] done in 357.0 msec
# [solve] done in 357.5 msec
# [solve] done in 355.4 msec
# [solve] done in 354.7 msec
# [solve] done in 356.0 msec
# [solve] done in 356.9 msec
# [solve] done in 355.7 msec
# [solve] done in 358.0 msec
# [solve] done in 356.8 msec
# [solve] done in 356.7 msec
# [solve] done in 357.2 msec
# [solve] done in 356.1 msec
# [solve] done in 356.9 msec
# [solve] done in 355.6 msec
# [solve] done in 357.0 msec
# [solve] done in 357.1 msec
# [solve] done in 355.8 msec
# [solve] done in 353.6 msec
# [solve] done in 355.7 msec
# [solve] done in 354.8 msec
# [solve] done in 357.3 msec
# [solve] done in 355.5 msec
# [solve] done in 356.9 msec
# [solve] done in 358.6 msec
# [solve] done in 357.3 msec
# [solve] done in 357.9 msec
# [solve] done in 358.1 msec
# [solve] done in 354.1 msec
# [solve] done in 355.8 msec
# [solve] done in 357.1 msec
# [solve] done in 356.9 msec
# [solve] done in 356.6 msec
# [solve] done in 357.5 msec
# [solve] done in 127.8 msec
# [solve] done in 118.3 msec
# [solve] done in 195.8 msec
# [solve] done in 196.1 msec
# [solve] done in 167.8 msec
# [solve] done in 186.8 msec
# [solve] done in 182.0 msec
# [solve] done in 193.9 msec
# [solve] done in 272.7 msec
# [solve] done in 251.9 msec
# [solve] done in 255.6 msec
# [solve] done in 325.9 msec
# SOLVER OK!!!!
# [solve] done in 184.0 msec
# [solve] done in 301.2 msec
# SOLVER OK!!!!
# [solve] done in 355.5 msec
# [solve] done in 356.2 msec
# [solve] done in 354.8 msec
# [solve] done in 354.8 msec
# [solve] done in 336.8 msec
# [solve] done in 355.9 msec
# [solve] done in 355.2 msec
# [solve] done in 355.1 msec
# [solve] done in 355.1 msec
# [solve] done in 356.0 msec
# [solve] done in 355.9 msec
# [solve] done in 356.0 msec
# [solve] done in 354.6 msec
# [solve] done in 355.8 msec
# [solve] done in 355.4 msec
# [solve] done in 355.9 msec
# [solve] done in 355.0 msec
# [solve] done in 356.1 msec
# [solve] done in 354.3 msec
# [solve] done in 355.0 msec
# [solve] done in 355.4 msec
# [solve] done in 354.4 msec
# [solve] done in 354.5 msec
# [solve] done in 355.5 msec
# [solve] done in 353.7 msec
# [solve] done in 358.2 msec
# [solve] done in 354.2 msec
# [solve] done in 357.1 msec
# [solve] done in 354.6 msec
# [solve] done in 267.2 msec
# [solve] done in 354.4 msec
# [solve] done in 354.5 msec
# [solve] done in 355.2 msec
# [solve] done in 353.2 msec
# [solve] done in 355.0 msec
# [solve] done in 353.7 msec
# [solve] done in 355.5 msec
# [solve] done in 356.1 msec
# [solve] done in 353.7 msec
# [solve] done in 354.5 msec
# [solve] done in 354.8 msec
# [solve] done in 356.1 msec
# [solve] done in 355.1 msec
# [solve] done in 355.4 msec
# [solve] done in 354.8 msec
# [solve] done in 354.2 msec
# [solve] done in 357.5 msec
# [solve] done in 355.2 msec
# [solve] done in 353.5 msec
# [solve] done in 362.0 msec
# [solve] done in 354.0 msec
# [solve] done in 355.8 msec
# [solve] done in 358.3 msec
# [solve] done in 359.5 msec
# [solve] done in 356.6 msec
# [solve] done in 356.7 msec
# [solve] done in 358.6 msec
# [solve] done in 361.1 msec
# [solve] done in 359.0 msec
# [solve] done in 359.0 msec
# [solve] done in 359.9 msec
# [solve] done in 357.4 msec
# [solve] done in 356.9 msec
# [solve] done in 358.6 msec
# [solve] done in 356.8 msec
# [solve] done in 357.7 msec
# [solve] done in 357.2 msec
# [solve] done in 357.3 msec
# [solve] done in 359.1 msec
# [solve] done in 356.3 msec
# [solve] done in 360.2 msec
# [solve] done in 358.9 msec
# [solve] done in 357.2 msec
# [solve] done in 50.5 msec
# [solve] done in 89.8 msec
# [solve] done in 76.7 msec
# SOLVER OK!!!!
# [solve] done in 355.1 msec
# [solve] done in 356.2 msec
# [solve] done in 355.5 msec
# [solve] done in 355.2 msec
# [solve] done in 356.1 msec
# [solve] done in 355.3 msec
# [solve] done in 354.5 msec
# [solve] done in 355.1 msec
# [solve] done in 356.6 msec
# [solve] done in 356.0 msec
# [solve] done in 356.0 msec
# [solve] done in 355.4 msec
# [solve] done in 356.7 msec
# [solve] done in 354.9 msec
# [solve] done in 356.0 msec
# [solve] done in 354.8 msec
# [solve] done in 355.9 msec
# [solve] done in 355.2 msec
# [solve] done in 354.2 msec
# [solve] done in 354.8 msec
# [solve] done in 356.0 msec
# [solve] done in 356.0 msec
# [solve] done in 356.4 msec
# [solve] done in 355.7 msec
# [solve] done in 354.9 msec
# [solve] done in 358.8 msec
# [solve] done in 358.2 msec
# [solve] done in 359.2 msec
# [solve] done in 674.8 msec
# [solve] done in 359.9 msec
# [solve] done in 392.8 msec
# [solve] done in 359.4 msec
# [solve] done in 363.8 msec
# [solve] done in 360.2 msec
# [solve] done in 358.0 msec
# [solve] done in 365.5 msec
# [solve] done in 357.0 msec
# [solve] done in 358.0 msec
# [solve] done in 359.4 msec
# [solve] done in 367.8 msec
# [solve] done in 283.8 msec
# [solve] done in 345.5 msec
# [solve] done in 354.8 msec
# [solve] done in 354.8 msec
# [solve] done in 355.1 msec
# [solve] done in 357.8 msec
# [solve] done in 356.3 msec
# [solve] done in 354.8 msec
# [solve] done in 353.9 msec
# [solve] done in 353.8 msec
# [solve] done in 355.9 msec
# [solve] done in 353.8 msec
# [solve] done in 355.1 msec
# [solve] done in 356.7 msec
# [solve] done in 356.8 msec
# [solve] done in 354.1 msec
# [solve] done in 355.2 msec
# [solve] done in 354.2 msec
# [solve] done in 358.1 msec
# [solve] done in 356.1 msec
# [solve] done in 353.9 msec
# [solve] done in 358.9 msec
# [solve] done in 355.9 msec
# [solve] done in 138.9 msec
# [solve] done in 214.1 msec
# [solve] done in 252.6 msec
# [solve] done in 293.3 msec
# [solve] done in 350.9 msec
# SOLVER OK!!!!
# [solve] done in 355.9 msec
# [solve] done in 356.3 msec
# [solve] done in 357.9 msec
# [solve] done in 358.1 msec
# [solve] done in 358.0 msec
# [solve] done in 355.5 msec
# [solve] done in 356.9 msec
# [solve] done in 355.9 msec
# [solve] done in 357.4 msec
# [solve] done in 355.1 msec
# [solve] done in 355.2 msec
# [solve] done in 356.8 msec
# [solve] done in 355.3 msec
# [solve] done in 293.0 msec
# [solve] done in 277.2 msec
# [solve] done in 284.9 msec
# [solve] done in 317.4 msec
# [solve] done in 285.7 msec
# [solve] done in 334.7 msec
# [solve] done in 354.9 msec
# [solve] done in 343.6 msec
# [solve] done in 336.3 msec
# [solve] done in 355.8 msec
# [solve] done in 354.7 msec
# [solve] done in 355.9 msec
# [solve] done in 288.9 msec
# [solve] done in 356.1 msec
# [solve] done in 356.0 msec
# [solve] done in 354.8 msec
# [solve] done in 354.9 msec
# [solve] done in 356.0 msec
# [solve] done in 356.0 msec
# [solve] done in 356.2 msec
# [solve] done in 354.8 msec
# [solve] done in 356.3 msec
# [solve] done in 330.4 msec
# [solve] done in 356.2 msec
# [solve] done in 344.0 msec
# [solve] done in 354.2 msec
# [solve] done in 357.2 msec
# [solve] done in 355.4 msec
# [solve] done in 101.8 msec
# [solve] done in 161.4 msec
# [solve] done in 299.9 msec
# SOLVER OK!!!!
# [solve] done in 355.9 msec
# [solve] done in 355.0 msec
# [solve] done in 356.2 msec
# [solve] done in 355.7 msec
# [solve] done in 355.6 msec
# [solve] done in 355.0 msec
# [solve] done in 355.0 msec
# [solve] done in 354.8 msec
# [solve] done in 354.2 msec
# [solve] done in 355.2 msec
# [solve] done in 356.0 msec
# [solve] done in 357.6 msec
# [solve] done in 355.3 msec
# [solve] done in 356.2 msec
# [solve] done in 356.6 msec
# [solve] done in 359.2 msec
# [solve] done in 354.7 msec
# [solve] done in 354.7 msec
# [solve] done in 355.1 msec
# [solve] done in 355.9 msec
# [solve] done in 355.5 msec
# [solve] done in 358.2 msec
# [solve] done in 357.6 msec
# [solve] done in 355.9 msec
# [solve] done in 354.6 msec
# [solve] done in 353.6 msec
# [solve] done in 353.0 msec
# [solve] done in 354.3 msec
# [solve] done in 354.4 msec
# [solve] done in 355.0 msec
# [solve] done in 354.1 msec
# [solve] done in 354.4 msec
# [solve] done in 355.8 msec
# [solve] done in 355.5 msec
# [solve] done in 357.1 msec
# [solve] done in 355.7 msec
# [solve] done in 356.9 msec
# [solve] done in 355.5 msec
# [solve] done in 357.3 msec
# [solve] done in 357.7 msec
# [solve] done in 356.1 msec
# [solve] done in 358.1 msec
# [solve] done in 355.2 msec
# [solve] done in 355.0 msec
# [solve] done in 354.7 msec
# [solve] done in 355.7 msec
# [solve] done in 356.2 msec
# [solve] done in 355.9 msec
# [solve] done in 354.6 msec
# [solve] done in 223.4 msec
# [solve] done in 356.7 msec
# [solve] done in 355.9 msec
# [solve] done in 355.4 msec
# [solve] done in 356.0 msec
# [solve] done in 350.2 msec
# [solve] done in 356.2 msec
# [solve] done in 354.8 msec
# [solve] done in 355.3 msec
# [solve] done in 357.1 msec
# [solve] done in 346.0 msec
# [solve] done in 354.8 msec
# [solve] done in 356.8 msec
# [solve] done in 354.9 msec
# [solve] done in 343.1 msec
# [solve] done in 356.4 msec
# [solve] done in 354.4 msec
# [solve] done in 355.7 msec
# [solve] done in 354.8 msec
# [solve] done in 355.5 msec
# [solve] done in 355.1 msec
# [solve] done in 357.0 msec
# [solve] done in 354.8 msec
# [solve] done in 356.0 msec
# [solve] done in 354.9 msec
# [solve] done in 358.5 msec
# [solve] done in 354.4 msec
# [solve] done in 111.0 msec
# [solve] done in 203.3 msec
# [solve] done in 355.1 msec
# [solve] done in 355.9 msec
# [solve] done in 354.6 msec
# [solve] done in 354.0 msec
# [solve] done in 356.0 msec
# [solve] done in 353.8 msec
# [solve] done in 354.5 msec
# [solve] done in 355.9 msec
# [solve] done in 356.3 msec
# [solve] done in 353.1 msec
# [solve] done in 355.0 msec
# [solve] done in 355.4 msec
# [solve] done in 356.4 msec
# [solve] done in 357.2 msec
# [solve] done in 355.9 msec
# [solve] done in 354.6 msec
# [solve] done in 355.9 msec
# [solve] done in 358.1 msec
# [solve] done in 354.4 msec
# [solve] done in 353.8 msec
# [solve] done in 357.1 msec
# [solve] done in 357.2 msec
# [solve] done in 357.2 msec
# [solve] done in 357.1 msec
# [solve] done in 356.2 msec
# [solve] done in 284.5 msec
# [solve] done in 355.0 msec
# [solve] done in 354.9 msec
# [solve] done in 353.6 msec
# [solve] done in 355.5 msec
# [solve] done in 353.4 msec
# [solve] done in 356.0 msec
# [solve] done in 354.7 msec
# [solve] done in 354.7 msec
# [solve] done in 354.0 msec
# [solve] done in 355.8 msec
# [solve] done in 354.6 msec
# [solve] done in 356.4 msec
# [solve] done in 356.1 msec
# [solve] done in 356.2 msec
# [solve] done in 356.4 msec
# [solve] done in 354.7 msec
# [solve] done in 353.7 msec
# [solve] done in 354.4 msec
# [solve] done in 354.9 msec
# [solve] done in 355.9 msec
# [solve] done in 355.0 msec
# [solve] done in 354.9 msec
# [solve] done in 354.4 msec
# [solve] done in 356.2 msec
# [solve] done in 356.2 msec
# [solve] done in 356.1 msec
# [solve] done in 357.2 msec
# [solve] done in 360.3 msec
# [solve] done in 358.1 msec
# [solve] done in 355.8 msec
# [solve] done in 357.9 msec
# [solve] done in 356.6 msec
# [solve] done in 358.9 msec
# [solve] done in 358.6 msec
# [solve] done in 361.0 msec
# [solve] done in 357.7 msec
# [solve] done in 29.9 msec
# [solve] done in 35.0 msec
# SOLVER OK!!!!
# [solve] done in 354.5 msec
# [solve] done in 356.0 msec
# [solve] done in 355.2 msec
# [solve] done in 356.5 msec
# [solve] done in 356.1 msec
# [solve] done in 357.2 msec
# [solve] done in 357.1 msec
# [solve] done in 357.1 msec
# [solve] done in 357.5 msec
# [solve] done in 355.4 msec
# [solve] done in 355.9 msec
# [solve] done in 355.9 msec
# [solve] done in 355.8 msec
# [solve] done in 357.3 msec
# [solve] done in 355.7 msec
# [solve] done in 357.8 msec
# [solve] done in 355.4 msec
# [solve] done in 357.1 msec
# [solve] done in 358.3 msec
# [solve] done in 356.1 msec
# [solve] done in 355.9 msec
# [solve] done in 356.6 msec
# [solve] done in 356.9 msec
# [solve] done in 354.8 msec
# [solve] done in 355.9 msec
# [solve] done in 353.6 msec
# [solve] done in 356.9 msec
# [solve] done in 354.9 msec
# [solve] done in 355.5 msec
# [solve] done in 355.2 msec
# [solve] done in 354.7 msec
# [solve] done in 356.3 msec
# [solve] done in 356.4 msec
# [solve] done in 355.3 msec
# [solve] done in 355.3 msec
# [solve] done in 355.0 msec
# [solve] done in 355.3 msec
# [solve] done in 162.2 msec
# [solve] done in 168.6 msec
# SOLVER OK!!!!
# [solve] done in 84.0 msec
# [solve] done in 113.9 msec
# [solve] done in 135.8 msec
# [solve] done in 79.1 msec
# [solve] done in 79.2 msec
# [solve] done in 96.0 msec
# [solve] done in 124.9 msec
# SOLVER OK!!!!
# [solve] done in 358.1 msec
# [solve] done in 356.6 msec
# [solve] done in 356.1 msec
# [solve] done in 357.6 msec
# [solve] done in 357.8 msec
# [solve] done in 356.0 msec
# [solve] done in 356.7 msec
# [solve] done in 355.7 msec
# [solve] done in 355.5 msec
# [solve] done in 358.4 msec
# [solve] done in 355.8 msec
# [solve] done in 358.4 msec
# [solve] done in 357.0 msec
# [solve] done in 358.4 msec
# [solve] done in 355.8 msec
# [solve] done in 358.0 msec
# [solve] done in 357.4 msec
# [solve] done in 356.8 msec
# [solve] done in 354.5 msec
# [solve] done in 355.9 msec
# [solve] done in 163.0 msec
# [solve] done in 308.0 msec
# [solve] done in 346.3 msec
# [solve] done in 327.9 msec
# [solve] done in 245.9 msec
# [solve] done in 345.2 msec
# [solve] done in 345.5 msec
# [solve] done in 355.2 msec
# [solve] done in 353.7 msec
# [solve] done in 355.4 msec
# [solve] done in 367.2 msec
# [solve] done in 354.8 msec
# [solve] done in 356.0 msec
# [solve] done in 355.5 msec
# [solve] done in 355.9 msec
# [solve] done in 355.4 msec
# [solve] done in 354.9 msec
# [solve] done in 356.3 msec
# [solve] done in 356.0 msec
# [solve] done in 354.2 msec
# [solve] done in 354.3 msec
# [solve] done in 354.8 msec
# [solve] done in 355.0 msec
# [solve] done in 355.6 msec
# [solve] done in 354.3 msec
# [solve] done in 354.7 msec
# [solve] done in 254.8 msec
# SOLVER OK!!!!
# [solve] done in 231.2 msec
# [solve] done in 309.9 msec
# [solve] done in 354.2 msec
# [solve] done in 356.2 msec
# [solve] done in 356.6 msec
# [solve] done in 354.1 msec
# [solve] done in 354.3 msec
# [solve] done in 354.2 msec
# [solve] done in 353.8 msec
# [solve] done in 354.0 msec
# [solve] done in 355.6 msec
# [solve] done in 355.1 msec
# [solve] done in 354.7 msec
# [solve] done in 357.3 msec
# [solve] done in 355.0 msec
# [solve] done in 355.0 msec
# [solve] done in 354.1 msec
# [solve] done in 354.8 msec
# [solve] done in 353.8 msec
# [solve] done in 355.1 msec
# [solve] done in 354.7 msec
# [solve] done in 355.2 msec
# [solve] done in 355.1 msec
# [solve] done in 357.1 msec
# [solve] done in 354.2 msec
# [solve] done in 354.7 msec
# [solve] done in 356.2 msec
# [solve] done in 355.9 msec
# [solve] done in 353.8 msec
# [solve] done in 128.0 msec
# [solve] done in 130.9 msec
# [solve] done in 152.2 msec
# [solve] done in 134.9 msec
# [solve] done in 163.4 msec
# [solve] done in 149.5 msec
# [solve] done in 199.4 msec
# [solve] done in 150.9 msec
# [solve] done in 206.0 msec
# [solve] done in 211.1 msec
# [solve] done in 203.2 msec
# [solve] done in 281.0 msec
# [solve] done in 357.6 msec
# [solve] done in 357.7 msec
# [solve] done in 359.1 msec
# [solve] done in 357.2 msec
# [solve] done in 356.6 msec
# [solve] done in 357.1 msec
# [solve] done in 356.3 msec
# [solve] done in 356.8 msec
# [solve] done in 355.6 msec
# [solve] done in 357.3 msec
# [solve] done in 356.1 msec
# [solve] done in 358.1 msec
# [solve] done in 357.8 msec
# [solve] done in 355.9 msec
# [solve] done in 358.1 msec
# [solve] done in 357.8 msec
# [solve] done in 357.0 msec
# [solve] done in 357.8 msec
# [solve] done in 358.4 msec
# [solve] done in 163.7 msec
# [solve] done in 204.0 msec
# [solve] done in 133.9 msec
# [solve] done in 208.2 msec
# [solve] done in 281.1 msec
# [solve] done in 284.2 msec
# [solve] done in 315.1 msec
# [solve] done in 319.6 msec
# [solve] done in 355.6 msec
# [solve] done in 355.9 msec
# [solve] done in 355.1 msec
# [solve] done in 356.7 msec
# [solve] done in 354.8 msec
# [solve] done in 327.2 msec
# [solve] done in 354.9 msec
# [solve] done in 358.1 msec
# [solve] done in 355.3 msec
# [solve] done in 354.0 msec
# [solve] done in 355.4 msec
# [solve] done in 355.9 msec
# [solve] done in 354.9 msec
# [solve] done in 354.3 msec
# [solve] done in 353.9 msec
# [solve] done in 354.7 msec
# [solve] done in 353.9 msec
# [solve] done in 353.9 msec
# [solve] done in 354.6 msec
# [solve] done in 354.6 msec
# [solve] done in 356.9 msec
# [solve] done in 356.2 msec
# [solve] done in 354.0 msec
# [solve] done in 362.6 msec
# [solve] done in 357.1 msec
# [solve] done in 358.9 msec
# [solve] done in 361.1 msec
# [solve] done in 357.9 msec
# [solve] done in 359.0 msec
# [solve] done in 357.8 msec
# [solve] done in 360.0 msec
# [solve] done in 359.1 msec
# [solve] done in 358.9 msec
# [solve] done in 358.0 msec
# [solve] done in 360.0 msec
# [solve] done in 355.7 msec
# [solve] done in 303.2 msec
# [solve] done in 354.3 msec
# [solve] done in 356.0 msec
# [solve] done in 353.2 msec
# [solve] done in 354.4 msec
# [solve] done in 354.8 msec
# [solve] done in 355.7 msec
# [solve] done in 353.6 msec
# [solve] done in 354.1 msec
# [solve] done in 355.5 msec
# [solve] done in 356.9 msec
# [solve] done in 356.8 msec
# [solve] done in 355.1 msec
# [solve] done in 356.2 msec
# [solve] done in 357.1 msec
# [solve] done in 355.7 msec
# [solve] done in 356.1 msec
# [solve] done in 357.0 msec
# [solve] done in 360.8 msec
# [solve] done in 356.0 msec
# [solve] done in 356.8 msec
# [solve] done in 356.9 msec
# [solve] done in 354.8 msec
# [solve] done in 356.1 msec
# [solve] done in 356.5 msec
# [solve] done in 358.5 msec
# [solve] done in 356.2 msec
# [solve] done in 357.0 msec
# [solve] done in 357.0 msec
# [solve] done in 355.8 msec
# [solve] done in 357.1 msec
# [solve] done in 358.1 msec
# [solve] done in 357.1 msec
# [solve] done in 355.8 msec
# [solve] done in 356.1 msec
# [solve] done in 356.2 msec
# [solve] done in 355.5 msec
# [solve] done in 355.2 msec
# [solve] done in 354.6 msec
# [solve] done in 357.9 msec
# [solve] done in 354.6 msec
# [solve] done in 355.4 msec
# [solve] done in 388.0 msec
# [solve] done in 355.3 msec
# [solve] done in 356.7 msec
# [solve] done in 158.9 msec
# [solve] done in 273.5 msec
# [solve] done in 354.9 msec
# [solve] done in 354.9 msec
# [solve] done in 355.0 msec
# [solve] done in 335.9 msec
# [solve] done in 349.0 msec
# [solve] done in 238.0 msec
# [solve] done in 165.1 msec
# [solve] done in 141.9 msec
# [solve] done in 272.8 msec
# [solve] done in 309.7 msec
# [solve] done in 294.1 msec
# [solve] done in 356.3 msec
# [solve] done in 358.1 msec
# [solve] done in 355.4 msec
# [solve] done in 353.9 msec
# [solve] done in 360.1 msec
# [solve] done in 369.2 msec
# [solve] done in 357.1 msec
# [solve] done in 356.9 msec
# [solve] done in 357.3 msec
# [solve] done in 475.2 msec
# [solve] done in 353.6 msec
# [solve] done in 355.0 msec
# [solve] done in 354.8 msec
# [solve] done in 354.8 msec
# [solve] done in 356.0 msec
# [solve] done in 355.6 msec
# [solve] done in 355.1 msec
# [solve] done in 355.9 msec
# [solve] done in 356.2 msec
# [solve] done in 356.1 msec
# [solve] done in 354.9 msec
# [solve] done in 355.0 msec
# [solve] done in 354.7 msec
# [solve] done in 356.2 msec
# [solve] done in 369.0 msec
# [solve] done in 362.1 msec
# [solve] done in 364.8 msec
# [solve] done in 360.4 msec
# [solve] done in 362.6 msec
# [solve] done in 363.0 msec
# [solve] done in 359.7 msec
# [solve] done in 363.8 msec
# [solve] done in 364.9 msec
# [solve] done in 360.7 msec
# [solve] done in 364.0 msec
# [solve] done in 355.0 msec
# [solve] done in 357.1 msec
# [solve] done in 354.9 msec
# [solve] done in 356.2 msec
# [solve] done in 355.8 msec
# [solve] done in 355.7 msec
# [solve] done in 342.6 msec
# [solve] done in 355.0 msec
# [solve] done in 355.9 msec
# [solve] done in 354.6 msec
# [solve] done in 354.2 msec
# [solve] done in 353.9 msec
# [solve] done in 354.1 msec
# [solve] done in 354.6 msec
# [solve] done in 357.6 msec
# [solve] done in 354.9 msec
# [solve] done in 355.3 msec
# [solve] done in 357.3 msec
# [solve] done in 356.1 msec
# [solve] done in 356.5 msec
# [solve] done in 355.0 msec
# [solve] done in 355.0 msec
# [solve] done in 357.0 msec
# ...
# [solve] done in 365.1 msec
# [solve] done in 407.6 msec
# [solve] done in 359.8 msec
# [solve] done in 359.7 msec
# [solve] done in 367.4 msec
# [solve] done in 367.4 msec
# [solve] done in 358.3 msec
# [solve] done in 362.8 msec
# [solve] done in 360.6 msec
# [solve] done in 359.1 msec
# [solve] done in 365.4 msec
# [solve] done in 360.2 msec
# [solve] done in 355.1 msec
# [solve] done in 354.8 msec
# [solve] done in 355.9 msec
# [solve] done in 356.6 msec
# [solve] done in 355.0 msec
# [solve] done in 356.6 msec
# [solve] done in 357.2 msec
# [solve] done in 356.1 msec
# [solve] done in 356.1 msec
# [solve] done in 355.0 msec
# [solve] done in 354.9 msec
# [solve] done in 354.9 msec
# [solve] done in 355.3 msec
# [solve] done in 354.5 msec
# [solve] done in 356.0 msec
# [solve] done in 354.5 msec
# [solve] done in 356.0 msec
# [solve] done in 354.6 msec
# [solve] done in 355.7 msec
# [solve] done in 354.8 msec
# [solve] done in 356.0 msec
# [solve] done in 354.9 msec
# [solve] done in 355.5 msec
# [solve] done in 354.8 msec
# [solve] done in 356.2 msec
# [solve] done in 356.7 msec
# [solve] done in 354.9 msec
# [solve] done in 356.1 msec
# [solve] done in 355.9 msec
# [solve] done in 354.2 msec
# [solve] done in 358.0 msec
# [solve] done in 356.0 msec
# [solve] done in 355.2 msec
# [solve] done in 356.3 msec
# [solve] done in 355.1 msec
# [solve] done in 356.7 msec
# [solve] done in 354.6 msec
# [solve] done in 354.6 msec
# [solve] done in 356.9 msec
# [solve] done in 357.2 msec
# [solve] done in 356.9 msec
# [solve] done in 355.2 msec
# [solve] done in 355.2 msec
# [solve] done in 355.9 msec
# [solve] done in 355.6 msec
# [solve] done in 355.7 msec
# [solve] done in 354.5 msec
# [solve] done in 354.6 msec
# [solve] done in 355.0 msec
# [solve] done in 356.0 msec
# [solve] done in 355.6 msec
# [solve] done in 358.1 msec
# [solve] done in 355.7 msec
# [solve] done in 357.0 msec
# [solve] done in 355.7 msec
# [solve] done in 356.4 msec
# [solve] done in 357.2 msec
# [solve] done in 356.6 msec
# [solve] done in 356.3 msec
# [solve] done in 356.1 msec
# [solve] done in 357.0 msec
# [solve] done in 356.7 msec
# [solve] done in 356.2 msec
# [solve] done in 355.5 msec
# [solve] done in 355.7 msec
# [solve] done in 357.0 msec
# [solve] done in 358.1 msec
# [solve] done in 355.4 msec
# [solve] done in 355.8 msec
# [solve] done in 356.8 msec
# [solve] done in 356.1 msec
# [solve] done in 356.2 msec
# [solve] done in 356.6 msec
# [solve] done in 357.0 msec
# [solve] done in 355.7 msec
# [solve] done in 357.1 msec
# [solve] done in 355.3 msec
# [solve] done in 356.0 msec
# [solve] done in 101.3 msec
# SOLVER OK!!!!
# [solve] done in 356.1 msec
# [solve] done in 355.8 msec
# [solve] done in 356.5 msec
# [solve] done in 355.9 msec
# [solve] done in 356.1 msec
# [solve] done in 354.9 msec
# [solve] done in 356.9 msec
# [solve] done in 357.0 msec
# [solve] done in 356.2 msec
# [solve] done in 357.2 msec
# [solve] done in 355.2 msec
# [solve] done in 357.0 msec
# [solve] done in 355.9 msec
# [solve] done in 357.0 msec
# [solve] done in 362.1 msec
# [solve] done in 357.2 msec
# [solve] done in 356.9 msec
# [solve] done in 357.0 msec
# [solve] done in 355.3 msec
# [solve] done in 362.6 msec
# [solve] done in 358.0 msec
# [solve] done in 156.7 msec
# [solve] done in 306.9 msec
# [solve] done in 354.1 msec
# [solve] done in 355.0 msec
# [solve] done in 355.6 msec
# [solve] done in 354.2 msec
# [solve] done in 353.5 msec
# [solve] done in 353.9 msec
# [solve] done in 355.0 msec
# [solve] done in 357.1 msec
# [solve] done in 354.6 msec
# [solve] done in 356.1 msec
# [solve] done in 355.0 msec
# [solve] done in 354.5 msec
# [solve] done in 357.9 msec
# [solve] done in 356.4 msec
# [solve] done in 356.1 msec
# [solve] done in 359.1 msec
# [solve] done in 357.6 msec
# [solve] done in 359.3 msec
# [solve] done in 356.0 msec
# [solve] done in 359.0 msec
# [solve] done in 358.4 msec
# [solve] done in 357.6 msec
# [solve] done in 355.8 msec
# [solve] done in 356.0 msec
# [solve] done in 356.5 msec
# [solve] done in 355.7 msec
# [solve] done in 355.6 msec
# [solve] done in 357.0 msec
# [solve] done in 356.5 msec
# [solve] done in 354.3 msec
# [solve] done in 354.9 msec
# [solve] done in 355.4 msec
# [solve] done in 354.8 msec
# [solve] done in 355.4 msec
# [solve] done in 356.4 msec
# [solve] done in 357.0 msec
# [solve] done in 355.1 msec
# [solve] done in 356.2 msec
# [solve] done in 356.8 msec
# [solve] done in 360.3 msec
# [solve] done in 355.0 msec
# [solve] done in 354.8 msec
# [solve] done in 356.5 msec
# [solve] done in 356.9 msec
# [solve] done in 355.0 msec
# [solve] done in 183.4 msec
# [solve] done in 258.1 msec
# SOLVER OK!!!!
# [solve] done in 54.9 msec
# [solve] done in 58.9 msec
# SOLVER OK!!!!
# [solve] done in 157.9 msec
# [solve] done in 256.9 msec
# [solve] done in 348.9 msec
# [solve] done in 354.8 msec
# [solve] done in 353.6 msec
# [solve] done in 356.0 msec
# [solve] done in 354.9 msec
# [solve] done in 351.1 msec
# [solve] done in 354.4 msec
# [solve] done in 354.8 msec
# [solve] done in 355.1 msec
# [solve] done in 356.2 msec
# [solve] done in 355.2 msec
# [solve] done in 355.3 msec
# [solve] done in 356.1 msec
# [solve] done in 355.0 msec
# [solve] done in 357.1 msec
# [solve] done in 356.3 msec
# [solve] done in 354.9 msec
# [solve] done in 354.7 msec
# [solve] done in 354.2 msec
# [solve] done in 359.9 msec
# [solve] done in 360.9 msec
# [solve] done in 353.6 msec
# [solve] done in 354.8 msec
# [solve] done in 358.1 msec
# [solve] done in 362.5 msec
# [solve] done in 362.5 msec
# [solve] done in 354.6 msec
# [solve] done in 360.1 msec
# [solve] done in 363.7 msec
# [solve] done in 408.8 msec
# [solve] done in 405.2 msec
# [solve] done in 357.9 msec
# [solve] done in 355.8 msec
# [solve] done in 358.7 msec
# [solve] done in 359.0 msec
# [solve] done in 368.1 msec
# [solve] done in 358.2 msec
# [solve] done in 365.9 msec
# [solve] done in 358.1 msec
# [solve] done in 356.7 msec
# [solve] done in 359.9 msec
# [solve] done in 357.3 msec
# [solve] done in 356.0 msec
# [solve] done in 355.9 msec
# [solve] done in 354.7 msec
# [solve] done in 354.8 msec
# [solve] done in 356.1 msec
# [solve] done in 356.1 msec
# [solve] done in 356.6 msec
# [solve] done in 356.1 msec
# [solve] done in 355.2 msec
# [solve] done in 356.9 msec
# [solve] done in 354.1 msec
# [solve] done in 356.0 msec
# [solve] done in 354.1 msec
# [solve] done in 355.2 msec
# [solve] done in 354.9 msec
# [solve] done in 354.3 msec
# [solve] done in 354.9 msec
# [solve] done in 355.4 msec
# [solve] done in 354.7 msec
# [solve] done in 354.3 msec
# [solve] done in 11.8 msec
# [solve] done in 12.4 msec
# [solve] done in 12.3 msec
# SOLVER OK!!!!
# [solve] done in 355.8 msec
# [solve] done in 354.3 msec
# [solve] done in 356.0 msec
# [solve] done in 354.6 msec
# [solve] done in 356.2 msec
# [solve] done in 354.5 msec
# [solve] done in 355.4 msec
# [solve] done in 356.0 msec
# [solve] done in 356.4 msec
# [solve] done in 355.2 msec
# [solve] done in 354.8 msec
# [solve] done in 356.6 msec
# [solve] done in 356.6 msec
# [solve] done in 356.4 msec
# [solve] done in 355.6 msec
# [solve] done in 354.9 msec
# [solve] done in 355.1 msec
# [solve] done in 355.7 msec
# [solve] done in 362.4 msec
# [solve] done in 359.3 msec
# [solve] done in 359.8 msec
# [solve] done in 362.6 msec
# [solve] done in 361.1 msec
# [solve] done in 363.8 msec
# [solve] done in 360.2 msec
# [solve] done in 362.3 msec
# [solve] done in 363.1 msec
# [solve] done in 363.3 msec
# [solve] done in 365.6 msec
# [solve] done in 372.1 msec
# [solve] done in 360.8 msec
# [solve] done in 356.2 msec
# [solve] done in 356.5 msec
# [solve] done in 354.2 msec
# [solve] done in 354.4 msec
# [solve] done in 354.7 msec
# [solve] done in 356.7 msec
# [solve] done in 356.0 msec
# [solve] done in 357.4 msec
# [solve] done in 354.9 msec
# [solve] done in 356.0 msec
# [solve] done in 357.0 msec
# [solve] done in 355.9 msec
# [solve] done in 354.8 msec
# [solve] done in 356.0 msec
# [solve] done in 354.8 msec
# [solve] done in 355.4 msec
# [solve] done in 356.0 msec
# [solve] done in 354.7 msec
# [solve] done in 357.7 msec
# [solve] done in 355.2 msec
# [solve] done in 356.1 msec
# [solve] done in 356.4 msec
# [solve] done in 354.8 msec
# [solve] done in 356.5 msec
# [solve] done in 354.2 msec
# [solve] done in 355.8 msec
# [solve] done in 354.2 msec
# [solve] done in 354.9 msec
# [solve] done in 356.2 msec
# [solve] done in 355.8 msec
# [solve] done in 354.2 msec
# [solve] done in 355.9 msec
# [solve] done in 356.4 msec
# [solve] done in 357.0 msec
# [solve] done in 353.6 msec
# [solve] done in 355.9 msec
# [solve] done in 356.0 msec
# [solve] done in 356.0 msec
# [solve] done in 354.6 msec
# [solve] done in 356.0 msec
# [solve] done in 356.0 msec
# [solve] done in 355.9 msec
# [solve] done in 355.0 msec
# [solve] done in 354.5 msec
# [solve] done in 357.6 msec
# [solve] done in 356.3 msec
# [solve] done in 357.4 msec
# [solve] done in 354.8 msec
# [solve] done in 355.1 msec
# [solve] done in 355.3 msec
# [solve] done in 356.1 msec
# [solve] done in 356.6 msec
# [solve] done in 356.9 msec
# [solve] done in 354.9 msec
# [solve] done in 357.0 msec
# [solve] done in 355.4 msec
# [solve] done in 356.2 msec
# [solve] done in 356.0 msec
# [solve] done in 355.2 msec
# [solve] done in 356.4 msec
# [solve] done in 356.0 msec
# [solve] done in 356.0 msec
# [solve] done in 356.2 msec
# [solve] done in 356.2 msec
# [solve] done in 354.2 msec
# [solve] done in 354.8 msec
# [solve] done in 354.7 msec
# [solve] done in 358.1 msec
# [solve] done in 357.1 msec
# [solve] done in 355.8 msec
# [solve] done in 358.4 msec
# [solve] done in 355.9 msec
# [solve] done in 357.0 msec
# [solve] done in 358.0 msec
# [solve] done in 359.4 msec
# [solve] done in 357.5 msec
# [solve] done in 355.7 msec
# [solve] done in 356.7 msec
# [solve] done in 358.4 msec
# [solve] done in 359.1 msec
# [solve] done in 357.8 msec
# [solve] done in 379.3 msec
# [solve] done in 357.3 msec
# [solve] done in 356.9 msec
# [solve] done in 356.1 msec
# [solve] done in 356.1 msec
# [solve] done in 356.4 msec
# [solve] done in 357.9 msec
# [solve] done in 356.9 msec
# [solve] done in 356.8 msec
# [solve] done in 355.9 msec
# [solve] done in 356.9 msec
# [solve] done in 356.2 msec
# [solve] done in 355.1 msec
# [solve] done in 356.6 msec
# [solve] done in 355.9 msec
# [solve] done in 357.1 msec
# [solve] done in 357.2 msec
# [solve] done in 358.1 msec
# [solve] done in 356.1 msec
# [solve] done in 355.8 msec
# [solve] done in 355.1 msec
# [solve] done in 357.9 msec
# [solve] done in 356.4 msec
# [solve] done in 356.1 msec
# [solve] done in 359.3 msec
# [solve] done in 356.0 msec
# [solve] done in 357.3 msec
# [solve] done in 356.9 msec
# [solve] done in 358.0 msec
# [solve] done in 356.1 msec
# [solve] done in 360.7 msec
# [solve] done in 407.0 msec
# [solve] done in 358.0 msec
# [solve] done in 405.2 msec
# [solve] done in 358.0 msec
# [solve] done in 360.1 msec
# [solve] done in 357.0 msec
# [solve] done in 355.8 msec
# [solve] done in 356.9 msec
# [solve] done in 357.1 msec
# [solve] done in 357.1 msec
# [solve] done in 355.1 msec
# [solve] done in 355.6 msec
# [solve] done in 356.5 msec
# [solve] done in 355.8 msec
# [solve] done in 356.8 msec
# [solve] done in 356.7 msec
# [solve] done in 355.8 msec
# [solve] done in 356.3 msec
# [solve] done in 355.8 msec
# [solve] done in 356.1 msec
# [solve] done in 355.7 msec
# [solve] done in 11.3 msec
# [solve] done in 10.3 msec
# SOLVER OK!!!!
# [solve] done in 325.8 msec
# [solve] done in 354.9 msec
# [solve] done in 355.5 msec
# [solve] done in 355.2 msec
# [solve] done in 353.4 msec
# [solve] done in 353.8 msec
# [solve] done in 356.1 msec
# [solve] done in 356.2 msec
# [solve] done in 357.0 msec
# [solve] done in 354.5 msec
# [solve] done in 353.7 msec
# [solve] done in 357.9 msec
# [solve] done in 355.3 msec
# [solve] done in 355.2 msec
# [solve] done in 355.0 msec
# [solve] done in 354.5 msec
# [solve] done in 354.0 msec
# [solve] done in 355.8 msec
# [solve] done in 356.2 msec
# [solve] done in 355.1 msec
# [solve] done in 356.3 msec
# [solve] done in 355.9 msec
# [solve] done in 158.8 msec
# [solve] done in 192.2 msec
# [solve] done in 218.7 msec
# [solve] done in 161.0 msec
# [solve] done in 238.7 msec
# [solve] done in 177.9 msec
# [solve] done in 181.8 msec
# [solve] done in 217.9 msec
# [solve] done in 176.7 msec
# [solve] done in 215.4 msec
# [solve] done in 289.0 msec
# [solve] done in 67.4 msec
# [solve] done in 91.5 msec
# SOLVER OK!!!!
# [solve] done in 361.8 msec
# [solve] done in 362.4 msec
# [solve] done in 361.9 msec
# [solve] done in 360.5 msec
# [solve] done in 361.0 msec
# [solve] done in 359.7 msec
# [solve] done in 362.3 msec
# [solve] done in 360.8 msec
# [solve] done in 360.7 msec
# [solve] done in 358.9 msec
# [solve] done in 355.1 msec
# [solve] done in 355.6 msec
# [solve] done in 354.2 msec
# [solve] done in 356.3 msec
# [solve] done in 353.9 msec
# [solve] done in 354.0 msec
# [solve] done in 353.8 msec
# [solve] done in 355.0 msec
# [solve] done in 353.6 msec
# [solve] done in 353.9 msec
# [solve] done in 356.1 msec
# [solve] done in 353.9 msec
# [solve] done in 353.8 msec
# [solve] done in 355.5 msec
# [solve] done in 354.6 msec
# [solve] done in 355.5 msec
# [solve] done in 36.7 msec
# [solve] done in 73.3 msec
# SOLVER OK!!!!
# [solve] done in 111.3 msec
# [solve] done in 130.8 msec
# [solve] done in 131.2 msec
# [solve] done in 218.4 msec
# [solve] done in 231.1 msec
# [solve] done in 234.7 msec
# [solve] done in 174.1 msec
# [solve] done in 302.9 msec
# [solve] done in 204.9 msec
# [solve] done in 267.3 msec
# [solve] done in 308.0 msec
# SOLVER OK!!!!
# [solve] done in 356.1 msec
# [solve] done in 355.9 msec
# [solve] done in 356.3 msec
# [solve] done in 355.9 msec
# [solve] done in 355.2 msec
# [solve] done in 355.9 msec
# [solve] done in 356.1 msec
# [solve] done in 356.4 msec
# [solve] done in 354.7 msec
# [solve] done in 357.3 msec
# [solve] done in 355.8 msec
# [solve] done in 355.5 msec
# [solve] done in 356.1 msec
# [solve] done in 356.9 msec
# [solve] done in 355.3 msec
# [solve] done in 354.9 msec
# [solve] done in 355.4 msec
# [solve] done in 354.5 msec
# [solve] done in 355.9 msec
# [solve] done in 354.8 msec
# [solve] done in 354.1 msec
# [solve] done in 355.2 msec
# [solve] done in 355.8 msec
# [solve] done in 355.3 msec
# [solve] done in 355.6 msec
# [solve] done in 355.0 msec
# [solve] done in 354.7 msec
# [solve] done in 356.9 msec
# [solve] done in 355.1 msec
# [solve] done in 356.1 msec
# [solve] done in 356.9 msec
# [solve] done in 355.1 msec
# [solve] done in 355.1 msec
# [solve] done in 396.2 msec
# [solve] done in 353.8 msec
# [solve] done in 393.8 msec
# [solve] done in 355.7 msec
# [solve] done in 384.5 msec
# [solve] done in 354.0 msec
# [solve] done in 354.5 msec
# [solve] done in 354.8 msec
# [solve] done in 398.4 msec
# [solve] done in 353.5 msec
# [solve] done in 355.2 msec
# [solve] done in 357.0 msec
# [solve] done in 357.1 msec
# [solve] done in 356.1 msec
# [solve] done in 357.0 msec
# [solve] done in 355.9 msec
# [solve] done in 358.2 msec
# [solve] done in 356.3 msec
# [solve] done in 356.2 msec
# [solve] done in 358.1 msec
# [solve] done in 357.6 msec
# [solve] done in 359.0 msec
# [solve] done in 366.1 msec
# [solve] done in 355.8 msec
# [solve] done in 355.7 msec
# [solve] done in 356.9 msec
# [solve] done in 357.9 msec
# [solve] done in 357.4 msec
# [solve] done in 355.9 msec
# [solve] done in 357.3 msec
# [solve] done in 354.9 msec
# [solve] done in 358.7 msec
# [solve] done in 355.7 msec
# [solve] done in 360.0 msec
# [solve] done in 355.6 msec
# [solve] done in 356.9 msec
# [solve] done in 357.2 msec
# [solve] done in 358.2 msec
# [solve] done in 357.3 msec
# [solve] done in 357.0 msec
# [solve] done in 356.5 msec
# [solve] done in 356.4 msec
# [solve] done in 355.9 msec
# [solve] done in 357.9 msec
# [solve] done in 356.2 msec
# [solve] done in 356.0 msec
# [solve] done in 360.0 msec
# [solve] done in 354.7 msec
# [solve] done in 356.8 msec
# [solve] done in 357.1 msec
# [solve] done in 357.1 msec
# [solve] done in 356.5 msec
# [solve] done in 354.7 msec
# [solve] done in 355.9 msec
# [solve] done in 355.7 msec
# [solve] done in 356.7 msec
# [solve] done in 355.3 msec
# [solve] done in 356.0 msec
# [solve] done in 354.6 msec
# [solve] done in 355.1 msec
# [solve] done in 355.9 msec
# [solve] done in 355.0 msec
# [solve] done in 355.1 msec
# [solve] done in 356.4 msec
# [solve] done in 355.3 msec
# [solve] done in 356.9 msec
# [solve] done in 355.9 msec
# [solve] done in 357.1 msec
# [solve] done in 356.8 msec
# [solve] done in 304.5 msec
# [solve] done in 284.3 msec
# [solve] done in 316.0 msec
# SOLVER OK!!!!
# [solve] done in 128.1 msec
# [solve] done in 109.3 msec
# [solve] done in 121.8 msec
# [solve] done in 117.5 msec
# [solve] done in 146.8 msec
# [solve] done in 139.2 msec
# [solve] done in 142.6 msec
# [solve] done in 213.1 msec
# [solve] done in 213.7 msec
# [solve] done in 135.0 msec
# [solve] done in 177.1 msec
# [solve] done in 261.7 msec
# SOLVER OK!!!!

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.bar(list(range(len(n_size))), n_size, alpha=0.5)
plt.bar(list(range(len(scores))), scores)
plt.bar(list(range(len(ans_points))), ans_points, alpha=0.5)

plt.xticks(range(0, len(scores)+1, 5))
plt.show()

print(sum(scores) / len(scores))
# Out:
# 134.13

# %%
m_list = []
n_list = []
level_list = []
point_list = []
for result in smt_solved_result:
    n, m, level, score, point_size = result
    n_list.append(n)
    m_list.append(m)
    level_list.append(level)
    point_list.append(point_size)

# %%
c.keys(), c.values()
# Out:
# (dict_keys([0.05, 0.45, 0.75, 0.6, 0.1, 0.2, 0.4, 0.25, 0.15, 0.3, 0.35, 0.5]),
#  dict_values([63, 11, 15, 13, 65, 18, 10, 18, 30, 20, 9, 8]))

# %%
from collections import Counter
c = Counter(level_list)
plt.bar(c.keys(), c.values(), width=0.01)
plt.show()

# %%
# 0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.60, 0.75, 1.0

[0.075, 0.125, 0.2, 0.3, 0.55, 1]

# %%
plt.figure(figsize=(6,6))
# plt.scatter(n_list, m_list, s=3)
plt.hist2d(n_list, m_list)
plt.xlabel("n")
plt.ylabel("m")
plt.show()

# %%
# 10, 5
# 11, 5
# 12, 4
# 13, 3
# 14, 2
# 15, 2

# %%
smt_solved_result
# Out:
# [(12, 3, 0.05, 8, 44),
#  (10, 5, 0.45, 53, 27),
#  (10, 5, 0.75, 86, 30),
#  (11, 5, 0.6, 83, 28),
#  (14, 2, 0.05, 10, 30),
#  (11, 2, 0.05, 7, 25),
#  (12, 2, 0.1, 16, 28),
#  (10, 3, 0.75, 86, 18),
#  (12, 2, 0.75, 119, 25),
#  (12, 3, 0.2, 32, 50),
#  (17, 2, 0.05, 15, 53),
#  (11, 2, 0.4, 56, 35),
#  (13, 4, 0.25, 55, 47),
#  (10, 2, 0.15, 17, 25),
#  (10, 2, 0.1, 11, 36),
#  (11, 5, 0.6, 83, 30),
#  (10, 3, 0.3, 35, 19),
#  (12, 2, 0.1, 16, 44),
#  (13, 3, 0.1, 18, 39),
#  (10, 3, 0.1, 11, 31),
#  (12, 3, 0.15, 24, 48),
#  (12, 2, 0.3, 49, 33),
#  (10, 2, 0.75, 86, 26),
#  (14, 2, 0.1, 22, 60),
#  (10, 5, 0.75, 86, 31),
#  (13, 4, 0.1, 18, 58),
#  (10, 3, 0.15, 17, 24),
#  (13, 4, 0.25, 47, 33),
#  (11, 4, 0.15, 21, 44),
#  (11, 2, 0.1, 14, 41),
#  (11, 4, 0.1, 14, 28),
#  (12, 3, 0.35, 57, 36),
#  (16, 3, 0.05, 13, 71),
#  (14, 2, 0.3, 64, 31),
#  (12, 4, 0.45, 73, 37),
#  (10, 3, 0.15, 17, 30),
#  (10, 4, 0.35, 41, 32),
#  (17, 2, 0.05, 15, 90),
#  (14, 2, 0.05, 10, 96),
#  (13, 4, 0.25, 47, 42),
#  (10, 4, 0.6, 70, 25),
#  (10, 2, 0.1, 11, 26),
#  (10, 2, 0.05, 5, 38),
#  (16, 2, 0.05, 13, 47),
#  (19, 2, 0.05, 19, 148),
#  (12, 4, 0.2, 32, 27),
#  (14, 2, 0.05, 10, 77),
#  (10, 3, 0.3, 35, 24),
#  (10, 3, 0.15, 17, 31),
#  (18, 2, 0.5, 171, 55),
#  (11, 5, 0.75, 104, 25),
#  (11, 6, 0.45, 65, 27),
#  (10, 3, 0.15, 17, 34),
#  (16, 2, 0.05, 13, 96),
#  (13, 2, 0.1, 18, 37),
#  (10, 4, 0.15, 17, 40),
#  (11, 5, 0.25, 40, 29),
#  (12, 4, 0.15, 24, 31),
#  (11, 2, 0.1, 14, 32),
#  (13, 3, 0.1, 18, 59),
#  (11, 3, 0.1, 14, 24),
#  (16, 2, 0.05, 13, 73),
#  (10, 2, 0.1, 11, 31),
#  (10, 2, 0.1, 11, 29),
#  (11, 2, 0.05, 7, 52),
#  (12, 2, 0.05, 8, 41),
#  (10, 3, 0.15, 17, 27),
#  (10, 2, 0.25, 29, 21),
#  (12, 4, 0.2, 49, 54),
#  (10, 4, 0.2, 23, 36),
#  (16, 2, 0.05, 13, 70),
#  (12, 4, 0.2, 32, 41),
#  (10, 3, 0.1, 11, 42),
#  (10, 5, 0.2, 23, 26),
#  (11, 5, 0.1, 14, 42),
#  (11, 2, 0.05, 7, 45),
#  (10, 5, 0.6, 70, 23),
#  (10, 4, 0.4, 47, 31),
#  (12, 3, 0.45, 73, 36),
#  (11, 5, 0.35, 50, 28),
#  (10, 4, 0.75, 86, 19),
#  (11, 4, 0.2, 28, 38),
#  (19, 2, 0.05, 19, 47),
#  (12, 4, 0.6, 97, 48),
#  (10, 4, 0.35, 41, 17),
#  (14, 3, 0.3, 64, 67),
#  (10, 4, 0.45, 53, 23),
#  (11, 4, 0.3, 42, 39),
#  (10, 3, 0.3, 35, 23),
#  (11, 2, 0.05, 7, 26),
#  (12, 2, 0.05, 8, 28),
#  (18, 2, 0.05, 17, 105),
#  (11, 2, 0.05, 7, 40),
#  (10, 5, 0.6, 70, 33),
#  (17, 2, 0.05, 15, 108),
#  (10, 3, 0.1, 11, 27),
#  (11, 3, 0.1, 14, 35),
#  (14, 2, 0.2, 43, 90),
#  (13, 4, 0.3, 56, 46),
#  (11, 2, 0.1, 14, 40),
#  (11, 3, 0.4, 56, 26),
#  (12, 3, 0.25, 40, 30),
#  (10, 3, 0.4, 47, 21),
#  (12, 6, 0.25, 52, 40),
#  (13, 3, 0.05, 9, 27),
#  (10, 2, 0.1, 11, 39),
#  (11, 3, 0.25, 35, 36),
#  (10, 4, 0.75, 86, 22),
#  (10, 2, 0.1, 11, 41),
#  (11, 3, 0.1, 14, 40),
#  (10, 3, 0.1, 11, 26),
#  (11, 2, 0.15, 21, 32),
#  (12, 5, 0.15, 25, 55),
#  (17, 3, 0.05, 15, 71),
#  (10, 2, 0.1, 11, 27),
#  (10, 5, 0.4, 49, 26),
#  (15, 2, 0.05, 12, 77),
#  (10, 4, 0.2, 23, 22),
#  (11, 4, 0.5, 70, 24),
#  (10, 3, 0.1, 11, 26),
#  (10, 3, 0.15, 17, 27),
#  (10, 4, 0.15, 17, 28),
#  (12, 2, 0.5, 81, 42),
#  (11, 4, 0.1, 14, 35),
#  (13, 4, 0.15, 28, 51),
#  (10, 5, 0.3, 35, 29),
#  (10, 4, 0.75, 86, 23),
#  (11, 2, 0.1, 14, 35),
#  (10, 2, 0.05, 5, 31),
#  (12, 2, 0.05, 8, 35),
#  (12, 5, 0.25, 41, 40),
#  (11, 5, 0.25, 35, 50),
#  (10, 2, 0.15, 17, 25),
#  (11, 2, 0.1, 14, 25),
#  (14, 4, 0.15, 35, 57),
#  (14, 3, 0.05, 10, 65),
#  (10, 3, 0.3, 35, 21),
#  (11, 2, 0.1, 14, 29),
#  (11, 3, 0.5, 70, 24),
#  (10, 5, 0.35, 41, 31),
#  (16, 2, 0.05, 13, 72),
#  (10, 5, 0.45, 53, 30),
#  (14, 2, 0.1, 21, 28),
#  (12, 2, 0.1, 16, 62),
#  (16, 2, 0.05, 13, 74),
#  (10, 4, 0.45, 53, 21),
#  (14, 3, 0.05, 10, 49),
#  (11, 3, 0.1, 14, 51),
#  (10, 5, 0.25, 29, 23),
#  (12, 4, 0.2, 35, 38),
#  (10, 4, 0.25, 29, 37),
#  (11, 5, 0.4, 56, 41),
#  (10, 5, 0.75, 86, 36),
#  (19, 2, 0.05, 19, 126),
#  (11, 4, 0.2, 28, 44),
#  (13, 3, 0.2, 37, 32),
#  (11, 5, 0.75, 105, 23),
#  (12, 2, 0.1, 16, 37),
#  (13, 2, 0.05, 9, 59),
#  (16, 2, 0.05, 13, 86),
#  (14, 3, 0.15, 32, 33),
#  (10, 5, 0.35, 41, 28),
#  (11, 6, 0.15, 34, 29),
#  (18, 3, 0.05, 17, 88),
#  (10, 3, 0.3, 35, 35),
#  (12, 3, 0.1, 16, 44),
#  (10, 5, 0.45, 53, 20),
#  (12, 3, 0.25, 40, 41),
#  (11, 3, 0.15, 21, 17),
#  (11, 2, 0.4, 56, 28),
#  (10, 4, 0.5, 59, 40),
#  (10, 5, 0.5, 59, 36),
#  (10, 3, 0.45, 53, 26),
#  (13, 2, 0.05, 9, 46),
#  (11, 2, 0.25, 35, 22),
#  (14, 2, 0.1, 21, 72),
#  (10, 2, 0.05, 5, 30),
#  (11, 6, 0.3, 42, 22),
#  (11, 2, 0.05, 7, 31),
#  (13, 2, 0.05, 9, 67),
#  (12, 4, 0.3, 49, 29),
#  (11, 3, 0.1, 14, 32),
#  (16, 3, 0.05, 13, 84),
#  (12, 3, 0.1, 16, 47),
#  (15, 2, 0.1, 25, 68),
#  (11, 3, 0.3, 42, 46),
#  (12, 4, 0.3, 49, 56),
#  (20, 2, 0.05, 20, 145),
#  (13, 2, 0.1, 18, 50),
#  (10, 4, 0.4, 47, 32),
#  (14, 3, 0.05, 10, 53),
#  (13, 2, 0.1, 18, 61),
#  (20, 2, 0.05, 20, 136),
#  (11, 2, 0.1, 14, 21),
#  (11, 2, 0.1, 14, 35),
#  (10, 3, 0.25, 29, 28),
#  (11, 4, 0.5, 71, 38),
#  (10, 4, 0.4, 47, 25),
#  (13, 3, 0.1, 18, 46),
#  (10, 3, 0.15, 17, 29),
#  (10, 5, 0.75, 86, 27),
#  (11, 4, 0.15, 22, 41),
#  (10, 5, 0.25, 29, 27),
#  (11, 4, 0.15, 21, 39),
#  (10, 5, 0.6, 70, 31),
#  (10, 3, 0.25, 29, 31),
#  (13, 2, 0.05, 9, 62),
#  (10, 3, 0.3, 35, 28),
#  (11, 2, 0.05, 7, 34),
#  (13, 2, 0.05, 9, 28),
#  (10, 5, 0.2, 23, 35),
#  (12, 2, 0.1, 16, 39),
#  (11, 4, 0.2, 28, 37),
#  (12, 3, 0.2, 32, 49),
#  (13, 3, 0.6, 119, 23),
#  (10, 5, 0.3, 35, 34),
#  (12, 3, 0.05, 8, 52),
#  (12, 4, 0.1, 16, 30),
#  (19, 2, 0.05, 19, 52),
#  (10, 4, 0.2, 23, 32),
#  (11, 2, 0.1, 14, 29),
#  (10, 3, 0.1, 11, 35),
#  (10, 4, 0.35, 41, 23),
#  (13, 4, 0.35, 67, 51),
#  (10, 4, 0.2, 23, 32),
#  (10, 4, 0.1, 11, 41),
#  (17, 2, 0.05, 15, 111),
#  (12, 4, 0.1, 16, 31),
#  (16, 2, 0.05, 13, 34),
#  (12, 2, 0.45, 73, 23),
#  (15, 3, 0.05, 12, 79),
#  (11, 2, 0.05, 7, 41),
#  (16, 2, 0.05, 13, 65),
#  (15, 3, 0.05, 12, 54),
#  (11, 5, 0.75, 102, 25),
#  (12, 2, 0.1, 16, 44),
#  (11, 2, 0.1, 14, 31),
#  (14, 2, 0.05, 10, 37),
#  (10, 4, 0.15, 17, 34),
#  (10, 5, 0.45, 53, 24),
#  (13, 3, 0.05, 9, 58),
#  (10, 5, 0.4, 47, 38),
#  (12, 4, 0.5, 81, 36),
#  (13, 2, 0.05, 9, 53),
#  (16, 2, 0.05, 13, 66),
#  (13, 3, 0.1, 18, 57),
#  (11, 5, 0.6, 83, 29),
#  (13, 2, 0.15, 28, 39),
#  (11, 4, 0.15, 22, 44),
#  (13, 3, 0.35, 66, 38),
#  (10, 4, 0.15, 17, 37),
#  (10, 5, 0.1, 11, 29),
#  (11, 4, 0.6, 83, 30),
#  (11, 2, 0.3, 42, 35),
#  (10, 2, 0.1, 11, 14),
#  (10, 4, 0.25, 29, 27),
#  (10, 4, 0.2, 23, 43),
#  (10, 4, 0.3, 35, 30),
#  (10, 5, 0.6, 70, 29),
#  (10, 5, 0.75, 86, 34),
#  (16, 3, 0.05, 13, 42),
#  (12, 4, 0.15, 24, 29),
#  (11, 4, 0.3, 42, 33),
#  (13, 2, 0.1, 18, 43),
#  (16, 3, 0.05, 13, 75),
#  (10, 4, 0.6, 70, 29),
#  (13, 2, 0.05, 9, 34),
#  (13, 2, 0.1, 18, 90),
#  (16, 2, 0.1, 27, 107),
#  (11, 3, 0.1, 14, 28),
#  (14, 2, 0.05, 10, 53),
#  (12, 4, 0.1, 16, 48),
#  (10, 3, 0.1, 11, 25),
#  (10, 2, 0.15, 17, 39),
#  (10, 2, 0.1, 11, 48),
#  (14, 2, 0.1, 21, 42),
#  (10, 3, 0.1, 11, 35),
#  (13, 3, 0.6, 112, 30),
#  (14, 4, 0.15, 32, 47),
#  (10, 5, 0.75, 86, 38)]

# %%
# BFS RESULT 1000 > 145.714
