# %%
from pathlib import Path 
import math
import pickle
import bisect
import numpy as np
import time

# %%
DEBUG = True
AREA_MAX = 1000 * 1000
AREA_TH = 0.996
INF = 10 ** 18

def debug_print(*args, **kwargs):
    if DEBUG:
        print(*args, **kwargs)

# %%
def fastcopy(obj):
    return pickle.loads(pickle.dumps(obj, -1))

class Env:
    def __init__(self, input_txt_path: Path):
        self.W, self.D, self.N, self.a = self._input(input_txt_path)

    def _input(self, txt_path):
        with open(txt_path, mode="r") as file:
            lines = file.readlines()
        W, D, N = map(int, lines[0].split())
        a = []
        for line, d in zip(lines[1:], range(D)):
            d = list(map(int, line.split()))
            a.append(d)
        return W, D, N, a

class Area:
    def __init__(self, id_val: int, self_area: int, target_area: int):
        self.id = id_val
        self.self_area = self_area
        self.target_area = target_area
        self.need_first = False

# %%
def check_ans(ans: list[tuple[int]]):
    for d in range(len(ans)):
        for coordinates in ans[d]:
            x1, y1, x2, y2 = coordinates
            if x1 < 0 or x2 > 1000 or y1 < 0 or y2 > 1000:
                return False
    return True

# def check_ans(ans:list[list[int]], env:Env):
#     for d in range(len(ans)):
#         for coordinates in ans[d]:
#             x1, y1, x2, y2 = coordinates
#             if x1 < 0 or x2 > 1000 or y1 < 0 or y2 > 1000:
#                 return False
#     for d in range(len(ans)):
#         for ans_vec, true_area in zip(ans[d], env.a[d]):
#             ans_area = (ans_vec[2] - ans_vec[0]) * (ans_vec[3] - ans_vec[1])
#             if ans_area < true_area:
#                 return False
#     return True

# %%
def get_diff_max(target_areas: list[list[int]], env: Env):
    now_target_areas = fastcopy(target_areas)
    target_dw = len(target_areas)

    get_ind_from_area = [dict() for _ in range(target_dw)]
    for d in range(target_dw):
        tmp_dict = dict()
        for tn in range(env.N):
            val = now_target_areas[d][tn]
            tmp_dict[val] = tn
        get_ind_from_area[d] = tmp_dict

    diff_max = []
    for n in range(env.N):
        tmp_diff_max = []
        len_n = len(now_target_areas[0])
        for d in range(target_dw):
            for tn in range(len_n):
                left_area = now_target_areas[d][tn]
                seach_areas = []
                for next_d in range(target_dw):
                    if d == next_d:
                        seach_areas.append(left_area)
                        continue
                    b_ind = bisect.bisect_left(now_target_areas[next_d], left_area)
                    if b_ind == len_n:
                        break
                    seach_areas.append(now_target_areas[next_d][b_ind])
                if len(seach_areas) != target_dw:
                    continue
                diff = max(seach_areas) - min(seach_areas)
                max_area = max(seach_areas)
                inds = []
                for si, area in enumerate(seach_areas):
                    inds.append(get_ind_from_area[si][area])
                tmp_diff_max.append((diff, max_area, inds, seach_areas))
        sorted_diff_max = sorted(tmp_diff_max)
        add_diff, add_max_area, add_inds, del_areas = sorted_diff_max[0]
        diff_max.append((add_diff, add_max_area, add_inds))
        for si, area in enumerate(del_areas):
            now_target_areas[si].remove(area)

    return diff_max

# %%
def calc_cost(ans: list[list[int]], env: Env):
    partial_cost = 0
    area_cost = 0

    hs = set()
    vs = set()
    for d in range(env.D):
        hs2 = set()
        vs2 = set()
        for k in range(env.N):
            i0, j0, i1, j1 = ans[d][k]
            area = (i1 - i0) * (j1 - j0)
            if env.a[d][k] > area:
                area_cost += 100 * (env.a[d][k] - area)
            for j in range(j0, j1):
                if i0 > 0:
                    hs2.add((i0, j))
                if i1 < env.W:
                    hs2.add((i1, j))
            for i in range(i0, i1):
                if j0 > 0:
                    vs2.add((j0, i))
                if j1 < env.W:
                    vs2.add((j1, i))

        if d > 0:
            for i, j in hs:
                if (i, j) not in hs2:
                    partial_cost += 1
            for j, i in vs:
                if (j, i) not in vs2:
                    partial_cost += 1

        hs = hs2
        vs = vs2
    return partial_cost + area_cost + 1

# %%
def one_day_solve_optim(one_day_area: list[int], env: Env):
    x1 = 0
    y1 = 0
    x2 = 1000
    y2 = 1000

    ans = [None for _ in range(env.N)]
    areas = [(i, area) for i, area in enumerate(one_day_area)]
    for n in range(env.N):
        area_diffs = []
        now_lr = x2 - x1
        now_ud = y2 - y1
        for now_i, (i, area) in enumerate(areas):
            len1 = math.ceil(area / now_lr)
            len2 = math.ceil(area / now_ud)
            if len1 * now_lr < len2 * now_ud:
                direct = "ud"
                diff = len1 * now_lr - area
                area_diffs.append((diff, len1, direct, i, now_i))
            else:
                direct = "lr"
                diff = len2 * now_ud - area
                area_diffs.append((diff, len2, direct, i, now_i))
        min_diff, min_len, min_direct, min_i, min_now_i = sorted(area_diffs)[0]
        if n == env.N - 1:
            ans[min_i] = (x1, y1, x2, y2)
            break
        if min_direct == "ud":
            ans[min_i] = (x1, y1, x2, y1 + min_len)
            y1 += min_len
        else:
            ans[min_i] = (x2 - min_len, y1, x2, y2)
            x2 -= min_len
        areas.pop(min_now_i)
    return [ans]

# %%
def one_day_solve_aspect(one_day_area: list[int], env: Env):
    x1 = 0
    y1 = 0
    x2 = 1000
    y2 = 1000

    ans = [None for _ in range(env.N)]
    areas = [(i, area) for i, area in enumerate(one_day_area)]
    for n in range(env.N):
        area_diffs = []
        now_lr = x2 - x1
        now_ud = y2 - y1
        for now_i, (i, area) in enumerate(areas):
            len1 = math.ceil(area / now_lr)
            len2 = math.ceil(area / now_ud)
            if len1 * now_lr < len2 * now_ud:
                direct = "ud"
                diff = len1 * now_lr - area
                aspect = 1 - min(len1, now_lr) / max(len1, now_lr)
                area_diffs.append((aspect, diff, len1, direct, i, now_i))
            else:
                direct = "lr"
                diff = len2 * now_ud - area
                aspect = 1 - min(len2, now_ud) / max(len2, now_ud)
                area_diffs.append((aspect, diff, len2, direct, i, now_i))
        _, _, min_len, min_direct, min_i, min_now_i = sorted(area_diffs)[0]
        if n == env.N - 1:
            ans[min_i] = (x1, y1, x2, y2)
            break
        if min_direct == "ud":
            ans[min_i] = (x1, y1, x2, y1 + min_len)
            y1 += min_len
        else:
            ans[min_i] = (x2 - min_len, y1, x2, y2)
            x2 -= min_len
        areas.pop(min_now_i)

    if not check_ans([ans]):
        raise ValueError("failed check ans")

    return [ans]

# %%
def one_day_solve(one_day_area: list[int], env: Env):
    try:
        ans = one_day_solve_aspect(one_day_area, env)
    except Exception as e:
        debug_print(f"Err: one_day_solve_aspect {e}")
        ans = one_day_solve_optim(one_day_area, env)
    return ans

# %%
def common_area_solver_core_opt(ret_area_objs, env: Env):

    ans = []
    target_dw = len(ret_area_objs)

    for d in range(target_dw):
        is_need_areas = [area for area in ret_area_objs[d] if area.need_first]
        is_not_need_areas = [area for area in ret_area_objs[d] if not area.need_first]

        x1 = 0
        y1 = 0
        x2 = 1000
        y2 = 1000

        now_ans = [None for _ in range(env.N)]
        for n in range(env.N):
            area_diffs = []
            now_lr = x2 - x1
            now_ud = y2 - y1
            if is_need_areas:
                for target_area in is_need_areas:
                    len1 = math.ceil(target_area.target_area / now_lr)
                    len2 = math.ceil(target_area.target_area / now_ud)
                    if len1 * now_lr < len2 * now_ud:
                        direct = "ud"
                        diff = len1 * now_lr - target_area.target_area
                        area_diffs.append((diff, len1, direct, target_area.id))
                    else:
                        direct = "lr"
                        diff = len2 * now_ud - target_area.target_area
                        area_diffs.append((diff, len2, direct, target_area.id))
            elif is_not_need_areas:
                for target_area in is_not_need_areas:
                    len1 = math.ceil(target_area.target_area / now_lr)
                    len2 = math.ceil(target_area.target_area / now_ud)
                    if len1 * now_lr < len2 * now_ud:
                        direct = "ud"
                        diff = len1 * now_lr - target_area.target_area
                        area_diffs.append((diff, len1, direct, target_area.id))
                    else:
                        direct = "lr"
                        diff = len2 * now_ud - target_area.target_area
                        area_diffs.append((diff, len2, direct, target_area.id))
            else:
                raise ValueError("target is empty")

            min_diff, min_len, min_direct, area_id = sorted(area_diffs)[0]
            if n == env.N - 1:
                now_ans[area_id] = (x1, y1, x2, y2)
                break
            if min_direct == "ud":
                now_ans[area_id] = (x1, y1, x2, y1 + min_len)
                y1 += min_len
            else:
                now_ans[area_id] = (x2 - min_len, y1, x2, y2)
                x2 -= min_len

            if is_need_areas:
                is_need_areas = [area for area in is_need_areas if area.id != area_id]
            elif is_not_need_areas:
                is_not_need_areas = [area for area in is_not_need_areas if area.id != area_id]
        ans.append(now_ans)

    if not check_ans(ans):
        raise ValueError("failed check ans")

    return ans

# %%
def common_area_solver_core_aspect(ret_area_objs, env: Env):

    ans = []
    target_dw = len(ret_area_objs)

    for d in range(target_dw):
        is_need_areas = [area for area in ret_area_objs[d] if area.need_first]
        is_not_need_areas = [area for area in ret_area_objs[d] if not area.need_first]

        x1 = 0
        y1 = 0
        x2 = 1000
        y2 = 1000

        now_ans = [None for _ in range(env.N)]
        for n in range(env.N):
            area_diffs = []
            now_lr = x2 - x1
            now_ud = y2 - y1
            if is_need_areas:
                for target_area in is_need_areas:
                    len1 = math.ceil(target_area.target_area / now_lr)
                    len2 = math.ceil(target_area.target_area / now_ud)
                    if len1 * now_lr < len2 * now_ud:
                        direct = "ud"
                        aspect = 1 - min(len1, now_lr) / max(len1, now_lr)
                        diff = len1 * now_lr - target_area.target_area
                        area_diffs.append((aspect, diff, len1, direct, target_area.id))
                    else:
                        direct = "lr"
                        aspect = 1 - min(len2, now_ud) / max(len2, now_ud)
                        diff = len2 * now_ud - target_area.target_area
                        area_diffs.append((aspect, diff, len2, direct, target_area.id))
            elif is_not_need_areas:
                for target_area in is_not_need_areas:
                    len1 = math.ceil(target_area.target_area / now_lr)
                    len2 = math.ceil(target_area.target_area / now_ud)
                    if len1 * now_lr < len2 * now_ud:
                        direct = "ud"
                        aspect = 1 - min(len1, now_lr) / max(len1, now_lr)
                        diff = len1 * now_lr - target_area.target_area
                        area_diffs.append((aspect, diff, len1, direct, target_area.id))
                    else:
                        direct = "lr"
                        aspect = 1 - min(len2, now_ud) / max(len2, now_ud)
                        diff = len2 * now_ud - target_area.target_area
                        area_diffs.append((aspect, diff, len2, direct, target_area.id))
            else:
                raise ValueError("target is empty")

            _, _, min_len, min_direct, area_id = sorted(area_diffs)[0]
            if n == env.N - 1:
                now_ans[area_id] = (x1, y1, x2, y2)
                break
            if min_direct == "ud":
                now_ans[area_id] = (x1, y1, x2, y1 + min_len)
                y1 += min_len
            else:
                now_ans[area_id] = (x2 - min_len, y1, x2, y2)
                x2 -= min_len

            if is_need_areas:
                is_need_areas = [area for area in is_need_areas if area.id != area_id]
            elif is_not_need_areas:
                is_not_need_areas = [area for area in is_not_need_areas if area.id != area_id]
        ans.append(now_ans)

    if not check_ans(ans):
        raise ValueError("failed check ans")

    return ans

# %%
def common_area_solver(target_areas: list[list[int]], env: Env):

    ans = []

    target_dw = len(target_areas)
    diff_max = get_diff_max(target_areas, env)

    # エリアオブジェクトを作成
    area_objs = []
    for target_area in target_areas:
        area_obj = []
        for i in range(env.N):
            area_obj.append(Area(id_val=i, self_area=target_area[i], target_area=target_area[i]))
        area_objs.append(area_obj)

    # 目標面積を決定
    ret_area_objs = fastcopy(area_objs)
    for _, max_area, pattern in diff_max:
        now_area_objs = fastcopy(ret_area_objs)
        for d in range(target_dw):
            now_area_objs[d][pattern[d]].target_area = max_area
            now_area_objs[d][pattern[d]].need_first = True
        is_ok = True
        for d in range(target_dw):
            sum_area = sum(now_area_objs[d][i].target_area for i in range(env.N))
            if sum_area / AREA_MAX > AREA_TH:
                is_ok = False
                break
        if is_ok:
            ret_area_objs = fastcopy(now_area_objs)
        else:
            break

    try:
        ans = common_area_solver_core_aspect(ret_area_objs, env)
        return ans
    except Exception as e:
        debug_print(f"Err: common_area_solver_core_aspect {e}")
        ans = common_area_solver_core_opt(ret_area_objs, env)
        return ans

# %%
def fin_solver(target_areas: list[list[int]], env: Env):
    ret = []
    if len(target_areas) == 1:
        ret = one_day_solve(target_areas[0], env)
    else:
        try:
            ret = common_area_solver(target_areas, env)
        except Exception as e:
            debug_print(f"Err: common_area_solver {e}")
            for d in range(len(target_areas)):
                ret += one_day_solve(env.a[d], env)
    return ret

# %%
def solve(env: Env):
    best_cost = INF
    best_ans = None
    best_shift = None

    start_time = time.time()
    shift_list = list(set([1, 2] + [int(x) for x in np.linspace(3, env.D, 8)]))
    for shift in shift_list:
        ans = []
        for d in range(0, env.D, shift):
            ans += fin_solver(env.a[d:d+shift], env)
        cost = calc_cost(ans, env)

        if cost < best_cost:
            best_cost = cost
            best_ans = ans
            best_shift = shift
        if time.time() - start_time > 2.4:
            debug_print("over!!!")
            break

    debug_print(f"best:{best_cost} shift:{best_shift}/{env.D}")
    return best_ans

# %%
def main():
    for i in range(100):
        debug_print(f"----- {i}/100 -----")
        input_txt_path = Path(f"./in/{str(i).zfill(4)}.txt")
        output_txt_path = Path(f"./out/{str(i).zfill(4)}.txt")
        env = Env(input_txt_path)

        ans = solve(env)

        str_ans = []
        for d in range(env.D):
            for k in range(env.N):
                i0, j0, i1, j1 = ans[d][k]
                str_ans.append(f"{i0} {j0} {i1} {j1}")

        with open(output_txt_path, mode="w") as file:
            file.write("\n".join(str_ans))
main()
# Out:
# ----- 0/100 -----
# best:4637 shift:3/5
# ----- 1/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:349565 shift:21/25
# ----- 2/100 -----
# best:126547 shift:3/25
# ----- 3/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:114253 shift:3/11
# ----- 4/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# best:85530 shift:3/9
# ----- 5/100 -----
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:190046 shift:3/49
# ----- 6/100 -----
# best:23640 shift:3/5
# ----- 7/100 -----
# best:51999 shift:9/15
# ----- 8/100 -----
# best:115100 shift:6/26
# ----- 9/100 -----
# best:5186 shift:6/6
# ----- 10/100 -----
# best:75059 shift:3/28
# ----- 11/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:132967 shift:7/18
# ----- 12/100 -----
# best:108933 shift:8/39
# ----- 13/100 -----
# Err: common_area_solver_core_aspect failed check ans
# best:181835 shift:6/24
# ----- 14/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:221729 shift:3/23
# ----- 15/100 -----
# best:136737 shift:6/24
# ----- 16/100 -----
# Err: common_area_solver_core_aspect failed check ans
# best:333035 shift:38/44
# ----- 17/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:138552 shift:8/16
# ----- 18/100 -----
# over!!!
# best:79691 shift:11/34
# ----- 19/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:519572 shift:12/37
# ----- 20/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:181796 shift:9/18
# ----- 21/100 -----
# best:102245 shift:6/25
# ----- 22/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:89388 shift:6/28
# ----- 23/100 -----
# best:93024 shift:10/29
# ----- 24/100 -----
# Err: common_area_solver_core_aspect division by zero
# over!!!
# best:360424 shift:21/45
# ----- 25/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:180499 shift:16/27
# ----- 26/100 -----
# best:18345 shift:8/11
# ----- 27/100 -----
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# over!!!
# best:360360 shift:9/26
# ----- 28/100 -----
# Err: common_area_solver_core_aspect division by zero
# best:62670 shift:14/14
# ----- 29/100 -----
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:99442 shift:5/19
# ----- 30/100 -----
# best:79547 shift:3/20
# ----- 31/100 -----
# best:95510 shift:3/29
# ----- 32/100 -----
# best:24053 shift:7/9
# ----- 33/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:474362 shift:28/48
# ----- 34/100 -----
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect division by zero
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect division by zero
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:697498 shift:3/30
# ----- 35/100 -----
# best:14998 shift:5/10
# ----- 36/100 -----
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:383182 shift:33/46
# ----- 37/100 -----
# best:63429 shift:10/13
# ----- 38/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:153496 shift:5/13
# ----- 39/100 -----
# best:64089 shift:1/21
# ----- 40/100 -----
# best:71404 shift:2/47
# ----- 41/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:50637 shift:4/12
# ----- 42/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:154344 shift:6/29
# ----- 43/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:392595 shift:2/38
# ----- 44/100 -----
# best:79165 shift:8/21
# ----- 45/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:436343 shift:3/24
# ----- 46/100 -----
# Err: common_area_solver_core_aspect failed check ans
# best:104166 shift:9/12
# ----- 47/100 -----
# best:148470 shift:3/34
# ----- 48/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:153914 shift:15/24
# ----- 49/100 -----
# best:149042 shift:3/30
# ----- 50/100 -----
# best:52342 shift:4/16
# ----- 51/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:360801 shift:26/26
# ----- 52/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:125383 shift:9/15
# ----- 53/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# over!!!
# best:311611 shift:11/31
# ----- 54/100 -----
# best:32361 shift:4/13
# ----- 55/100 -----
# best:100001 shift:3/28
# ----- 56/100 -----
# over!!!
# best:117051 shift:3/17
# ----- 57/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:502108 shift:2/40
# ----- 58/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:331001 shift:18/25
# ----- 59/100 -----
# best:63029 shift:8/38
# ----- 60/100 -----
# best:1038984 shift:1/21
# ----- 61/100 -----
# best:407377 shift:2/50
# ----- 62/100 -----
# best:93870 shift:2/44
# ----- 63/100 -----
# over!!!
# best:96318 shift:6/27
# ----- 64/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:677287 shift:40/40
# ----- 65/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:127591 shift:7/11
# ----- 66/100 -----
# best:144931 shift:2/46
# ----- 67/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:110057 shift:1/7
# ----- 68/100 -----
# Err: common_area_solver_core_aspect failed check ans
# best:95762 shift:3/14
# ----- 69/100 -----
# best:74905 shift:3/32
# ----- 70/100 -----
# best:61558 shift:4/12
# ----- 71/100 -----
# best:55378 shift:6/12
# ----- 72/100 -----
# best:49326 shift:6/14
# ----- 73/100 -----
# best:31696 shift:2/14
# ----- 74/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:1000075 shift:1/46
# ----- 75/100 -----
# best:267037 shift:3/34
# ----- 76/100 -----
# Err: common_area_solver_core_aspect division by zero
# Err: one_day_solve_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:587881 shift:1/32
# ----- 77/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:278344 shift:26/26
# ----- 78/100 -----
# best:120235 shift:10/14
# ----- 79/100 -----
# Err: common_area_solver_core_aspect failed check ans
# best:264912 shift:2/34
# ----- 80/100 -----
# best:42283 shift:3/31
# ----- 81/100 -----
# best:41207 shift:3/27
# ----- 82/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:735358 shift:34/47
# ----- 83/100 -----
# best:39597 shift:5/13
# ----- 84/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# best:407522 shift:1/36
# ----- 85/100 -----
# Err: common_area_solver_core_aspect failed check ans
# best:163230 shift:8/23
# ----- 86/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:1094917 shift:1/48
# ----- 87/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:70727 shift:4/6
# ----- 88/100 -----
# best:42089 shift:11/18
# ----- 89/100 -----
# best:79871 shift:3/21
# ----- 90/100 -----
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect division by zero
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect division by zero
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: one_day_solve_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# best:454795 shift:2/18
# ----- 91/100 -----
# best:50256 shift:19/19
# ----- 92/100 -----
# Err: common_area_solver_core_aspect failed check ans
# best:166715 shift:3/24
# ----- 93/100 -----
# best:39539 shift:3/13
# ----- 94/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:840710 shift:34/47
# ----- 95/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# over!!!
# best:839861 shift:9/49
# ----- 96/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# best:93583 shift:7/13
# ----- 97/100 -----
# best:19797 shift:11/11
# ----- 98/100 -----
# best:142838 shift:5/22
# ----- 99/100 -----
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect failed check ans
# Err: common_area_solver_core_aspect division by zero
# over!!!
# best:354006 shift:23/38

# %%
# import time

# start_time = time.time()

# i = 94
# input_txt_path = Path(f"./in/{str(i).zfill(4)}.txt")
# output_txt_path = Path(f"./out/{str(i).zfill(4)}.txt")

# env = Env(input_txt_path)
# ans = solve(env)

# str_ans = []
# for d in range(env.D):
#     for k in range(env.N):
#         i0, j0, i1, j1 = ans[d][k]
#         str_ans.append(f"{i0} {j0} {i1} {j1}")

# with open(output_txt_path, mode="w") as file:
#     file.write("\n".join(str_ans))

# debug_print(time.time() - start_time)
