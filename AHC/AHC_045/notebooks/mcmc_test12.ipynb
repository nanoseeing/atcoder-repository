# %%
# =================================
# 設定
# =================================
IS_ONLINE_JUDGE = False

LIMIT_QUERY_CNT = None

DEBUG = False
DEBUG_QUERY = None
DEBUG_L = None

MAX_TIME = 1.25
FILE_NUM = 100

# =================================
# 初期化
# =================================
import time

GLOBAL_START_TIME = time.perf_counter()

import random

random.seed(1111)

if IS_ONLINE_JUDGE:
    DEBUG = False

# =================================
# Import
# =================================
import math
from collections import defaultdict

# =================================
# 共通
# =================================
if True:
    from importlib import reload

    import src.common as common

    reload(common)


from src.common import (
    Env,
    EnvOffline,
    calc_dist,
    construct_dist_matrix,
    construct_graph,
    construct_graph_from_edges,
    cut_graph,
    exponential_schedule,
    prim_k,
    sort_pair,
)


# =================================
# 汎用（main.py専用）
# =================================
def debug_print(*args, **kwargs):
    if IS_ONLINE_JUDGE:
        return
    print(*args, **kwargs)


def print_elapsed_time():
    debug_print(f"elapsed time: {(time.perf_counter() - GLOBAL_START_TIME) * 1000:.2f}msecs")

# %%
file_num = 7
input_file_path = f"../in/{file_num:04d}.txt"
output_file_path = f"../out/{file_num:04d}.txt"
env = EnvOffline(input_file_path, output_file_path)

# %%
def cost_formula(d1: int, d2: int) -> int:
    if d1 > d2:
        return d1 - d2
    else:
        return 0


def calc_init_cost(
    constrains: list[tuple[tuple[int, int], tuple[int, int]]],
    x: list[tuple[int, int]],
) -> tuple[list[int], int]:
    cost_list: list[int] = [0 for _ in range(len(constrains))]
    for ci in range(len(constrains)):
        cons = constrains[ci]
        (p1, p2), (q1, q2) = cons
        dist1 = calc_dist(x[p1], x[p2])
        dist2 = calc_dist(x[q1], x[q2])
        cost_list[ci] = cost_formula(dist1, dist2)
    total_cost = sum(cost_list)
    return cost_list, total_cost


def calc_cost(
    constrains: list[tuple[tuple[int, int], tuple[int, int]]],
    x_now: list[tuple[int, int]],
    x_update: dict[int, tuple[int, int]],
    cost_list: list[int],
    cost_now: int,
    vid_to_constid: dict[int, list[int]],
) -> tuple[dict[int, int], int]:
    new_cost = cost_now
    cost_update = dict()
    for v in x_update:
        for consid in vid_to_constid[v]:
            (p1, p2), (q1, q2) = constrains[consid]
            coord1 = x_update[p1] if p1 in x_update else x_now[p1]
            coord2 = x_update[p2] if p2 in x_update else x_now[p2]
            coord3 = x_update[q1] if q1 in x_update else x_now[q1]
            coord4 = x_update[q2] if q2 in x_update else x_now[q2]
            dist1 = calc_dist(coord1, coord2)
            dist2 = calc_dist(coord3, coord4)
            pre_cost = cost_list[consid]
            now_cost = cost_formula(dist1, dist2)
            new_cost += now_cost - pre_cost
            cost_update[consid] = now_cost
    return cost_update, new_cost


def neighbor(
    x: list[tuple[int, int]],
    target_v: list[int],
    rects: list[list[int]],
    now_mul_x: float,
    k: int = 1,
):
    vs: list[int] = random.sample(target_v, k=k)
    x_update: dict[int, tuple[int, int]] = dict()

    for v in vs:
        rnd = random.random()
        rand_coord = tuple()
        if rnd < 0.99:
            x1, x2, y1, y2 = rects[v]
            nx, ny = x[v]
            dx = x2 - x1
            dy = y2 - y1
            max_dx = max(int(dx * now_mul_x), 1)
            max_dy = max(int(dy * now_mul_x), 1)
            lim_l = max(x1, nx - max_dx)
            lim_r = min(x2, nx + max_dx)
            lim_u = max(y1, ny - max_dy)
            lim_d = min(y2, ny + max_dy)
            rand_coord = random.randint(lim_l, lim_r), random.randint(lim_u, lim_d)
        else:
            x1, x2, y1, y2 = rects[v]
            rand_coord = random.randint(x1, x2), random.randint(y1, y2)

        x_update[v] = rand_coord
        nx, ny = x[v]
        x1, x2, y1, y2 = rects[v]
        mul_x = abs(nx - rand_coord[0]) / (x2 - x1)

    return x_update, mul_x

# %%
def simulated_annealing(
    x0: list[tuple[int, int]],
    t0: float,
    t1: float,
    constrains: list[tuple[tuple[int, int], tuple[int, int]]],
    rectangles: list[tuple[int, int, int, int]],
    target_vs: list[int],
    vid_to_constid: dict[int, list[int]],
    max_time: float = 1.0,
    display: bool = False,
):
    x = x0.copy()
    x_best = x
    x_update = dict()

    cost_list, cost_current = calc_init_cost(constrains, x)
    cost_best = cost_current
    cost_update = dict()

    simulate_cnt = 0
    good_cnt = 0
    st = time.perf_counter()

    sum_mul_x = 0.0
    now_mul_x = 0.5
    while True:
        elapsed_time = time.perf_counter() - st
        if elapsed_time >= max_time:
            break
        temp = exponential_schedule(t0, t1, elapsed_time, max_time)

        x_update, mul_x = neighbor(x, target_vs, rectangles, now_mul_x)
        cost_update, cost_new = calc_cost(
            constrains=constrains,
            x_now=x,
            x_update=x_update,
            cost_list=cost_list,
            cost_now=cost_current,
            vid_to_constid=vid_to_constid,
        )

        delta_cost = cost_new - cost_current
        if delta_cost < 0:
            good_cnt += 1
            sum_mul_x += mul_x
        if delta_cost <= 0 or random.random() < math.exp(-delta_cost / temp):
            cost_current = cost_new
            for v in x_update:
                x[v] = x_update[v]
            for ci in cost_update:
                cost_list[ci] = cost_update[ci]
        if cost_current < cost_best:
            x_best = x
            cost_best = cost_current

        simulate_cnt += 1
        if display and simulate_cnt % 5000 == 0:
            debug_print(
                f"i: {simulate_cnt}, cost_now: {cost_current}, best_cost: {cost_best}, temp: {temp:.2f}, good_cnt: {good_cnt}/{simulate_cnt}"
            )
        if good_cnt > 0 and good_cnt % 100 == 0:
            now_mul_x = max(min(0.01, sum_mul_x / good_cnt), 0.5)
            sum_mul_x = 0.0
    return x_best, cost_best

# %%
all_graph: dict[int, list[tuple[int, int]]] = construct_graph({i: p for i, p in enumerate(env.cneter_points)})

max_d_list = []
for i, (l, r, t, b) in enumerate(env.rectangles):
    dx = r - l
    dy = b - t
    max_d_list.append((i, dx + dy))  # あえて辺の合計にする
max_d_list.sort(key=lambda x: x[1], reverse=True)

constrains = set()
random_vs = set()
for big_v, _ in max_d_list[: env.Q]:
    other_points = all_graph[big_v][: env.L * 2]
    other_points = [p for d, p in other_points]
    other_points = sorted(other_points, key=lambda x: max_d_list[x], reverse=True)
    other_points = other_points[: env.L - 1]

    tmp_random_vs = [big_v] + other_points

    edges = env.query(tmp_random_vs)
    graph = construct_graph_from_edges(edges, tmp_random_vs)

    for e in edges:
        group_vs1, group_vs2 = cut_graph(graph, e)
        for v1 in group_vs1:
            for v2 in group_vs2:
                sv1, sv2 = sort_pair((v1, v2))
                if e == (sv1, sv2):
                    continue
                constrains.add((e, (sv1, sv2)))
    random_vs.update(tmp_random_vs)
constrains = list(constrains)
random_vs = list(random_vs)

vid_to_constid = defaultdict(set)
for i, const in enumerate(constrains):
    (p1, p2), (q1, q2) = const
    vid_to_constid[p1].add(i)
    vid_to_constid[p2].add(i)
    vid_to_constid[q1].add(i)
    vid_to_constid[q2].add(i)

# %%
x_bests = []
for _ in range(20):
    x_best, cost_best = simulated_annealing(
        x0=env.cneter_points,
        t0=10.0,
        t1=1.0,
        constrains=constrains,
        rectangles=env.rectangles,
        target_vs=random_vs,
        vid_to_constid=vid_to_constid,
        max_time=5,
        display=True,
    )
    x_bests.append(x_best)
# Out:
# i: 5000, cost_now: 2186, best_cost: 2186, temp: 9.80, good_cnt: 526/5000
# i: 10000, cost_now: 390, best_cost: 330, temp: 9.63, good_cnt: 633/10000
# i: 15000, cost_now: 159, best_cost: 140, temp: 9.47, good_cnt: 715/15000
# i: 20000, cost_now: 185, best_cost: 117, temp: 9.31, good_cnt: 774/20000
# i: 25000, cost_now: 82, best_cost: 46, temp: 9.14, good_cnt: 845/25000
# i: 30000, cost_now: 209, best_cost: 29, temp: 9.00, good_cnt: 912/30000
# i: 35000, cost_now: 131, best_cost: 26, temp: 8.85, good_cnt: 972/35000
# i: 40000, cost_now: 110, best_cost: 26, temp: 8.69, good_cnt: 1049/40000
# i: 45000, cost_now: 102, best_cost: 26, temp: 8.55, good_cnt: 1118/45000
# i: 50000, cost_now: 94, best_cost: 20, temp: 8.41, good_cnt: 1189/50000
# i: 55000, cost_now: 90, best_cost: 20, temp: 8.28, good_cnt: 1248/55000
# i: 60000, cost_now: 58, best_cost: 20, temp: 8.13, good_cnt: 1323/60000
# i: 65000, cost_now: 103, best_cost: 20, temp: 7.99, good_cnt: 1394/65000
# i: 70000, cost_now: 145, best_cost: 20, temp: 7.86, good_cnt: 1456/70000
# i: 75000, cost_now: 66, best_cost: 20, temp: 7.71, good_cnt: 1524/75000
# i: 80000, cost_now: 216, best_cost: 19, temp: 7.59, good_cnt: 1599/80000
# i: 85000, cost_now: 64, best_cost: 12, temp: 7.47, good_cnt: 1671/85000
# i: 90000, cost_now: 11, best_cost: 7, temp: 7.35, good_cnt: 1725/90000
# i: 95000, cost_now: 58, best_cost: 7, temp: 7.23, good_cnt: 1776/95000
# i: 100000, cost_now: 111, best_cost: 7, temp: 7.11, good_cnt: 1830/100000
# i: 105000, cost_now: 116, best_cost: 7, temp: 6.99, good_cnt: 1893/105000
# i: 110000, cost_now: 26, best_cost: 7, temp: 6.86, good_cnt: 1950/110000
# i: 115000, cost_now: 40, best_cost: 0, temp: 6.75, good_cnt: 2012/115000
# i: 120000, cost_now: 14, best_cost: 0, temp: 6.64, good_cnt: 2060/120000
# i: 125000, cost_now: 72, best_cost: 0, temp: 6.54, good_cnt: 2112/125000
# i: 130000, cost_now: 91, best_cost: 0, temp: 6.43, good_cnt: 2157/130000
# i: 135000, cost_now: 66, best_cost: 0, temp: 6.32, good_cnt: 2219/135000
# i: 140000, cost_now: 60, best_cost: 0, temp: 6.23, good_cnt: 2272/140000
# i: 145000, cost_now: 60, best_cost: 0, temp: 6.13, good_cnt: 2331/145000
# i: 150000, cost_now: 16, best_cost: 0, temp: 6.03, good_cnt: 2382/150000
# i: 155000, cost_now: 29, best_cost: 0, temp: 5.93, good_cnt: 2425/155000
# i: 160000, cost_now: 45, best_cost: 0, temp: 5.84, good_cnt: 2469/160000
# i: 165000, cost_now: 44, best_cost: 0, temp: 5.75, good_cnt: 2516/165000
# i: 170000, cost_now: 11, best_cost: 0, temp: 5.65, good_cnt: 2561/170000
# i: 175000, cost_now: 61, best_cost: 0, temp: 5.56, good_cnt: 2606/175000
# i: 180000, cost_now: 75, best_cost: 0, temp: 5.48, good_cnt: 2651/180000
# i: 185000, cost_now: 8, best_cost: 0, temp: 5.38, good_cnt: 2702/185000
# i: 190000, cost_now: 41, best_cost: 0, temp: 5.29, good_cnt: 2734/190000
# i: 195000, cost_now: 34, best_cost: 0, temp: 5.21, good_cnt: 2789/195000
# i: 200000, cost_now: 33, best_cost: 0, temp: 5.12, good_cnt: 2820/200000
# i: 205000, cost_now: 33, best_cost: 0, temp: 5.03, good_cnt: 2855/205000
# i: 210000, cost_now: 37, best_cost: 0, temp: 4.95, good_cnt: 2894/210000
# i: 215000, cost_now: 57, best_cost: 0, temp: 4.86, good_cnt: 2938/215000
# i: 220000, cost_now: 40, best_cost: 0, temp: 4.78, good_cnt: 2974/220000
# i: 225000, cost_now: 18, best_cost: 0, temp: 4.70, good_cnt: 3016/225000
# i: 230000, cost_now: 9, best_cost: 0, temp: 4.62, good_cnt: 3049/230000
# i: 235000, cost_now: 3, best_cost: 0, temp: 4.54, good_cnt: 3085/235000
# i: 240000, cost_now: 47, best_cost: 0, temp: 4.47, good_cnt: 3121/240000
# i: 245000, cost_now: 10, best_cost: 0, temp: 4.39, good_cnt: 3153/245000
# i: 250000, cost_now: 11, best_cost: 0, temp: 4.32, good_cnt: 3185/250000
# i: 255000, cost_now: 8, best_cost: 0, temp: 4.25, good_cnt: 3217/255000
# i: 260000, cost_now: 23, best_cost: 0, temp: 4.19, good_cnt: 3250/260000
# i: 265000, cost_now: 21, best_cost: 0, temp: 4.12, good_cnt: 3279/265000
# i: 270000, cost_now: 34, best_cost: 0, temp: 4.05, good_cnt: 3299/270000
# i: 275000, cost_now: 27, best_cost: 0, temp: 3.98, good_cnt: 3333/275000
# i: 280000, cost_now: 4, best_cost: 0, temp: 3.92, good_cnt: 3363/280000
# i: 285000, cost_now: 9, best_cost: 0, temp: 3.85, good_cnt: 3381/285000
# i: 290000, cost_now: 13, best_cost: 0, temp: 3.79, good_cnt: 3403/290000
# i: 295000, cost_now: 5, best_cost: 0, temp: 3.73, good_cnt: 3431/295000
# i: 300000, cost_now: 6, best_cost: 0, temp: 3.66, good_cnt: 3463/300000
# i: 305000, cost_now: 13, best_cost: 0, temp: 3.61, good_cnt: 3487/305000
# i: 310000, cost_now: 20, best_cost: 0, temp: 3.55, good_cnt: 3512/310000
# i: 315000, cost_now: 17, best_cost: 0, temp: 3.50, good_cnt: 3532/315000
# i: 320000, cost_now: 26, best_cost: 0, temp: 3.45, good_cnt: 3557/320000
# i: 325000, cost_now: 42, best_cost: 0, temp: 3.39, good_cnt: 3589/325000
# i: 330000, cost_now: 21, best_cost: 0, temp: 3.34, good_cnt: 3614/330000
# i: 335000, cost_now: 13, best_cost: 0, temp: 3.28, good_cnt: 3638/335000
# i: 340000, cost_now: 13, best_cost: 0, temp: 3.23, good_cnt: 3657/340000
# i: 345000, cost_now: 4, best_cost: 0, temp: 3.18, good_cnt: 3682/345000
# i: 350000, cost_now: 6, best_cost: 0, temp: 3.12, good_cnt: 3710/350000
# i: 355000, cost_now: 23, best_cost: 0, temp: 3.07, good_cnt: 3723/355000
# i: 360000, cost_now: 4, best_cost: 0, temp: 3.02, good_cnt: 3745/360000
# i: 365000, cost_now: 4, best_cost: 0, temp: 2.97, good_cnt: 3763/365000
# i: 370000, cost_now: 11, best_cost: 0, temp: 2.92, good_cnt: 3781/370000
# i: 375000, cost_now: 14, best_cost: 0, temp: 2.87, good_cnt: 3799/375000
# i: 380000, cost_now: 2, best_cost: 0, temp: 2.83, good_cnt: 3817/380000
# i: 385000, cost_now: 10, best_cost: 0, temp: 2.79, good_cnt: 3831/385000
# i: 390000, cost_now: 8, best_cost: 0, temp: 2.75, good_cnt: 3845/390000
# i: 395000, cost_now: 13, best_cost: 0, temp: 2.71, good_cnt: 3867/395000
# i: 400000, cost_now: 1, best_cost: 0, temp: 2.67, good_cnt: 3884/400000
# i: 405000, cost_now: 3, best_cost: 0, temp: 2.63, good_cnt: 3899/405000
# i: 410000, cost_now: 0, best_cost: 0, temp: 2.58, good_cnt: 3923/410000
# i: 415000, cost_now: 13, best_cost: 0, temp: 2.55, good_cnt: 3938/415000
# i: 420000, cost_now: 6, best_cost: 0, temp: 2.51, good_cnt: 3961/420000
# i: 425000, cost_now: 11, best_cost: 0, temp: 2.47, good_cnt: 3983/425000
# i: 430000, cost_now: 0, best_cost: 0, temp: 2.44, good_cnt: 4005/430000
# i: 435000, cost_now: 7, best_cost: 0, temp: 2.40, good_cnt: 4022/435000
# i: 440000, cost_now: 1, best_cost: 0, temp: 2.36, good_cnt: 4033/440000
# i: 445000, cost_now: 13, best_cost: 0, temp: 2.33, good_cnt: 4054/445000
# i: 450000, cost_now: 1, best_cost: 0, temp: 2.30, good_cnt: 4067/450000
# i: 455000, cost_now: 5, best_cost: 0, temp: 2.26, good_cnt: 4076/455000
# i: 460000, cost_now: 3, best_cost: 0, temp: 2.23, good_cnt: 4089/460000
# i: 465000, cost_now: 14, best_cost: 0, temp: 2.20, good_cnt: 4104/465000
# i: 470000, cost_now: 3, best_cost: 0, temp: 2.16, good_cnt: 4120/470000
# i: 475000, cost_now: 4, best_cost: 0, temp: 2.13, good_cnt: 4129/475000
# i: 480000, cost_now: 5, best_cost: 0, temp: 2.10, good_cnt: 4141/480000
# i: 485000, cost_now: 0, best_cost: 0, temp: 2.07, good_cnt: 4154/485000
# i: 490000, cost_now: 4, best_cost: 0, temp: 2.04, good_cnt: 4167/490000
# i: 495000, cost_now: 6, best_cost: 0, temp: 2.01, good_cnt: 4174/495000
# i: 500000, cost_now: 10, best_cost: 0, temp: 1.98, good_cnt: 4186/500000
# i: 505000, cost_now: 5, best_cost: 0, temp: 1.94, good_cnt: 4200/505000
# i: 510000, cost_now: 1, best_cost: 0, temp: 1.91, good_cnt: 4212/510000
# i: 515000, cost_now: 1, best_cost: 0, temp: 1.88, good_cnt: 4221/515000
# i: 520000, cost_now: 6, best_cost: 0, temp: 1.85, good_cnt: 4225/520000
# i: 525000, cost_now: 2, best_cost: 0, temp: 1.83, good_cnt: 4236/525000
# i: 530000, cost_now: 0, best_cost: 0, temp: 1.80, good_cnt: 4247/530000
# i: 535000, cost_now: 1, best_cost: 0, temp: 1.77, good_cnt: 4251/535000
# i: 540000, cost_now: 0, best_cost: 0, temp: 1.74, good_cnt: 4261/540000
# i: 545000, cost_now: 0, best_cost: 0, temp: 1.71, good_cnt: 4277/545000
# i: 550000, cost_now: 0, best_cost: 0, temp: 1.68, good_cnt: 4286/550000
# i: 555000, cost_now: 0, best_cost: 0, temp: 1.66, good_cnt: 4295/555000
# i: 560000, cost_now: 6, best_cost: 0, temp: 1.63, good_cnt: 4304/560000
# i: 565000, cost_now: 2, best_cost: 0, temp: 1.60, good_cnt: 4315/565000
# i: 570000, cost_now: 1, best_cost: 0, temp: 1.57, good_cnt: 4327/570000
# i: 575000, cost_now: 3, best_cost: 0, temp: 1.55, good_cnt: 4339/575000
# i: 580000, cost_now: 1, best_cost: 0, temp: 1.52, good_cnt: 4345/580000
# i: 585000, cost_now: 0, best_cost: 0, temp: 1.49, good_cnt: 4354/585000
# i: 590000, cost_now: 1, best_cost: 0, temp: 1.47, good_cnt: 4364/590000
# i: 595000, cost_now: 1, best_cost: 0, temp: 1.44, good_cnt: 4377/595000
# i: 600000, cost_now: 0, best_cost: 0, temp: 1.42, good_cnt: 4389/600000
# i: 605000, cost_now: 3, best_cost: 0, temp: 1.40, good_cnt: 4392/605000
# i: 610000, cost_now: 1, best_cost: 0, temp: 1.38, good_cnt: 4401/610000
# i: 615000, cost_now: 6, best_cost: 0, temp: 1.35, good_cnt: 4412/615000
# i: 620000, cost_now: 3, best_cost: 0, temp: 1.33, good_cnt: 4423/620000
# i: 625000, cost_now: 0, best_cost: 0, temp: 1.31, good_cnt: 4428/625000
# i: 630000, cost_now: 0, best_cost: 0, temp: 1.29, good_cnt: 4435/630000
# i: 635000, cost_now: 3, best_cost: 0, temp: 1.27, good_cnt: 4438/635000
# i: 640000, cost_now: 11, best_cost: 0, temp: 1.25, good_cnt: 4445/640000
# i: 645000, cost_now: 0, best_cost: 0, temp: 1.23, good_cnt: 4452/645000
# i: 650000, cost_now: 0, best_cost: 0, temp: 1.21, good_cnt: 4460/650000
# i: 655000, cost_now: 1, best_cost: 0, temp: 1.20, good_cnt: 4470/655000
# i: 660000, cost_now: 4, best_cost: 0, temp: 1.18, good_cnt: 4476/660000
# i: 665000, cost_now: 3, best_cost: 0, temp: 1.16, good_cnt: 4484/665000
# i: 670000, cost_now: 1, best_cost: 0, temp: 1.14, good_cnt: 4489/670000
# i: 675000, cost_now: 1, best_cost: 0, temp: 1.12, good_cnt: 4497/675000
# i: 680000, cost_now: 2, best_cost: 0, temp: 1.11, good_cnt: 4506/680000
# i: 685000, cost_now: 1, best_cost: 0, temp: 1.09, good_cnt: 4509/685000
# i: 690000, cost_now: 0, best_cost: 0, temp: 1.07, good_cnt: 4519/690000
# i: 695000, cost_now: 2, best_cost: 0, temp: 1.06, good_cnt: 4525/695000
# i: 700000, cost_now: 0, best_cost: 0, temp: 1.04, good_cnt: 4530/700000
# i: 705000, cost_now: 0, best_cost: 0, temp: 1.03, good_cnt: 4539/705000
# i: 710000, cost_now: 0, best_cost: 0, temp: 1.01, good_cnt: 4539/710000
# i: 5000, cost_now: 316, best_cost: 287, temp: 9.85, good_cnt: 510/5000
# i: 10000, cost_now: 169, best_cost: 69, temp: 9.71, good_cnt: 591/10000
# i: 15000, cost_now: 140, best_cost: 69, temp: 9.57, good_cnt: 665/15000
# i: 20000, cost_now: 97, best_cost: 60, temp: 9.42, good_cnt: 752/20000
# i: 25000, cost_now: 53, best_cost: 43, temp: 9.27, good_cnt: 833/25000
# i: 30000, cost_now: 72, best_cost: 27, temp: 9.13, good_cnt: 912/30000
# i: 35000, cost_now: 161, best_cost: 27, temp: 8.99, good_cnt: 980/35000
# i: 40000, cost_now: 67, best_cost: 7, temp: 8.86, good_cnt: 1044/40000
# i: 45000, cost_now: 148, best_cost: 7, temp: 8.73, good_cnt: 1120/45000
# i: 50000, cost_now: 60, best_cost: 7, temp: 8.59, good_cnt: 1178/50000
# i: 55000, cost_now: 64, best_cost: 7, temp: 8.46, good_cnt: 1248/55000
# i: 60000, cost_now: 79, best_cost: 7, temp: 8.32, good_cnt: 1321/60000
# i: 65000, cost_now: 65, best_cost: 7, temp: 8.20, good_cnt: 1386/65000
# i: 70000, cost_now: 52, best_cost: 7, temp: 8.08, good_cnt: 1452/70000
# i: 75000, cost_now: 63, best_cost: 7, temp: 7.96, good_cnt: 1506/75000
# i: 80000, cost_now: 30, best_cost: 0, temp: 7.84, good_cnt: 1560/80000
# i: 85000, cost_now: 79, best_cost: 0, temp: 7.72, good_cnt: 1620/85000
# i: 90000, cost_now: 66, best_cost: 0, temp: 7.60, good_cnt: 1678/90000
# i: 95000, cost_now: 74, best_cost: 0, temp: 7.48, good_cnt: 1753/95000
# i: 100000, cost_now: 63, best_cost: 0, temp: 7.36, good_cnt: 1808/100000
# i: 105000, cost_now: 89, best_cost: 0, temp: 7.25, good_cnt: 1856/105000
# i: 110000, cost_now: 50, best_cost: 0, temp: 7.14, good_cnt: 1918/110000
# i: 115000, cost_now: 31, best_cost: 0, temp: 7.03, good_cnt: 1977/115000
# i: 120000, cost_now: 72, best_cost: 0, temp: 6.93, good_cnt: 2030/120000
# i: 125000, cost_now: 58, best_cost: 0, temp: 6.82, good_cnt: 2089/125000
# i: 130000, cost_now: 61, best_cost: 0, temp: 6.71, good_cnt: 2136/130000
# i: 135000, cost_now: 36, best_cost: 0, temp: 6.61, good_cnt: 2182/135000
# i: 140000, cost_now: 8, best_cost: 0, temp: 6.51, good_cnt: 2228/140000
# i: 145000, cost_now: 38, best_cost: 0, temp: 6.42, good_cnt: 2273/145000
# i: 150000, cost_now: 18, best_cost: 0, temp: 6.32, good_cnt: 2320/150000
# i: 155000, cost_now: 47, best_cost: 0, temp: 6.23, good_cnt: 2373/155000
# i: 160000, cost_now: 60, best_cost: 0, temp: 6.13, good_cnt: 2428/160000
# i: 165000, cost_now: 46, best_cost: 0, temp: 6.02, good_cnt: 2479/165000
# i: 170000, cost_now: 1, best_cost: 0, temp: 5.92, good_cnt: 2530/170000
# i: 175000, cost_now: 11, best_cost: 0, temp: 5.82, good_cnt: 2576/175000
# i: 180000, cost_now: 25, best_cost: 0, temp: 5.73, good_cnt: 2619/180000
# i: 185000, cost_now: 38, best_cost: 0, temp: 5.64, good_cnt: 2660/185000
# i: 190000, cost_now: 31, best_cost: 0, temp: 5.56, good_cnt: 2702/190000
# i: 195000, cost_now: 46, best_cost: 0, temp: 5.47, good_cnt: 2739/195000
# i: 200000, cost_now: 22, best_cost: 0, temp: 5.39, good_cnt: 2775/200000
# i: 205000, cost_now: 49, best_cost: 0, temp: 5.32, good_cnt: 2809/205000
# i: 210000, cost_now: 40, best_cost: 0, temp: 5.24, good_cnt: 2847/210000
# i: 215000, cost_now: 10, best_cost: 0, temp: 5.16, good_cnt: 2887/215000
# i: 220000, cost_now: 40, best_cost: 0, temp: 5.07, good_cnt: 2931/220000
# i: 225000, cost_now: 20, best_cost: 0, temp: 4.99, good_cnt: 2974/225000
# i: 230000, cost_now: 30, best_cost: 0, temp: 4.91, good_cnt: 3010/230000
# i: 235000, cost_now: 25, best_cost: 0, temp: 4.83, good_cnt: 3058/235000
# i: 240000, cost_now: 28, best_cost: 0, temp: 4.76, good_cnt: 3096/240000
# i: 245000, cost_now: 12, best_cost: 0, temp: 4.69, good_cnt: 3131/245000
# i: 250000, cost_now: 18, best_cost: 0, temp: 4.63, good_cnt: 3167/250000
# i: 255000, cost_now: 29, best_cost: 0, temp: 4.56, good_cnt: 3200/255000
# i: 260000, cost_now: 27, best_cost: 0, temp: 4.49, good_cnt: 3234/260000
# i: 265000, cost_now: 10, best_cost: 0, temp: 4.42, good_cnt: 3265/265000
# i: 270000, cost_now: 21, best_cost: 0, temp: 4.35, good_cnt: 3296/270000
# i: 275000, cost_now: 26, best_cost: 0, temp: 4.29, good_cnt: 3334/275000
# i: 280000, cost_now: 36, best_cost: 0, temp: 4.23, good_cnt: 3373/280000
# i: 285000, cost_now: 24, best_cost: 0, temp: 4.16, good_cnt: 3409/285000
# i: 290000, cost_now: 32, best_cost: 0, temp: 4.10, good_cnt: 3448/290000
# i: 295000, cost_now: 39, best_cost: 0, temp: 4.04, good_cnt: 3475/295000
# i: 300000, cost_now: 20, best_cost: 0, temp: 3.97, good_cnt: 3522/300000
# i: 305000, cost_now: 12, best_cost: 0, temp: 3.91, good_cnt: 3555/305000
# i: 310000, cost_now: 10, best_cost: 0, temp: 3.85, good_cnt: 3594/310000
# i: 315000, cost_now: 16, best_cost: 0, temp: 3.79, good_cnt: 3617/315000
# i: 320000, cost_now: 9, best_cost: 0, temp: 3.73, good_cnt: 3641/320000
# i: 325000, cost_now: 7, best_cost: 0, temp: 3.67, good_cnt: 3667/325000
# i: 330000, cost_now: 15, best_cost: 0, temp: 3.61, good_cnt: 3687/330000
# i: 335000, cost_now: 9, best_cost: 0, temp: 3.56, good_cnt: 3712/335000
# i: 340000, cost_now: 7, best_cost: 0, temp: 3.50, good_cnt: 3736/340000
# i: 345000, cost_now: 52, best_cost: 0, temp: 3.45, good_cnt: 3762/345000
# i: 350000, cost_now: 5, best_cost: 0, temp: 3.40, good_cnt: 3795/350000
# i: 355000, cost_now: 12, best_cost: 0, temp: 3.35, good_cnt: 3821/355000
# i: 360000, cost_now: 6, best_cost: 0, temp: 3.30, good_cnt: 3840/360000
# i: 365000, cost_now: 5, best_cost: 0, temp: 3.25, good_cnt: 3864/365000
# i: 370000, cost_now: 2, best_cost: 0, temp: 3.20, good_cnt: 3879/370000
# i: 375000, cost_now: 11, best_cost: 0, temp: 3.15, good_cnt: 3892/375000
# i: 380000, cost_now: 0, best_cost: 0, temp: 3.10, good_cnt: 3922/380000
# i: 385000, cost_now: 7, best_cost: 0, temp: 3.06, good_cnt: 3940/385000
# i: 390000, cost_now: 34, best_cost: 0, temp: 3.01, good_cnt: 3966/390000
# i: 395000, cost_now: 14, best_cost: 0, temp: 2.97, good_cnt: 3982/395000
# i: 400000, cost_now: 12, best_cost: 0, temp: 2.92, good_cnt: 3997/400000
# i: 405000, cost_now: 9, best_cost: 0, temp: 2.87, good_cnt: 4011/405000
# i: 410000, cost_now: 3, best_cost: 0, temp: 2.82, good_cnt: 4027/410000
# i: 415000, cost_now: 22, best_cost: 0, temp: 2.78, good_cnt: 4046/415000
# i: 420000, cost_now: 7, best_cost: 0, temp: 2.73, good_cnt: 4061/420000
# i: 425000, cost_now: 11, best_cost: 0, temp: 2.69, good_cnt: 4078/425000
# i: 430000, cost_now: 17, best_cost: 0, temp: 2.64, good_cnt: 4102/430000
# i: 435000, cost_now: 24, best_cost: 0, temp: 2.60, good_cnt: 4125/435000
# i: 440000, cost_now: 5, best_cost: 0, temp: 2.56, good_cnt: 4150/440000
# i: 445000, cost_now: 6, best_cost: 0, temp: 2.52, good_cnt: 4163/445000
# i: 450000, cost_now: 14, best_cost: 0, temp: 2.48, good_cnt: 4179/450000
# i: 455000, cost_now: 1, best_cost: 0, temp: 2.44, good_cnt: 4202/455000
# i: 460000, cost_now: 7, best_cost: 0, temp: 2.40, good_cnt: 4217/460000
# i: 465000, cost_now: 1, best_cost: 0, temp: 2.37, good_cnt: 4231/465000
# i: 470000, cost_now: 0, best_cost: 0, temp: 2.33, good_cnt: 4248/470000
# i: 475000, cost_now: 1, best_cost: 0, temp: 2.30, good_cnt: 4258/475000
# i: 480000, cost_now: 1, best_cost: 0, temp: 2.26, good_cnt: 4271/480000
# i: 485000, cost_now: 10, best_cost: 0, temp: 2.22, good_cnt: 4292/485000
# i: 490000, cost_now: 2, best_cost: 0, temp: 2.19, good_cnt: 4315/490000
# i: 495000, cost_now: 3, best_cost: 0, temp: 2.15, good_cnt: 4323/495000
# i: 500000, cost_now: 23, best_cost: 0, temp: 2.11, good_cnt: 4340/500000
# i: 505000, cost_now: 8, best_cost: 0, temp: 2.08, good_cnt: 4360/505000
# i: 510000, cost_now: 5, best_cost: 0, temp: 2.05, good_cnt: 4380/510000
# i: 515000, cost_now: 2, best_cost: 0, temp: 2.01, good_cnt: 4396/515000
# i: 520000, cost_now: 4, best_cost: 0, temp: 1.98, good_cnt: 4420/520000
# i: 525000, cost_now: 2, best_cost: 0, temp: 1.95, good_cnt: 4441/525000
# i: 530000, cost_now: 5, best_cost: 0, temp: 1.92, good_cnt: 4454/530000
# i: 535000, cost_now: 8, best_cost: 0, temp: 1.89, good_cnt: 4468/535000
# i: 540000, cost_now: 1, best_cost: 0, temp: 1.86, good_cnt: 4483/540000
# i: 545000, cost_now: 2, best_cost: 0, temp: 1.83, good_cnt: 4489/545000
# i: 550000, cost_now: 2, best_cost: 0, temp: 1.80, good_cnt: 4500/550000
# i: 555000, cost_now: 3, best_cost: 0, temp: 1.77, good_cnt: 4513/555000
# i: 560000, cost_now: 2, best_cost: 0, temp: 1.74, good_cnt: 4521/560000
# i: 565000, cost_now: 6, best_cost: 0, temp: 1.72, good_cnt: 4536/565000
# i: 570000, cost_now: 2, best_cost: 0, temp: 1.69, good_cnt: 4552/570000
# i: 575000, cost_now: 2, best_cost: 0, temp: 1.67, good_cnt: 4559/575000
# i: 580000, cost_now: 0, best_cost: 0, temp: 1.64, good_cnt: 4570/580000
# i: 585000, cost_now: 5, best_cost: 0, temp: 1.61, good_cnt: 4576/585000
# i: 590000, cost_now: 2, best_cost: 0, temp: 1.59, good_cnt: 4588/590000
# i: 595000, cost_now: 0, best_cost: 0, temp: 1.56, good_cnt: 4600/595000
# i: 600000, cost_now: 4, best_cost: 0, temp: 1.54, good_cnt: 4605/600000
# i: 605000, cost_now: 0, best_cost: 0, temp: 1.51, good_cnt: 4616/605000
# i: 610000, cost_now: 4, best_cost: 0, temp: 1.49, good_cnt: 4629/610000
# i: 615000, cost_now: 2, best_cost: 0, temp: 1.47, good_cnt: 4640/615000
# i: 620000, cost_now: 0, best_cost: 0, temp: 1.44, good_cnt: 4648/620000
# i: 625000, cost_now: 5, best_cost: 0, temp: 1.42, good_cnt: 4656/625000
# i: 630000, cost_now: 2, best_cost: 0, temp: 1.40, good_cnt: 4662/630000
# i: 635000, cost_now: 0, best_cost: 0, temp: 1.38, good_cnt: 4672/635000
# i: 640000, cost_now: 0, best_cost: 0, temp: 1.36, good_cnt: 4679/640000
# i: 645000, cost_now: 0, best_cost: 0, temp: 1.34, good_cnt: 4690/645000
# i: 650000, cost_now: 0, best_cost: 0, temp: 1.32, good_cnt: 4695/650000
# i: 655000, cost_now: 0, best_cost: 0, temp: 1.30, good_cnt: 4704/655000
# i: 660000, cost_now: 5, best_cost: 0, temp: 1.28, good_cnt: 4709/660000
# i: 665000, cost_now: 3, best_cost: 0, temp: 1.26, good_cnt: 4714/665000
# i: 670000, cost_now: 3, best_cost: 0, temp: 1.23, good_cnt: 4722/670000
# i: 675000, cost_now: 0, best_cost: 0, temp: 1.22, good_cnt: 4731/675000
# i: 680000, cost_now: 0, best_cost: 0, temp: 1.20, good_cnt: 4736/680000
# i: 685000, cost_now: 3, best_cost: 0, temp: 1.18, good_cnt: 4739/685000
# i: 690000, cost_now: 1, best_cost: 0, temp: 1.16, good_cnt: 4748/690000
# i: 695000, cost_now: 0, best_cost: 0, temp: 1.14, good_cnt: 4755/695000
# i: 700000, cost_now: 0, best_cost: 0, temp: 1.12, good_cnt: 4758/700000
# i: 705000, cost_now: 1, best_cost: 0, temp: 1.11, good_cnt: 4762/705000
# i: 710000, cost_now: 0, best_cost: 0, temp: 1.09, good_cnt: 4768/710000
# i: 715000, cost_now: 2, best_cost: 0, temp: 1.07, good_cnt: 4777/715000
# i: 720000, cost_now: 0, best_cost: 0, temp: 1.06, good_cnt: 4786/720000
# i: 725000, cost_now: 1, best_cost: 0, temp: 1.04, good_cnt: 4792/725000
# i: 730000, cost_now: 1, best_cost: 0, temp: 1.02, good_cnt: 4797/730000
# i: 735000, cost_now: 1, best_cost: 0, temp: 1.01, good_cnt: 4802/735000
# i: 5000, cost_now: 813, best_cost: 778, temp: 9.85, good_cnt: 454/5000
# i: 10000, cost_now: 210, best_cost: 175, temp: 9.70, good_cnt: 540/10000
# i: 15000, cost_now: 167, best_cost: 124, temp: 9.55, good_cnt: 634/15000
# i: 20000, cost_now: 135, best_cost: 48, temp: 9.39, good_cnt: 725/20000
# i: 25000, cost_now: 145, best_cost: 18, temp: 9.24, good_cnt: 810/25000
# i: 30000, cost_now: 32, best_cost: 16, temp: 9.09, good_cnt: 895/30000
# i: 35000, cost_now: 57, best_cost: 16, temp: 8.94, good_cnt: 971/35000
# i: 40000, cost_now: 76, best_cost: 16, temp: 8.79, good_cnt: 1032/40000
# i: 45000, cost_now: 79, best_cost: 10, temp: 8.64, good_cnt: 1100/45000
# i: 50000, cost_now: 57, best_cost: 10, temp: 8.49, good_cnt: 1176/50000
# i: 55000, cost_now: 56, best_cost: 10, temp: 8.35, good_cnt: 1236/55000
# i: 60000, cost_now: 65, best_cost: 10, temp: 8.22, good_cnt: 1292/60000
# i: 65000, cost_now: 78, best_cost: 0, temp: 8.08, good_cnt: 1341/65000
# i: 70000, cost_now: 64, best_cost: 0, temp: 7.95, good_cnt: 1398/70000
# i: 75000, cost_now: 52, best_cost: 0, temp: 7.80, good_cnt: 1460/75000
# i: 80000, cost_now: 65, best_cost: 0, temp: 7.67, good_cnt: 1501/80000
# i: 85000, cost_now: 24, best_cost: 0, temp: 7.54, good_cnt: 1545/85000
# i: 90000, cost_now: 72, best_cost: 0, temp: 7.42, good_cnt: 1587/90000
# i: 95000, cost_now: 69, best_cost: 0, temp: 7.30, good_cnt: 1630/95000
# i: 100000, cost_now: 16, best_cost: 0, temp: 7.19, good_cnt: 1686/100000
# i: 105000, cost_now: 53, best_cost: 0, temp: 7.08, good_cnt: 1729/105000
# i: 110000, cost_now: 64, best_cost: 0, temp: 6.97, good_cnt: 1774/110000
# i: 115000, cost_now: 21, best_cost: 0, temp: 6.86, good_cnt: 1830/115000
# i: 120000, cost_now: 134, best_cost: 0, temp: 6.76, good_cnt: 1877/120000
# i: 125000, cost_now: 49, best_cost: 0, temp: 6.65, good_cnt: 1926/125000
# i: 130000, cost_now: 7, best_cost: 0, temp: 6.55, good_cnt: 1981/130000
# i: 135000, cost_now: 51, best_cost: 0, temp: 6.45, good_cnt: 2029/135000
# i: 140000, cost_now: 58, best_cost: 0, temp: 6.35, good_cnt: 2092/140000
# i: 145000, cost_now: 47, best_cost: 0, temp: 6.25, good_cnt: 2141/145000
# i: 150000, cost_now: 48, best_cost: 0, temp: 6.15, good_cnt: 2199/150000
# i: 155000, cost_now: 28, best_cost: 0, temp: 6.04, good_cnt: 2255/155000
# i: 160000, cost_now: 58, best_cost: 0, temp: 5.95, good_cnt: 2316/160000
# i: 165000, cost_now: 40, best_cost: 0, temp: 5.86, good_cnt: 2362/165000
# i: 170000, cost_now: 97, best_cost: 0, temp: 5.77, good_cnt: 2402/170000
# i: 175000, cost_now: 76, best_cost: 0, temp: 5.68, good_cnt: 2456/175000
# i: 180000, cost_now: 35, best_cost: 0, temp: 5.60, good_cnt: 2506/180000
# i: 185000, cost_now: 13, best_cost: 0, temp: 5.51, good_cnt: 2548/185000
# i: 190000, cost_now: 40, best_cost: 0, temp: 5.43, good_cnt: 2584/190000
# i: 195000, cost_now: 30, best_cost: 0, temp: 5.34, good_cnt: 2623/195000
# i: 200000, cost_now: 19, best_cost: 0, temp: 5.25, good_cnt: 2660/200000
# i: 205000, cost_now: 7, best_cost: 0, temp: 5.18, good_cnt: 2702/205000
# i: 210000, cost_now: 22, best_cost: 0, temp: 5.10, good_cnt: 2738/210000
# i: 215000, cost_now: 20, best_cost: 0, temp: 5.02, good_cnt: 2774/215000
# i: 220000, cost_now: 28, best_cost: 0, temp: 4.94, good_cnt: 2813/220000
# i: 225000, cost_now: 32, best_cost: 0, temp: 4.87, good_cnt: 2847/225000
# i: 230000, cost_now: 34, best_cost: 0, temp: 4.79, good_cnt: 2889/230000
# i: 235000, cost_now: 15, best_cost: 0, temp: 4.72, good_cnt: 2922/235000
# i: 240000, cost_now: 14, best_cost: 0, temp: 4.65, good_cnt: 2952/240000
# i: 245000, cost_now: 30, best_cost: 0, temp: 4.58, good_cnt: 2986/245000
# i: 250000, cost_now: 32, best_cost: 0, temp: 4.51, good_cnt: 3020/250000
# i: 255000, cost_now: 13, best_cost: 0, temp: 4.45, good_cnt: 3058/255000
# i: 260000, cost_now: 18, best_cost: 0, temp: 4.38, good_cnt: 3089/260000
# i: 265000, cost_now: 25, best_cost: 0, temp: 4.30, good_cnt: 3120/265000
# i: 270000, cost_now: 17, best_cost: 0, temp: 4.23, good_cnt: 3154/270000
# i: 275000, cost_now: 21, best_cost: 0, temp: 4.17, good_cnt: 3183/275000
# i: 280000, cost_now: 4, best_cost: 0, temp: 4.10, good_cnt: 3202/280000
# i: 285000, cost_now: 65, best_cost: 0, temp: 4.04, good_cnt: 3229/285000
# i: 290000, cost_now: 22, best_cost: 0, temp: 3.98, good_cnt: 3252/290000
# i: 295000, cost_now: 34, best_cost: 0, temp: 3.91, good_cnt: 3283/295000
# i: 300000, cost_now: 2, best_cost: 0, temp: 3.82, good_cnt: 3311/300000
# i: 305000, cost_now: 42, best_cost: 0, temp: 3.76, good_cnt: 3336/305000
# i: 310000, cost_now: 18, best_cost: 0, temp: 3.70, good_cnt: 3371/310000
# i: 315000, cost_now: 1, best_cost: 0, temp: 3.64, good_cnt: 3405/315000
# i: 320000, cost_now: 11, best_cost: 0, temp: 3.58, good_cnt: 3423/320000
# i: 325000, cost_now: 4, best_cost: 0, temp: 3.53, good_cnt: 3449/325000
# i: 330000, cost_now: 7, best_cost: 0, temp: 3.47, good_cnt: 3472/330000
# i: 335000, cost_now: 18, best_cost: 0, temp: 3.42, good_cnt: 3496/335000
# i: 340000, cost_now: 10, best_cost: 0, temp: 3.37, good_cnt: 3525/340000
# i: 345000, cost_now: 12, best_cost: 0, temp: 3.31, good_cnt: 3549/345000
# i: 350000, cost_now: 0, best_cost: 0, temp: 3.27, good_cnt: 3575/350000
# i: 355000, cost_now: 9, best_cost: 0, temp: 3.22, good_cnt: 3591/355000
# i: 360000, cost_now: 12, best_cost: 0, temp: 3.17, good_cnt: 3610/360000
# i: 365000, cost_now: 15, best_cost: 0, temp: 3.12, good_cnt: 3637/365000
# i: 370000, cost_now: 22, best_cost: 0, temp: 3.07, good_cnt: 3656/370000
# i: 375000, cost_now: 18, best_cost: 0, temp: 3.02, good_cnt: 3680/375000
# i: 380000, cost_now: 2, best_cost: 0, temp: 2.97, good_cnt: 3707/380000
# i: 385000, cost_now: 18, best_cost: 0, temp: 2.92, good_cnt: 3723/385000
# i: 390000, cost_now: 6, best_cost: 0, temp: 2.87, good_cnt: 3747/390000
# i: 395000, cost_now: 6, best_cost: 0, temp: 2.82, good_cnt: 3770/395000
# i: 400000, cost_now: 8, best_cost: 0, temp: 2.78, good_cnt: 3792/400000
# i: 405000, cost_now: 6, best_cost: 0, temp: 2.74, good_cnt: 3805/405000
# i: 410000, cost_now: 28, best_cost: 0, temp: 2.70, good_cnt: 3826/410000
# i: 415000, cost_now: 0, best_cost: 0, temp: 2.66, good_cnt: 3849/415000
# i: 420000, cost_now: 7, best_cost: 0, temp: 2.62, good_cnt: 3860/420000
# i: 425000, cost_now: 0, best_cost: 0, temp: 2.58, good_cnt: 3880/425000
# i: 430000, cost_now: 5, best_cost: 0, temp: 2.54, good_cnt: 3895/430000
# i: 435000, cost_now: 2, best_cost: 0, temp: 2.50, good_cnt: 3916/435000
# i: 440000, cost_now: 5, best_cost: 0, temp: 2.46, good_cnt: 3926/440000
# i: 445000, cost_now: 0, best_cost: 0, temp: 2.42, good_cnt: 3938/445000
# i: 450000, cost_now: 7, best_cost: 0, temp: 2.39, good_cnt: 3945/450000
# i: 455000, cost_now: 8, best_cost: 0, temp: 2.35, good_cnt: 3963/455000
# i: 460000, cost_now: 4, best_cost: 0, temp: 2.31, good_cnt: 3978/460000
# i: 465000, cost_now: 2, best_cost: 0, temp: 2.28, good_cnt: 3996/465000
# i: 470000, cost_now: 6, best_cost: 0, temp: 2.24, good_cnt: 4009/470000
# i: 475000, cost_now: 0, best_cost: 0, temp: 2.21, good_cnt: 4026/475000
# i: 480000, cost_now: 2, best_cost: 0, temp: 2.17, good_cnt: 4034/480000
# i: 485000, cost_now: 5, best_cost: 0, temp: 2.14, good_cnt: 4049/485000
# i: 490000, cost_now: 1, best_cost: 0, temp: 2.11, good_cnt: 4061/490000
# i: 495000, cost_now: 14, best_cost: 0, temp: 2.08, good_cnt: 4075/495000
# i: 500000, cost_now: 3, best_cost: 0, temp: 2.04, good_cnt: 4091/500000
# i: 505000, cost_now: 11, best_cost: 0, temp: 2.01, good_cnt: 4101/505000
# i: 510000, cost_now: 0, best_cost: 0, temp: 1.98, good_cnt: 4118/510000
# i: 515000, cost_now: 4, best_cost: 0, temp: 1.95, good_cnt: 4130/515000
# i: 520000, cost_now: 14, best_cost: 0, temp: 1.93, good_cnt: 4144/520000
# i: 525000, cost_now: 1, best_cost: 0, temp: 1.90, good_cnt: 4156/525000
# i: 530000, cost_now: 1, best_cost: 0, temp: 1.87, good_cnt: 4167/530000
# i: 535000, cost_now: 5, best_cost: 0, temp: 1.84, good_cnt: 4174/535000
# i: 540000, cost_now: 3, best_cost: 0, temp: 1.81, good_cnt: 4186/540000
# i: 545000, cost_now: 3, best_cost: 0, temp: 1.78, good_cnt: 4194/545000
# i: 550000, cost_now: 1, best_cost: 0, temp: 1.76, good_cnt: 4204/550000
# i: 555000, cost_now: 0, best_cost: 0, temp: 1.73, good_cnt: 4214/555000
# i: 560000, cost_now: 2, best_cost: 0, temp: 1.70, good_cnt: 4219/560000
# i: 565000, cost_now: 0, best_cost: 0, temp: 1.68, good_cnt: 4230/565000
# i: 570000, cost_now: 6, best_cost: 0, temp: 1.65, good_cnt: 4239/570000
# i: 575000, cost_now: 0, best_cost: 0, temp: 1.62, good_cnt: 4249/575000
# i: 580000, cost_now: 4, best_cost: 0, temp: 1.60, good_cnt: 4260/580000
# i: 585000, cost_now: 2, best_cost: 0, temp: 1.57, good_cnt: 4270/585000
# i: 590000, cost_now: 0, best_cost: 0, temp: 1.55, good_cnt: 4279/590000
# i: 595000, cost_now: 1, best_cost: 0, temp: 1.53, good_cnt: 4285/595000
# i: 600000, cost_now: 1, best_cost: 0, temp: 1.50, good_cnt: 4290/600000
# i: 605000, cost_now: 0, best_cost: 0, temp: 1.48, good_cnt: 4297/605000
# i: 610000, cost_now: 0, best_cost: 0, temp: 1.46, good_cnt: 4307/610000
# i: 615000, cost_now: 0, best_cost: 0, temp: 1.43, good_cnt: 4313/615000
# i: 620000, cost_now: 1, best_cost: 0, temp: 1.41, good_cnt: 4318/620000
# i: 625000, cost_now: 0, best_cost: 0, temp: 1.39, good_cnt: 4327/625000
# i: 630000, cost_now: 0, best_cost: 0, temp: 1.37, good_cnt: 4339/630000
# i: 635000, cost_now: 2, best_cost: 0, temp: 1.35, good_cnt: 4349/635000
# i: 640000, cost_now: 0, best_cost: 0, temp: 1.33, good_cnt: 4358/640000
# i: 645000, cost_now: 1, best_cost: 0, temp: 1.31, good_cnt: 4366/645000
# i: 650000, cost_now: 5, best_cost: 0, temp: 1.29, good_cnt: 4371/650000
# i: 655000, cost_now: 0, best_cost: 0, temp: 1.27, good_cnt: 4377/655000
# i: 660000, cost_now: 1, best_cost: 0, temp: 1.25, good_cnt: 4382/660000
# i: 665000, cost_now: 0, best_cost: 0, temp: 1.23, good_cnt: 4392/665000
# i: 670000, cost_now: 3, best_cost: 0, temp: 1.21, good_cnt: 4397/670000
# i: 675000, cost_now: 0, best_cost: 0, temp: 1.19, good_cnt: 4410/675000
# i: 680000, cost_now: 0, best_cost: 0, temp: 1.17, good_cnt: 4412/680000
# i: 685000, cost_now: 0, best_cost: 0, temp: 1.15, good_cnt: 4413/685000
# i: 690000, cost_now: 0, best_cost: 0, temp: 1.13, good_cnt: 4415/690000
# i: 695000, cost_now: 4, best_cost: 0, temp: 1.11, good_cnt: 4420/695000
# i: 700000, cost_now: 0, best_cost: 0, temp: 1.10, good_cnt: 4430/700000
# i: 705000, cost_now: 1, best_cost: 0, temp: 1.08, good_cnt: 4433/705000
# i: 710000, cost_now: 0, best_cost: 0, temp: 1.06, good_cnt: 4441/710000
# i: 715000, cost_now: 1, best_cost: 0, temp: 1.04, good_cnt: 4443/715000
# i: 720000, cost_now: 2, best_cost: 0, temp: 1.03, good_cnt: 4449/720000
# i: 725000, cost_now: 5, best_cost: 0, temp: 1.01, good_cnt: 4452/725000
# i: 5000, cost_now: 787, best_cost: 769, temp: 9.85, good_cnt: 491/5000
# i: 10000, cost_now: 400, best_cost: 334, temp: 9.70, good_cnt: 588/10000
# i: 15000, cost_now: 168, best_cost: 74, temp: 9.55, good_cnt: 687/15000
# i: 20000, cost_now: 89, best_cost: 49, temp: 9.40, good_cnt: 761/20000
# i: 25000, cost_now: 69, best_cost: 20, temp: 9.25, good_cnt: 831/25000
# i: 30000, cost_now: 72, best_cost: 20, temp: 9.11, good_cnt: 894/30000
# i: 35000, cost_now: 152, best_cost: 20, temp: 8.97, good_cnt: 953/35000
# i: 40000, cost_now: 45, best_cost: 19, temp: 8.84, good_cnt: 1020/40000
# i: 45000, cost_now: 41, best_cost: 19, temp: 8.71, good_cnt: 1098/45000
# i: 50000, cost_now: 88, best_cost: 13, temp: 8.57, good_cnt: 1175/50000
# i: 55000, cost_now: 116, best_cost: 9, temp: 8.44, good_cnt: 1235/55000
# i: 60000, cost_now: 106, best_cost: 9, temp: 8.32, good_cnt: 1296/60000
# i: 65000, cost_now: 27, best_cost: 1, temp: 8.20, good_cnt: 1347/65000
# i: 70000, cost_now: 56, best_cost: 1, temp: 8.08, good_cnt: 1408/70000
# i: 75000, cost_now: 65, best_cost: 1, temp: 7.96, good_cnt: 1474/75000
# i: 80000, cost_now: 39, best_cost: 1, temp: 7.84, good_cnt: 1543/80000
# i: 85000, cost_now: 34, best_cost: 1, temp: 7.73, good_cnt: 1611/85000
# i: 90000, cost_now: 9, best_cost: 1, temp: 7.61, good_cnt: 1671/90000
# i: 95000, cost_now: 44, best_cost: 1, temp: 7.49, good_cnt: 1711/95000
# i: 100000, cost_now: 38, best_cost: 1, temp: 7.39, good_cnt: 1773/100000
# i: 105000, cost_now: 48, best_cost: 1, temp: 7.27, good_cnt: 1835/105000
# i: 110000, cost_now: 58, best_cost: 1, temp: 7.16, good_cnt: 1883/110000
# i: 115000, cost_now: 78, best_cost: 1, temp: 7.05, good_cnt: 1955/115000
# i: 120000, cost_now: 47, best_cost: 1, temp: 6.95, good_cnt: 2001/120000
# i: 125000, cost_now: 56, best_cost: 1, temp: 6.83, good_cnt: 2055/125000
# i: 130000, cost_now: 48, best_cost: 1, temp: 6.73, good_cnt: 2103/130000
# i: 135000, cost_now: 43, best_cost: 1, temp: 6.63, good_cnt: 2159/135000
# i: 140000, cost_now: 88, best_cost: 1, temp: 6.53, good_cnt: 2227/140000
# i: 145000, cost_now: 40, best_cost: 1, temp: 6.43, good_cnt: 2279/145000
# i: 150000, cost_now: 92, best_cost: 1, temp: 6.32, good_cnt: 2334/150000
# i: 155000, cost_now: 33, best_cost: 1, temp: 6.22, good_cnt: 2384/155000
# i: 160000, cost_now: 43, best_cost: 1, temp: 6.12, good_cnt: 2423/160000
# i: 165000, cost_now: 48, best_cost: 1, temp: 6.02, good_cnt: 2483/165000
# i: 170000, cost_now: 70, best_cost: 1, temp: 5.93, good_cnt: 2539/170000
# i: 175000, cost_now: 8, best_cost: 1, temp: 5.85, good_cnt: 2575/175000
# i: 180000, cost_now: 81, best_cost: 1, temp: 5.76, good_cnt: 2609/180000
# i: 185000, cost_now: 13, best_cost: 1, temp: 5.68, good_cnt: 2650/185000
# i: 190000, cost_now: 3, best_cost: 1, temp: 5.59, good_cnt: 2690/190000
# i: 195000, cost_now: 19, best_cost: 1, temp: 5.50, good_cnt: 2731/195000
# i: 200000, cost_now: 23, best_cost: 1, temp: 5.42, good_cnt: 2774/200000
# i: 205000, cost_now: 35, best_cost: 0, temp: 5.33, good_cnt: 2812/205000
# i: 210000, cost_now: 13, best_cost: 0, temp: 5.26, good_cnt: 2849/210000
# i: 215000, cost_now: 35, best_cost: 0, temp: 5.18, good_cnt: 2893/215000
# i: 220000, cost_now: 47, best_cost: 0, temp: 5.10, good_cnt: 2928/220000
# i: 225000, cost_now: 13, best_cost: 0, temp: 5.02, good_cnt: 2969/225000
# i: 230000, cost_now: 41, best_cost: 0, temp: 4.94, good_cnt: 3016/230000
# i: 235000, cost_now: 15, best_cost: 0, temp: 4.86, good_cnt: 3058/235000
# i: 240000, cost_now: 18, best_cost: 0, temp: 4.79, good_cnt: 3080/240000
# i: 245000, cost_now: 9, best_cost: 0, temp: 4.72, good_cnt: 3111/245000
# i: 250000, cost_now: 46, best_cost: 0, temp: 4.65, good_cnt: 3144/250000
# i: 255000, cost_now: 22, best_cost: 0, temp: 4.58, good_cnt: 3179/255000
# i: 260000, cost_now: 11, best_cost: 0, temp: 4.50, good_cnt: 3216/260000
# i: 265000, cost_now: 26, best_cost: 0, temp: 4.43, good_cnt: 3245/265000
# i: 270000, cost_now: 34, best_cost: 0, temp: 4.36, good_cnt: 3272/270000
# i: 275000, cost_now: 62, best_cost: 0, temp: 4.30, good_cnt: 3317/275000
# i: 280000, cost_now: 27, best_cost: 0, temp: 4.24, good_cnt: 3350/280000
# i: 285000, cost_now: 31, best_cost: 0, temp: 4.18, good_cnt: 3372/285000
# i: 290000, cost_now: 24, best_cost: 0, temp: 4.11, good_cnt: 3405/290000
# i: 295000, cost_now: 14, best_cost: 0, temp: 4.05, good_cnt: 3441/295000
# i: 300000, cost_now: 42, best_cost: 0, temp: 3.98, good_cnt: 3459/300000
# i: 305000, cost_now: 8, best_cost: 0, temp: 3.91, good_cnt: 3492/305000
# i: 310000, cost_now: 11, best_cost: 0, temp: 3.85, good_cnt: 3519/310000
# i: 315000, cost_now: 9, best_cost: 0, temp: 3.79, good_cnt: 3544/315000
# i: 320000, cost_now: 9, best_cost: 0, temp: 3.73, good_cnt: 3567/320000
# i: 325000, cost_now: 34, best_cost: 0, temp: 3.67, good_cnt: 3596/325000
# i: 330000, cost_now: 13, best_cost: 0, temp: 3.62, good_cnt: 3621/330000
# i: 335000, cost_now: 23, best_cost: 0, temp: 3.56, good_cnt: 3656/335000
# i: 340000, cost_now: 6, best_cost: 0, temp: 3.50, good_cnt: 3678/340000
# i: 345000, cost_now: 21, best_cost: 0, temp: 3.45, good_cnt: 3708/345000
# i: 350000, cost_now: 2, best_cost: 0, temp: 3.40, good_cnt: 3729/350000
# i: 355000, cost_now: 12, best_cost: 0, temp: 3.35, good_cnt: 3745/355000
# i: 360000, cost_now: 0, best_cost: 0, temp: 3.30, good_cnt: 3767/360000
# i: 365000, cost_now: 7, best_cost: 0, temp: 3.24, good_cnt: 3791/365000
# i: 370000, cost_now: 7, best_cost: 0, temp: 3.20, good_cnt: 3811/370000
# i: 375000, cost_now: 2, best_cost: 0, temp: 3.15, good_cnt: 3835/375000
# i: 380000, cost_now: 4, best_cost: 0, temp: 3.10, good_cnt: 3857/380000
# i: 385000, cost_now: 21, best_cost: 0, temp: 3.05, good_cnt: 3877/385000
# i: 390000, cost_now: 3, best_cost: 0, temp: 3.01, good_cnt: 3897/390000
# i: 395000, cost_now: 9, best_cost: 0, temp: 2.96, good_cnt: 3915/395000
# i: 400000, cost_now: 3, best_cost: 0, temp: 2.91, good_cnt: 3935/400000
# i: 405000, cost_now: 12, best_cost: 0, temp: 2.87, good_cnt: 3954/405000
# i: 410000, cost_now: 0, best_cost: 0, temp: 2.83, good_cnt: 3978/410000
# i: 415000, cost_now: 8, best_cost: 0, temp: 2.78, good_cnt: 3991/415000
# i: 420000, cost_now: 5, best_cost: 0, temp: 2.74, good_cnt: 4014/420000
# i: 425000, cost_now: 6, best_cost: 0, temp: 2.70, good_cnt: 4037/425000
# i: 430000, cost_now: 12, best_cost: 0, temp: 2.66, good_cnt: 4048/430000
# i: 435000, cost_now: 5, best_cost: 0, temp: 2.62, good_cnt: 4069/435000
# i: 440000, cost_now: 2, best_cost: 0, temp: 2.58, good_cnt: 4086/440000
# i: 445000, cost_now: 6, best_cost: 0, temp: 2.54, good_cnt: 4111/445000
# i: 450000, cost_now: 18, best_cost: 0, temp: 2.50, good_cnt: 4134/450000
# i: 455000, cost_now: 15, best_cost: 0, temp: 2.46, good_cnt: 4161/455000
# i: 460000, cost_now: 8, best_cost: 0, temp: 2.42, good_cnt: 4181/460000
# i: 465000, cost_now: 12, best_cost: 0, temp: 2.39, good_cnt: 4193/465000
# i: 470000, cost_now: 7, best_cost: 0, temp: 2.35, good_cnt: 4214/470000
# i: 475000, cost_now: 6, best_cost: 0, temp: 2.31, good_cnt: 4229/475000
# i: 480000, cost_now: 0, best_cost: 0, temp: 2.28, good_cnt: 4255/480000
# i: 485000, cost_now: 0, best_cost: 0, temp: 2.24, good_cnt: 4270/485000
# i: 490000, cost_now: 9, best_cost: 0, temp: 2.21, good_cnt: 4280/490000
# i: 495000, cost_now: 4, best_cost: 0, temp: 2.18, good_cnt: 4305/495000
# i: 500000, cost_now: 2, best_cost: 0, temp: 2.14, good_cnt: 4317/500000
# i: 505000, cost_now: 4, best_cost: 0, temp: 2.11, good_cnt: 4334/505000
# i: 510000, cost_now: 2, best_cost: 0, temp: 2.08, good_cnt: 4347/510000
# i: 515000, cost_now: 0, best_cost: 0, temp: 2.05, good_cnt: 4364/515000
# i: 520000, cost_now: 1, best_cost: 0, temp: 2.02, good_cnt: 4375/520000
# i: 525000, cost_now: 0, best_cost: 0, temp: 1.99, good_cnt: 4391/525000
# i: 530000, cost_now: 2, best_cost: 0, temp: 1.96, good_cnt: 4402/530000
# i: 535000, cost_now: 7, best_cost: 0, temp: 1.93, good_cnt: 4414/535000
# i: 540000, cost_now: 5, best_cost: 0, temp: 1.90, good_cnt: 4430/540000
# i: 545000, cost_now: 2, best_cost: 0, temp: 1.86, good_cnt: 4442/545000
# i: 550000, cost_now: 0, best_cost: 0, temp: 1.83, good_cnt: 4452/550000
# i: 555000, cost_now: 1, best_cost: 0, temp: 1.80, good_cnt: 4460/555000
# i: 560000, cost_now: 0, best_cost: 0, temp: 1.77, good_cnt: 4470/560000
# i: 565000, cost_now: 5, best_cost: 0, temp: 1.75, good_cnt: 4480/565000
# i: 570000, cost_now: 9, best_cost: 0, temp: 1.72, good_cnt: 4493/570000
# i: 575000, cost_now: 3, best_cost: 0, temp: 1.69, good_cnt: 4511/575000
# i: 580000, cost_now: 0, best_cost: 0, temp: 1.66, good_cnt: 4524/580000
# i: 585000, cost_now: 3, best_cost: 0, temp: 1.64, good_cnt: 4533/585000
# i: 590000, cost_now: 1, best_cost: 0, temp: 1.61, good_cnt: 4540/590000
# i: 595000, cost_now: 9, best_cost: 0, temp: 1.59, good_cnt: 4546/595000
# i: 600000, cost_now: 2, best_cost: 0, temp: 1.57, good_cnt: 4556/600000
# i: 605000, cost_now: 0, best_cost: 0, temp: 1.54, good_cnt: 4565/605000
# i: 610000, cost_now: 0, best_cost: 0, temp: 1.52, good_cnt: 4572/610000
# i: 615000, cost_now: 2, best_cost: 0, temp: 1.49, good_cnt: 4582/615000
# i: 620000, cost_now: 3, best_cost: 0, temp: 1.47, good_cnt: 4591/620000
# i: 625000, cost_now: 3, best_cost: 0, temp: 1.44, good_cnt: 4602/625000
# i: 630000, cost_now: 2, best_cost: 0, temp: 1.42, good_cnt: 4614/630000
# i: 635000, cost_now: 4, best_cost: 0, temp: 1.40, good_cnt: 4618/635000
# i: 640000, cost_now: 2, best_cost: 0, temp: 1.37, good_cnt: 4624/640000
# i: 645000, cost_now: 2, best_cost: 0, temp: 1.35, good_cnt: 4636/645000
# i: 650000, cost_now: 0, best_cost: 0, temp: 1.33, good_cnt: 4644/650000
# i: 655000, cost_now: 0, best_cost: 0, temp: 1.31, good_cnt: 4646/655000
# i: 660000, cost_now: 0, best_cost: 0, temp: 1.29, good_cnt: 4650/660000
# i: 665000, cost_now: 5, best_cost: 0, temp: 1.27, good_cnt: 4660/665000
# i: 670000, cost_now: 3, best_cost: 0, temp: 1.25, good_cnt: 4667/670000
# i: 675000, cost_now: 2, best_cost: 0, temp: 1.23, good_cnt: 4673/675000
# i: 680000, cost_now: 3, best_cost: 0, temp: 1.22, good_cnt: 4678/680000
# i: 685000, cost_now: 3, best_cost: 0, temp: 1.20, good_cnt: 4684/685000
# i: 690000, cost_now: 0, best_cost: 0, temp: 1.18, good_cnt: 4690/690000
# i: 695000, cost_now: 1, best_cost: 0, temp: 1.16, good_cnt: 4696/695000
# i: 700000, cost_now: 2, best_cost: 0, temp: 1.15, good_cnt: 4705/700000
# i: 705000, cost_now: 3, best_cost: 0, temp: 1.13, good_cnt: 4710/705000
# i: 710000, cost_now: 0, best_cost: 0, temp: 1.11, good_cnt: 4714/710000
# i: 715000, cost_now: 8, best_cost: 0, temp: 1.09, good_cnt: 4722/715000
# i: 720000, cost_now: 1, best_cost: 0, temp: 1.08, good_cnt: 4728/720000
# i: 725000, cost_now: 0, best_cost: 0, temp: 1.06, good_cnt: 4734/725000
# i: 730000, cost_now: 1, best_cost: 0, temp: 1.05, good_cnt: 4738/730000
# i: 735000, cost_now: 0, best_cost: 0, temp: 1.03, good_cnt: 4746/735000
# i: 740000, cost_now: 0, best_cost: 0, temp: 1.02, good_cnt: 4751/740000
# i: 745000, cost_now: 0, best_cost: 0, temp: 1.00, good_cnt: 4754/745000
# i: 5000, cost_now: 994, best_cost: 955, temp: 9.85, good_cnt: 490/5000
# i: 10000, cost_now: 321, best_cost: 286, temp: 9.71, good_cnt: 596/10000
# i: 15000, cost_now: 202, best_cost: 144, temp: 9.56, good_cnt: 667/15000
# i: 20000, cost_now: 152, best_cost: 116, temp: 9.43, good_cnt: 744/20000
# i: 25000, cost_now: 54, best_cost: 49, temp: 9.30, good_cnt: 829/25000
# i: 30000, cost_now: 176, best_cost: 19, temp: 9.17, good_cnt: 900/30000
# i: 35000, cost_now: 43, best_cost: 19, temp: 9.03, good_cnt: 987/35000
# i: 40000, cost_now: 197, best_cost: 19, temp: 8.89, good_cnt: 1054/40000
# i: 45000, cost_now: 65, best_cost: 19, temp: 8.76, good_cnt: 1133/45000
# i: 50000, cost_now: 64, best_cost: 19, temp: 8.64, good_cnt: 1193/50000
# i: 55000, cost_now: 77, best_cost: 19, temp: 8.51, good_cnt: 1258/55000
# i: 60000, cost_now: 87, best_cost: 12, temp: 8.38, good_cnt: 1322/60000
# i: 65000, cost_now: 91, best_cost: 12, temp: 8.26, good_cnt: 1383/65000
# i: 70000, cost_now: 145, best_cost: 12, temp: 8.14, good_cnt: 1439/70000
# i: 75000, cost_now: 72, best_cost: 12, temp: 7.98, good_cnt: 1510/75000
# i: 80000, cost_now: 111, best_cost: 12, temp: 7.82, good_cnt: 1575/80000
# i: 85000, cost_now: 96, best_cost: 12, temp: 7.70, good_cnt: 1639/85000
# i: 90000, cost_now: 116, best_cost: 12, temp: 7.58, good_cnt: 1694/90000
# i: 95000, cost_now: 42, best_cost: 12, temp: 7.46, good_cnt: 1764/95000
# i: 100000, cost_now: 64, best_cost: 12, temp: 7.35, good_cnt: 1819/100000
# i: 105000, cost_now: 65, best_cost: 12, temp: 7.24, good_cnt: 1882/105000
# i: 110000, cost_now: 112, best_cost: 12, temp: 7.12, good_cnt: 1947/110000
# i: 115000, cost_now: 107, best_cost: 7, temp: 6.99, good_cnt: 2005/115000
# i: 120000, cost_now: 63, best_cost: 7, temp: 6.88, good_cnt: 2083/120000
# i: 125000, cost_now: 40, best_cost: 7, temp: 6.77, good_cnt: 2148/125000
# i: 130000, cost_now: 16, best_cost: 2, temp: 6.67, good_cnt: 2199/130000
# i: 135000, cost_now: 36, best_cost: 2, temp: 6.57, good_cnt: 2259/135000
# i: 140000, cost_now: 27, best_cost: 2, temp: 6.48, good_cnt: 2302/140000
# i: 145000, cost_now: 19, best_cost: 2, temp: 6.39, good_cnt: 2349/145000
# i: 150000, cost_now: 38, best_cost: 2, temp: 6.29, good_cnt: 2393/150000
# i: 155000, cost_now: 54, best_cost: 2, temp: 6.20, good_cnt: 2459/155000
# i: 160000, cost_now: 42, best_cost: 2, temp: 6.11, good_cnt: 2506/160000
# i: 165000, cost_now: 31, best_cost: 2, temp: 6.03, good_cnt: 2552/165000
# i: 170000, cost_now: 2, best_cost: 1, temp: 5.94, good_cnt: 2587/170000
# i: 175000, cost_now: 3, best_cost: 1, temp: 5.85, good_cnt: 2620/175000
# i: 180000, cost_now: 12, best_cost: 0, temp: 5.76, good_cnt: 2666/180000
# i: 185000, cost_now: 19, best_cost: 0, temp: 5.67, good_cnt: 2702/185000
# i: 190000, cost_now: 38, best_cost: 0, temp: 5.59, good_cnt: 2738/190000
# i: 195000, cost_now: 29, best_cost: 0, temp: 5.50, good_cnt: 2788/195000
# i: 200000, cost_now: 32, best_cost: 0, temp: 5.42, good_cnt: 2834/200000
# i: 205000, cost_now: 63, best_cost: 0, temp: 5.33, good_cnt: 2883/205000
# i: 210000, cost_now: 10, best_cost: 0, temp: 5.24, good_cnt: 2931/210000
# i: 215000, cost_now: 14, best_cost: 0, temp: 5.16, good_cnt: 2974/215000
# i: 220000, cost_now: 38, best_cost: 0, temp: 5.07, good_cnt: 3006/220000
# i: 225000, cost_now: 61, best_cost: 0, temp: 5.00, good_cnt: 3053/225000
# i: 230000, cost_now: 38, best_cost: 0, temp: 4.93, good_cnt: 3093/230000
# i: 235000, cost_now: 14, best_cost: 0, temp: 4.86, good_cnt: 3120/235000
# i: 240000, cost_now: 30, best_cost: 0, temp: 4.78, good_cnt: 3152/240000
# i: 245000, cost_now: 26, best_cost: 0, temp: 4.71, good_cnt: 3188/245000
# i: 250000, cost_now: 6, best_cost: 0, temp: 4.65, good_cnt: 3239/250000
# i: 255000, cost_now: 28, best_cost: 0, temp: 4.57, good_cnt: 3268/255000
# i: 260000, cost_now: 12, best_cost: 0, temp: 4.51, good_cnt: 3289/260000
# i: 265000, cost_now: 10, best_cost: 0, temp: 4.45, good_cnt: 3324/265000
# i: 270000, cost_now: 5, best_cost: 0, temp: 4.38, good_cnt: 3353/270000
# i: 275000, cost_now: 10, best_cost: 0, temp: 4.32, good_cnt: 3381/275000
# i: 280000, cost_now: 21, best_cost: 0, temp: 4.26, good_cnt: 3424/280000
# i: 285000, cost_now: 57, best_cost: 0, temp: 4.19, good_cnt: 3463/285000
# i: 290000, cost_now: 3, best_cost: 0, temp: 4.13, good_cnt: 3489/290000
# i: 295000, cost_now: 31, best_cost: 0, temp: 4.07, good_cnt: 3513/295000
# i: 300000, cost_now: 44, best_cost: 0, temp: 4.01, good_cnt: 3542/300000
# i: 305000, cost_now: 10, best_cost: 0, temp: 3.95, good_cnt: 3565/305000
# i: 310000, cost_now: 13, best_cost: 0, temp: 3.89, good_cnt: 3592/310000
# i: 315000, cost_now: 19, best_cost: 0, temp: 3.84, good_cnt: 3625/315000
# i: 320000, cost_now: 12, best_cost: 0, temp: 3.78, good_cnt: 3646/320000
# i: 325000, cost_now: 8, best_cost: 0, temp: 3.72, good_cnt: 3681/325000
# i: 330000, cost_now: 13, best_cost: 0, temp: 3.67, good_cnt: 3700/330000
# i: 335000, cost_now: 16, best_cost: 0, temp: 3.62, good_cnt: 3730/335000
# i: 340000, cost_now: 12, best_cost: 0, temp: 3.57, good_cnt: 3760/340000
# i: 345000, cost_now: 10, best_cost: 0, temp: 3.52, good_cnt: 3783/345000
# i: 350000, cost_now: 25, best_cost: 0, temp: 3.47, good_cnt: 3809/350000
# i: 355000, cost_now: 20, best_cost: 0, temp: 3.42, good_cnt: 3826/355000
# i: 360000, cost_now: 6, best_cost: 0, temp: 3.37, good_cnt: 3852/360000
# i: 365000, cost_now: 7, best_cost: 0, temp: 3.32, good_cnt: 3878/365000
# i: 370000, cost_now: 13, best_cost: 0, temp: 3.27, good_cnt: 3906/370000
# i: 375000, cost_now: 18, best_cost: 0, temp: 3.22, good_cnt: 3928/375000
# i: 380000, cost_now: 35, best_cost: 0, temp: 3.18, good_cnt: 3952/380000
# i: 385000, cost_now: 18, best_cost: 0, temp: 3.13, good_cnt: 3976/385000
# i: 390000, cost_now: 2, best_cost: 0, temp: 3.09, good_cnt: 3992/390000
# i: 395000, cost_now: 0, best_cost: 0, temp: 3.04, good_cnt: 4012/395000
# i: 400000, cost_now: 8, best_cost: 0, temp: 3.00, good_cnt: 4029/400000
# ...
# i: 385000, cost_now: 24, best_cost: 0, temp: 3.05, good_cnt: 3848/385000
# i: 390000, cost_now: 4, best_cost: 0, temp: 3.00, good_cnt: 3869/390000
# i: 395000, cost_now: 5, best_cost: 0, temp: 2.95, good_cnt: 3879/395000
# i: 400000, cost_now: 4, best_cost: 0, temp: 2.90, good_cnt: 3899/400000
# i: 405000, cost_now: 2, best_cost: 0, temp: 2.86, good_cnt: 3918/405000
# i: 410000, cost_now: 2, best_cost: 0, temp: 2.81, good_cnt: 3935/410000
# i: 415000, cost_now: 15, best_cost: 0, temp: 2.77, good_cnt: 3956/415000
# i: 420000, cost_now: 13, best_cost: 0, temp: 2.73, good_cnt: 3976/420000
# i: 425000, cost_now: 16, best_cost: 0, temp: 2.68, good_cnt: 3995/425000
# i: 430000, cost_now: 0, best_cost: 0, temp: 2.64, good_cnt: 4008/430000
# i: 435000, cost_now: 4, best_cost: 0, temp: 2.60, good_cnt: 4029/435000
# i: 440000, cost_now: 15, best_cost: 0, temp: 2.56, good_cnt: 4042/440000
# i: 445000, cost_now: 9, best_cost: 0, temp: 2.52, good_cnt: 4059/445000
# i: 450000, cost_now: 6, best_cost: 0, temp: 2.48, good_cnt: 4069/450000
# i: 455000, cost_now: 3, best_cost: 0, temp: 2.44, good_cnt: 4076/455000
# i: 460000, cost_now: 1, best_cost: 0, temp: 2.40, good_cnt: 4100/460000
# i: 465000, cost_now: 13, best_cost: 0, temp: 2.36, good_cnt: 4117/465000
# i: 470000, cost_now: 1, best_cost: 0, temp: 2.32, good_cnt: 4138/470000
# i: 475000, cost_now: 3, best_cost: 0, temp: 2.29, good_cnt: 4155/475000
# i: 480000, cost_now: 7, best_cost: 0, temp: 2.26, good_cnt: 4168/480000
# i: 485000, cost_now: 5, best_cost: 0, temp: 2.22, good_cnt: 4180/485000
# i: 490000, cost_now: 1, best_cost: 0, temp: 2.19, good_cnt: 4196/490000
# i: 495000, cost_now: 3, best_cost: 0, temp: 2.16, good_cnt: 4206/495000
# i: 500000, cost_now: 2, best_cost: 0, temp: 2.13, good_cnt: 4217/500000
# i: 505000, cost_now: 6, best_cost: 0, temp: 2.10, good_cnt: 4227/505000
# i: 510000, cost_now: 9, best_cost: 0, temp: 2.07, good_cnt: 4246/510000
# i: 515000, cost_now: 6, best_cost: 0, temp: 2.04, good_cnt: 4255/515000
# i: 520000, cost_now: 1, best_cost: 0, temp: 2.01, good_cnt: 4269/520000
# i: 525000, cost_now: 3, best_cost: 0, temp: 1.98, good_cnt: 4282/525000
# i: 530000, cost_now: 0, best_cost: 0, temp: 1.95, good_cnt: 4301/530000
# i: 535000, cost_now: 4, best_cost: 0, temp: 1.92, good_cnt: 4314/535000
# i: 540000, cost_now: 2, best_cost: 0, temp: 1.89, good_cnt: 4332/540000
# i: 545000, cost_now: 1, best_cost: 0, temp: 1.86, good_cnt: 4339/545000
# i: 550000, cost_now: 2, best_cost: 0, temp: 1.84, good_cnt: 4352/550000
# i: 555000, cost_now: 18, best_cost: 0, temp: 1.81, good_cnt: 4363/555000
# i: 560000, cost_now: 2, best_cost: 0, temp: 1.79, good_cnt: 4373/560000
# i: 565000, cost_now: 11, best_cost: 0, temp: 1.76, good_cnt: 4380/565000
# i: 570000, cost_now: 4, best_cost: 0, temp: 1.73, good_cnt: 4389/570000
# i: 575000, cost_now: 4, best_cost: 0, temp: 1.71, good_cnt: 4399/575000
# i: 580000, cost_now: 6, best_cost: 0, temp: 1.68, good_cnt: 4412/580000
# i: 585000, cost_now: 5, best_cost: 0, temp: 1.66, good_cnt: 4424/585000
# i: 590000, cost_now: 1, best_cost: 0, temp: 1.64, good_cnt: 4434/590000
# i: 595000, cost_now: 5, best_cost: 0, temp: 1.61, good_cnt: 4443/595000
# i: 600000, cost_now: 1, best_cost: 0, temp: 1.59, good_cnt: 4455/600000
# i: 605000, cost_now: 9, best_cost: 0, temp: 1.56, good_cnt: 4461/605000
# i: 610000, cost_now: 2, best_cost: 0, temp: 1.54, good_cnt: 4476/610000
# i: 615000, cost_now: 0, best_cost: 0, temp: 1.52, good_cnt: 4486/615000
# i: 620000, cost_now: 0, best_cost: 0, temp: 1.50, good_cnt: 4490/620000
# i: 625000, cost_now: 2, best_cost: 0, temp: 1.47, good_cnt: 4497/625000
# i: 630000, cost_now: 0, best_cost: 0, temp: 1.45, good_cnt: 4503/630000
# i: 635000, cost_now: 4, best_cost: 0, temp: 1.43, good_cnt: 4514/635000
# i: 640000, cost_now: 0, best_cost: 0, temp: 1.41, good_cnt: 4525/640000
# i: 645000, cost_now: 0, best_cost: 0, temp: 1.39, good_cnt: 4533/645000
# i: 650000, cost_now: 0, best_cost: 0, temp: 1.36, good_cnt: 4541/650000
# i: 655000, cost_now: 4, best_cost: 0, temp: 1.34, good_cnt: 4551/655000
# i: 660000, cost_now: 3, best_cost: 0, temp: 1.32, good_cnt: 4561/660000
# i: 665000, cost_now: 2, best_cost: 0, temp: 1.30, good_cnt: 4565/665000
# i: 670000, cost_now: 3, best_cost: 0, temp: 1.28, good_cnt: 4573/670000
# i: 675000, cost_now: 1, best_cost: 0, temp: 1.26, good_cnt: 4578/675000
# i: 680000, cost_now: 0, best_cost: 0, temp: 1.24, good_cnt: 4583/680000
# i: 685000, cost_now: 4, best_cost: 0, temp: 1.22, good_cnt: 4589/685000
# i: 690000, cost_now: 4, best_cost: 0, temp: 1.20, good_cnt: 4598/690000
# i: 695000, cost_now: 0, best_cost: 0, temp: 1.19, good_cnt: 4607/695000
# i: 700000, cost_now: 4, best_cost: 0, temp: 1.17, good_cnt: 4613/700000
# i: 705000, cost_now: 5, best_cost: 0, temp: 1.15, good_cnt: 4614/705000
# i: 710000, cost_now: 1, best_cost: 0, temp: 1.13, good_cnt: 4621/710000
# i: 715000, cost_now: 2, best_cost: 0, temp: 1.12, good_cnt: 4631/715000
# i: 720000, cost_now: 1, best_cost: 0, temp: 1.10, good_cnt: 4643/720000
# i: 725000, cost_now: 1, best_cost: 0, temp: 1.08, good_cnt: 4651/725000
# i: 730000, cost_now: 0, best_cost: 0, temp: 1.07, good_cnt: 4655/730000
# i: 735000, cost_now: 0, best_cost: 0, temp: 1.05, good_cnt: 4659/735000
# i: 740000, cost_now: 0, best_cost: 0, temp: 1.04, good_cnt: 4661/740000
# i: 745000, cost_now: 2, best_cost: 0, temp: 1.02, good_cnt: 4663/745000
# i: 750000, cost_now: 2, best_cost: 0, temp: 1.01, good_cnt: 4667/750000
# i: 5000, cost_now: 1189, best_cost: 1169, temp: 9.86, good_cnt: 467/5000
# i: 10000, cost_now: 304, best_cost: 301, temp: 9.71, good_cnt: 546/10000
# i: 15000, cost_now: 175, best_cost: 134, temp: 9.56, good_cnt: 627/15000
# i: 20000, cost_now: 64, best_cost: 47, temp: 9.43, good_cnt: 704/20000
# i: 25000, cost_now: 88, best_cost: 13, temp: 9.28, good_cnt: 783/25000
# i: 30000, cost_now: 108, best_cost: 13, temp: 9.12, good_cnt: 860/30000
# i: 35000, cost_now: 59, best_cost: 13, temp: 8.96, good_cnt: 933/35000
# i: 40000, cost_now: 143, best_cost: 13, temp: 8.82, good_cnt: 1008/40000
# i: 45000, cost_now: 46, best_cost: 12, temp: 8.69, good_cnt: 1075/45000
# i: 50000, cost_now: 173, best_cost: 12, temp: 8.56, good_cnt: 1131/50000
# i: 55000, cost_now: 42, best_cost: 12, temp: 8.43, good_cnt: 1214/55000
# i: 60000, cost_now: 137, best_cost: 12, temp: 8.31, good_cnt: 1271/60000
# i: 65000, cost_now: 77, best_cost: 12, temp: 8.18, good_cnt: 1342/65000
# i: 70000, cost_now: 109, best_cost: 12, temp: 8.06, good_cnt: 1407/70000
# i: 75000, cost_now: 61, best_cost: 12, temp: 7.95, good_cnt: 1476/75000
# i: 80000, cost_now: 92, best_cost: 12, temp: 7.83, good_cnt: 1532/80000
# i: 85000, cost_now: 98, best_cost: 6, temp: 7.72, good_cnt: 1595/85000
# i: 90000, cost_now: 143, best_cost: 6, temp: 7.61, good_cnt: 1656/90000
# i: 95000, cost_now: 74, best_cost: 6, temp: 7.50, good_cnt: 1730/95000
# i: 100000, cost_now: 31, best_cost: 6, temp: 7.38, good_cnt: 1786/100000
# i: 105000, cost_now: 41, best_cost: 6, temp: 7.27, good_cnt: 1837/105000
# i: 110000, cost_now: 50, best_cost: 6, temp: 7.16, good_cnt: 1900/110000
# i: 115000, cost_now: 79, best_cost: 6, temp: 7.06, good_cnt: 1957/115000
# i: 120000, cost_now: 96, best_cost: 6, temp: 6.95, good_cnt: 2018/120000
# i: 125000, cost_now: 29, best_cost: 6, temp: 6.85, good_cnt: 2089/125000
# i: 130000, cost_now: 94, best_cost: 6, temp: 6.75, good_cnt: 2133/130000
# i: 135000, cost_now: 51, best_cost: 6, temp: 6.65, good_cnt: 2173/135000
# i: 140000, cost_now: 82, best_cost: 6, temp: 6.55, good_cnt: 2236/140000
# i: 145000, cost_now: 22, best_cost: 5, temp: 6.46, good_cnt: 2276/145000
# i: 150000, cost_now: 30, best_cost: 5, temp: 6.36, good_cnt: 2333/150000
# i: 155000, cost_now: 45, best_cost: 5, temp: 6.27, good_cnt: 2385/155000
# i: 160000, cost_now: 64, best_cost: 5, temp: 6.18, good_cnt: 2430/160000
# i: 165000, cost_now: 77, best_cost: 5, temp: 6.09, good_cnt: 2481/165000
# i: 170000, cost_now: 44, best_cost: 5, temp: 6.00, good_cnt: 2532/170000
# i: 175000, cost_now: 45, best_cost: 5, temp: 5.91, good_cnt: 2576/175000
# i: 180000, cost_now: 60, best_cost: 5, temp: 5.82, good_cnt: 2617/180000
# i: 185000, cost_now: 57, best_cost: 5, temp: 5.73, good_cnt: 2674/185000
# i: 190000, cost_now: 32, best_cost: 5, temp: 5.64, good_cnt: 2721/190000
# i: 195000, cost_now: 22, best_cost: 0, temp: 5.56, good_cnt: 2757/195000
# i: 200000, cost_now: 49, best_cost: 0, temp: 5.47, good_cnt: 2806/200000
# i: 205000, cost_now: 48, best_cost: 0, temp: 5.39, good_cnt: 2852/205000
# i: 210000, cost_now: 12, best_cost: 0, temp: 5.31, good_cnt: 2893/210000
# i: 215000, cost_now: 21, best_cost: 0, temp: 5.21, good_cnt: 2942/215000
# i: 220000, cost_now: 25, best_cost: 0, temp: 5.14, good_cnt: 2977/220000
# i: 225000, cost_now: 10, best_cost: 0, temp: 5.06, good_cnt: 3019/225000
# i: 230000, cost_now: 41, best_cost: 0, temp: 4.99, good_cnt: 3051/230000
# i: 235000, cost_now: 19, best_cost: 0, temp: 4.91, good_cnt: 3081/235000
# i: 240000, cost_now: 11, best_cost: 0, temp: 4.83, good_cnt: 3127/240000
# i: 245000, cost_now: 27, best_cost: 0, temp: 4.75, good_cnt: 3170/245000
# i: 250000, cost_now: 40, best_cost: 0, temp: 4.66, good_cnt: 3203/250000
# i: 255000, cost_now: 26, best_cost: 0, temp: 4.57, good_cnt: 3237/255000
# i: 260000, cost_now: 34, best_cost: 0, temp: 4.49, good_cnt: 3265/260000
# i: 265000, cost_now: 21, best_cost: 0, temp: 4.43, good_cnt: 3288/265000
# i: 270000, cost_now: 9, best_cost: 0, temp: 4.35, good_cnt: 3312/270000
# i: 275000, cost_now: 13, best_cost: 0, temp: 4.27, good_cnt: 3345/275000
# i: 280000, cost_now: 20, best_cost: 0, temp: 4.20, good_cnt: 3382/280000
# i: 285000, cost_now: 5, best_cost: 0, temp: 4.14, good_cnt: 3417/285000
# i: 290000, cost_now: 50, best_cost: 0, temp: 4.07, good_cnt: 3437/290000
# i: 295000, cost_now: 36, best_cost: 0, temp: 4.01, good_cnt: 3482/295000
# i: 300000, cost_now: 15, best_cost: 0, temp: 3.95, good_cnt: 3515/300000
# i: 305000, cost_now: 28, best_cost: 0, temp: 3.88, good_cnt: 3543/305000
# i: 310000, cost_now: 30, best_cost: 0, temp: 3.82, good_cnt: 3575/310000
# i: 315000, cost_now: 14, best_cost: 0, temp: 3.76, good_cnt: 3614/315000
# i: 320000, cost_now: 23, best_cost: 0, temp: 3.70, good_cnt: 3640/320000
# i: 325000, cost_now: 19, best_cost: 0, temp: 3.65, good_cnt: 3678/325000
# i: 330000, cost_now: 11, best_cost: 0, temp: 3.59, good_cnt: 3695/330000
# i: 335000, cost_now: 30, best_cost: 0, temp: 3.53, good_cnt: 3725/335000
# i: 340000, cost_now: 12, best_cost: 0, temp: 3.47, good_cnt: 3754/340000
# i: 345000, cost_now: 11, best_cost: 0, temp: 3.42, good_cnt: 3778/345000
# i: 350000, cost_now: 4, best_cost: 0, temp: 3.36, good_cnt: 3806/350000
# i: 355000, cost_now: 7, best_cost: 0, temp: 3.30, good_cnt: 3820/355000
# i: 360000, cost_now: 6, best_cost: 0, temp: 3.24, good_cnt: 3836/360000
# i: 365000, cost_now: 9, best_cost: 0, temp: 3.18, good_cnt: 3856/365000
# i: 370000, cost_now: 17, best_cost: 0, temp: 3.12, good_cnt: 3882/370000
# i: 375000, cost_now: 0, best_cost: 0, temp: 3.07, good_cnt: 3913/375000
# i: 380000, cost_now: 13, best_cost: 0, temp: 3.02, good_cnt: 3933/380000
# i: 385000, cost_now: 2, best_cost: 0, temp: 2.97, good_cnt: 3961/385000
# i: 390000, cost_now: 5, best_cost: 0, temp: 2.92, good_cnt: 3972/390000
# i: 395000, cost_now: 8, best_cost: 0, temp: 2.88, good_cnt: 4007/395000
# i: 400000, cost_now: 10, best_cost: 0, temp: 2.84, good_cnt: 4023/400000
# i: 405000, cost_now: 4, best_cost: 0, temp: 2.79, good_cnt: 4042/405000
# i: 410000, cost_now: 5, best_cost: 0, temp: 2.75, good_cnt: 4059/410000
# i: 415000, cost_now: 3, best_cost: 0, temp: 2.70, good_cnt: 4079/415000
# i: 420000, cost_now: 21, best_cost: 0, temp: 2.66, good_cnt: 4099/420000
# i: 425000, cost_now: 2, best_cost: 0, temp: 2.62, good_cnt: 4130/425000
# i: 430000, cost_now: 12, best_cost: 0, temp: 2.58, good_cnt: 4150/430000
# i: 435000, cost_now: 11, best_cost: 0, temp: 2.54, good_cnt: 4177/435000
# i: 440000, cost_now: 6, best_cost: 0, temp: 2.50, good_cnt: 4193/440000
# i: 445000, cost_now: 8, best_cost: 0, temp: 2.47, good_cnt: 4209/445000
# i: 450000, cost_now: 21, best_cost: 0, temp: 2.43, good_cnt: 4225/450000
# i: 455000, cost_now: 0, best_cost: 0, temp: 2.39, good_cnt: 4241/455000
# i: 460000, cost_now: 3, best_cost: 0, temp: 2.36, good_cnt: 4252/460000
# i: 465000, cost_now: 7, best_cost: 0, temp: 2.32, good_cnt: 4272/465000
# i: 470000, cost_now: 10, best_cost: 0, temp: 2.29, good_cnt: 4288/470000
# i: 475000, cost_now: 0, best_cost: 0, temp: 2.25, good_cnt: 4309/475000
# i: 480000, cost_now: 6, best_cost: 0, temp: 2.22, good_cnt: 4315/480000
# i: 485000, cost_now: 3, best_cost: 0, temp: 2.18, good_cnt: 4333/485000
# i: 490000, cost_now: 2, best_cost: 0, temp: 2.15, good_cnt: 4354/490000
# i: 495000, cost_now: 2, best_cost: 0, temp: 2.12, good_cnt: 4367/495000
# i: 500000, cost_now: 10, best_cost: 0, temp: 2.09, good_cnt: 4380/500000
# i: 505000, cost_now: 4, best_cost: 0, temp: 2.05, good_cnt: 4395/505000
# i: 510000, cost_now: 3, best_cost: 0, temp: 2.02, good_cnt: 4402/510000
# i: 515000, cost_now: 4, best_cost: 0, temp: 1.98, good_cnt: 4415/515000
# i: 520000, cost_now: 1, best_cost: 0, temp: 1.95, good_cnt: 4429/520000
# i: 525000, cost_now: 5, best_cost: 0, temp: 1.92, good_cnt: 4446/525000
# i: 530000, cost_now: 4, best_cost: 0, temp: 1.89, good_cnt: 4458/530000
# i: 535000, cost_now: 1, best_cost: 0, temp: 1.86, good_cnt: 4467/535000
# i: 540000, cost_now: 13, best_cost: 0, temp: 1.83, good_cnt: 4476/540000
# i: 545000, cost_now: 0, best_cost: 0, temp: 1.80, good_cnt: 4485/545000
# i: 550000, cost_now: 0, best_cost: 0, temp: 1.78, good_cnt: 4493/550000
# i: 555000, cost_now: 2, best_cost: 0, temp: 1.75, good_cnt: 4503/555000
# i: 560000, cost_now: 0, best_cost: 0, temp: 1.72, good_cnt: 4510/560000
# i: 565000, cost_now: 2, best_cost: 0, temp: 1.70, good_cnt: 4516/565000
# i: 570000, cost_now: 0, best_cost: 0, temp: 1.67, good_cnt: 4522/570000
# i: 575000, cost_now: 1, best_cost: 0, temp: 1.65, good_cnt: 4532/575000
# i: 580000, cost_now: 1, best_cost: 0, temp: 1.62, good_cnt: 4543/580000
# i: 585000, cost_now: 4, best_cost: 0, temp: 1.60, good_cnt: 4552/585000
# i: 590000, cost_now: 2, best_cost: 0, temp: 1.57, good_cnt: 4560/590000
# i: 595000, cost_now: 0, best_cost: 0, temp: 1.55, good_cnt: 4570/595000
# i: 600000, cost_now: 3, best_cost: 0, temp: 1.52, good_cnt: 4577/600000
# i: 605000, cost_now: 3, best_cost: 0, temp: 1.50, good_cnt: 4586/605000
# i: 610000, cost_now: 5, best_cost: 0, temp: 1.48, good_cnt: 4593/610000
# i: 615000, cost_now: 3, best_cost: 0, temp: 1.46, good_cnt: 4605/615000
# i: 620000, cost_now: 2, best_cost: 0, temp: 1.44, good_cnt: 4613/620000
# i: 625000, cost_now: 0, best_cost: 0, temp: 1.42, good_cnt: 4622/625000
# i: 630000, cost_now: 0, best_cost: 0, temp: 1.40, good_cnt: 4628/630000
# i: 635000, cost_now: 0, best_cost: 0, temp: 1.38, good_cnt: 4633/635000
# i: 640000, cost_now: 10, best_cost: 0, temp: 1.36, good_cnt: 4639/640000
# i: 645000, cost_now: 0, best_cost: 0, temp: 1.34, good_cnt: 4649/645000
# i: 650000, cost_now: 1, best_cost: 0, temp: 1.32, good_cnt: 4660/650000
# i: 655000, cost_now: 1, best_cost: 0, temp: 1.30, good_cnt: 4671/655000
# i: 660000, cost_now: 0, best_cost: 0, temp: 1.28, good_cnt: 4675/660000
# i: 665000, cost_now: 1, best_cost: 0, temp: 1.26, good_cnt: 4684/665000
# i: 670000, cost_now: 0, best_cost: 0, temp: 1.24, good_cnt: 4692/670000
# i: 675000, cost_now: 1, best_cost: 0, temp: 1.22, good_cnt: 4700/675000
# i: 680000, cost_now: 2, best_cost: 0, temp: 1.20, good_cnt: 4711/680000
# i: 685000, cost_now: 0, best_cost: 0, temp: 1.18, good_cnt: 4719/685000
# i: 690000, cost_now: 2, best_cost: 0, temp: 1.17, good_cnt: 4725/690000
# i: 695000, cost_now: 4, best_cost: 0, temp: 1.15, good_cnt: 4729/695000
# i: 700000, cost_now: 0, best_cost: 0, temp: 1.13, good_cnt: 4735/700000
# i: 705000, cost_now: 0, best_cost: 0, temp: 1.11, good_cnt: 4740/705000
# i: 710000, cost_now: 2, best_cost: 0, temp: 1.10, good_cnt: 4744/710000
# i: 715000, cost_now: 0, best_cost: 0, temp: 1.08, good_cnt: 4750/715000
# i: 720000, cost_now: 0, best_cost: 0, temp: 1.06, good_cnt: 4757/720000
# i: 725000, cost_now: 2, best_cost: 0, temp: 1.05, good_cnt: 4764/725000
# i: 730000, cost_now: 7, best_cost: 0, temp: 1.03, good_cnt: 4767/730000
# i: 735000, cost_now: 0, best_cost: 0, temp: 1.01, good_cnt: 4774/735000

# %%
x_best_mean = [tuple() for _ in range(env.N)]
for i in range(env.N):
    total_x = 0
    total_y = 0
    for j in range(len(x_bests)):
        total_x += x_bests[j][i][0]
        total_y += x_bests[j][i][1]
    total_x //= len(x_bests)
    total_y //= len(x_bests)
    x_best_mean[i] = (total_x, total_y)

# %%
def calc_greedy_answer(
    env: Env,
    target_points: list[tuple[int, int]],
):
    graph = construct_dist_matrix(target_points)

    groups = [(i, g) for i, g in enumerate(env.G)]
    groups = sorted(groups, key=lambda x: x[1], reverse=True)

    ans_edges = [None for _ in range(len(groups))]
    ans_v = [None for _ in range(len(groups))]
    ans_costs = [None for _ in range(len(groups))]

    now_used: set = set()
    not_used: set = set(range(env.N))
    for group_n, group_size in groups:
        v = not_used.pop()
        prim_edges, prim_v, prim_cost = prim_k(graph, v, group_size, now_used, env.N)
        ans_edges[group_n] = prim_edges
        ans_v[group_n] = prim_v
        ans_costs[group_n] = prim_cost
        now_used.update(prim_v)
        not_used.difference_update(prim_v)

    return ans_v, ans_edges, ans_costs

# %%
ans_v, ans_edges, _ = calc_greedy_answer(env, x_best_mean)
env.answer(ans_v, ans_edges)
# Out:
# query: 400
# 484090.0

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


def get_color(i):
    # colors = list(matplotlib.colors.CSS4_COLORS.values())
    colors = matplotlib.cm.tab20.colors
    return colors[i % len(colors)]


point_inds = list(range(env.N))  # longs_points[:]
corrects_np = np.array(env.coordinates)[point_inds]
estimates_np = np.array(x_best)[point_inds]
rectangles = np.array([env.rectangles[i] for i in range(env.N)])[point_inds]

# 四角形と、四角形内の正解点と予測点を描画
plt.figure(figsize=(10, 10))
ax = plt.gca()
# for i, rect in enumerate(rectangles):
#     l, r, t, b = rect
#     ax.add_patch(matplotlib.patches.Rectangle((l, t), r - l, b - t, alpha=0.1))
ax.scatter(corrects_np[:, 0], corrects_np[:, 1], color="green", label="correct", s=20, marker="*")
ax.scatter(estimates_np[:, 0], estimates_np[:, 1], color="red", label="estimate", s=5, marker="o")
for point_ind in range(len(corrects_np)):
    ax.plot(
        (corrects_np[point_ind, 0], estimates_np[point_ind, 0]),
        (corrects_np[point_ind, 1], estimates_np[point_ind, 1]),
        color="gray",
        label="correct path",
    )
plt.show()
