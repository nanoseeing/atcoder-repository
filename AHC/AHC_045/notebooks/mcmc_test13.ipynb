# %%
# =================================
# 設定
# =================================
IS_ONLINE_JUDGE = False

LIMIT_QUERY_CNT = None

DEBUG = False
DEBUG_QUERY = None
DEBUG_L = None

MAX_TIME = 1.25
FILE_NUM = 100

# =================================
# 初期化
# =================================
import time

GLOBAL_START_TIME = time.perf_counter()

import random

random.seed(1111)

if IS_ONLINE_JUDGE:
    DEBUG = False

# =================================
# Import
# =================================
import math
from collections import defaultdict

# =================================
# 共通
# =================================
if True:
    from importlib import reload

    import src.common as common

    reload(common)


from src.common import (
    Env,
    EnvOffline,
    calc_dist,
    construct_dist_matrix,
    construct_graph,
    construct_graph_from_edges,
    cut_graph,
    exponential_schedule,
    prim_k,
    sort_pair,
)


# =================================
# 汎用（main.py専用）
# =================================
def debug_print(*args, **kwargs):
    if IS_ONLINE_JUDGE:
        return
    print(*args, **kwargs)


def print_elapsed_time():
    debug_print(f"elapsed time: {(time.perf_counter() - GLOBAL_START_TIME) * 1000:.2f}msecs")

# %%
file_num = 7
input_file_path = f"../in/{file_num:04d}.txt"
output_file_path = f"../out/{file_num:04d}.txt"
env = EnvOffline(input_file_path, output_file_path)

# %%
def cost_formula(d1: int, d2: int) -> int:
    if d1 > d2:
        return d1 - d2
    else:
        return 0


def calc_init_cost(
    constrains: list[tuple[tuple[int, int], tuple[int, int]]],
    x: list[tuple[int, int]],
) -> tuple[list[int], int]:
    cost_list: list[int] = [0 for _ in range(len(constrains))]
    for ci in range(len(constrains)):
        cons = constrains[ci]
        (p1, p2), (q1, q2) = cons
        dist1 = calc_dist(x[p1], x[p2])
        dist2 = calc_dist(x[q1], x[q2])
        cost_list[ci] = cost_formula(dist1, dist2)
    total_cost = sum(cost_list)
    return cost_list, total_cost


def calc_cost(
    constrains: list[tuple[tuple[int, int], tuple[int, int]]],
    x_now: list[tuple[int, int]],
    x_update: dict[int, tuple[int, int]],
    cost_list: list[int],
    cost_now: int,
    vid_to_constid: dict[int, list[int]],
) -> tuple[dict[int, int], int]:
    new_cost = cost_now
    cost_update = dict()
    for v in x_update:
        for consid in vid_to_constid[v]:
            (p1, p2), (q1, q2) = constrains[consid]
            coord1 = x_update[p1] if p1 in x_update else x_now[p1]
            coord2 = x_update[p2] if p2 in x_update else x_now[p2]
            coord3 = x_update[q1] if q1 in x_update else x_now[q1]
            coord4 = x_update[q2] if q2 in x_update else x_now[q2]
            dist1 = calc_dist(coord1, coord2)
            dist2 = calc_dist(coord3, coord4)
            pre_cost = cost_list[consid]
            now_cost = cost_formula(dist1, dist2)
            new_cost += now_cost - pre_cost
            cost_update[consid] = now_cost
    return cost_update, new_cost


def neighbor(
    x: list[tuple[int, int]],
    target_v: list[int],
    rects: list[list[int]],
    now_mul_x: float,
    k: int = 1,
):
    vs: list[int] = random.sample(target_v, k=k)
    x_update: dict[int, tuple[int, int]] = dict()

    for v in vs:
        rnd = random.random()
        rand_coord = tuple()
        if rnd < 0.99:
            x1, x2, y1, y2 = rects[v]
            nx, ny = x[v]
            dx = x2 - x1
            dy = y2 - y1
            max_dx = max(int(dx * now_mul_x), 1)
            max_dy = max(int(dy * now_mul_x), 1)
            lim_l = max(x1, nx - max_dx)
            lim_r = min(x2, nx + max_dx)
            lim_u = max(y1, ny - max_dy)
            lim_d = min(y2, ny + max_dy)
            rand_coord = random.randint(lim_l, lim_r), random.randint(lim_u, lim_d)
        else:
            x1, x2, y1, y2 = rects[v]
            rand_coord = random.randint(x1, x2), random.randint(y1, y2)

        x_update[v] = rand_coord
        nx, ny = x[v]
        x1, x2, y1, y2 = rects[v]
        if (x2 - x1) == 0:
            mul_x = 0.01
        else:
            mul_x = abs(nx - rand_coord[0]) / (x2 - x1)

    return x_update, mul_x

# %%
def simulated_annealing(
    x0: list[tuple[int, int]],
    t0: float,
    t1: float,
    constrains: list[tuple[tuple[int, int], tuple[int, int]]],
    rectangles: list[tuple[int, int, int, int]],
    target_vs: list[int],
    vid_to_constid: dict[int, list[int]],
    max_time: float = 1.0,
    display: bool = False,
):
    x = x0.copy()
    x_best = x
    x_update = dict()

    cost_list, cost_current = calc_init_cost(constrains, x)
    cost_best = cost_current
    cost_update = dict()

    simulate_cnt = 0
    good_cnt = 0
    st = time.perf_counter()

    sum_mul_x = 0.0
    now_mul_x = 0.5
    while True:
        elapsed_time = time.perf_counter() - st
        if elapsed_time >= max_time:
            break
        temp = exponential_schedule(t0, t1, elapsed_time, max_time)

        x_update, mul_x = neighbor(x, target_vs, rectangles, now_mul_x)
        cost_update, cost_new = calc_cost(
            constrains=constrains,
            x_now=x,
            x_update=x_update,
            cost_list=cost_list,
            cost_now=cost_current,
            vid_to_constid=vid_to_constid,
        )

        delta_cost = cost_new - cost_current
        if delta_cost < 0:
            good_cnt += 1
            sum_mul_x += mul_x
        if delta_cost <= 0 or random.random() < math.exp(-delta_cost / temp):
            cost_current = cost_new
            for v in x_update:
                x[v] = x_update[v]
            for ci in cost_update:
                cost_list[ci] = cost_update[ci]
        if cost_current < cost_best:
            x_best = x
            cost_best = cost_current

        simulate_cnt += 1
        if display and simulate_cnt % 5000 == 0:
            debug_print(
                f"i: {simulate_cnt}, cost_now: {cost_current}, best_cost: {cost_best}, temp: {temp:.2f}, good_cnt: {good_cnt}/{simulate_cnt}"
            )
        if good_cnt > 0 and good_cnt % 100 == 0:
            now_mul_x = max(min(0.01, sum_mul_x / good_cnt), 0.5)
            sum_mul_x = 0.0
    return x_best, cost_best

# %%
import itertools
import math


def triangle_score(p1: tuple[int, int], p2: tuple[int, int], p3: tuple[int, int]):
    """三角形が正三角形にどれだけ近いか（辺の長さの標準偏差で評価）"""
    d1 = math.dist(p1, p2)
    d2 = math.dist(p2, p3)
    d3 = math.dist(p3, p1)
    mean = (d1 + d2 + d3) / 3
    variance = ((d1 - mean) ** 2 + (d2 - mean) ** 2 + (d3 - mean) ** 2) / 3
    return math.sqrt(variance)

# %%
all_graph: dict[int, list[tuple[int, int]]] = construct_graph({i: p for i, p in enumerate(env.cneter_points)})
graph_matrix = construct_dist_matrix(env.cneter_points)

# %%
area_list = []
for i, (l, r, t, b) in enumerate(env.rectangles):
    dx = r - l
    dy = b - t
    area_list.append((i, dx * dy))
area_list.sort(key=lambda x: x[1], reverse=True)
area_points = [i for i, _ in area_list]

# %%
target_query = []
for random_v in area_points:
    neighbors = all_graph[random_v]
    neighbor_v_nums = [v for d, v in neighbors][:20]

    best_score = float("inf")
    now_p = env.cneter_points[random_v]
    for v1, v2 in itertools.combinations(neighbor_v_nums, 2):
        p1 = env.cneter_points[v1]
        p2 = env.cneter_points[v2]
        score = triangle_score(now_p, p1, p2)
        if score < best_score:
            best_score = score
            best_triangle = (random_v, v1, v2)
            best_triangle_points = (now_p, p1, p2)
    target_query.append(best_triangle)

# %%
# other_points = all_graph[nearest_center_point][: env.L - 1]
# other_point_inds = [p[1] for p in other_points]
# other_point_inds

# init_group = [nearest_center_point] + other_point_inds

# query_vs = [init_group]
# group_que = [init_group]
# used = set(init_group)

# while (len(query_vs) < env.L) or (0 < len(group_que)):
#     now_group_list_num = len(group_que)
#     target_group_num = random.randint(0, now_group_list_num - 1)
#     target_group = group_que[target_group_num]
#     group_que.pop(target_group_num)

#     for v_num in target_group:
#         # グループ内のL-2-1点
#         # in_group_dists = []
#         # for in_group_num in target_group:
#         #     if v_num == in_group_num:
#         #         continue
#         #     in_group_dists.append((graph_matrix[v_num][in_group_num], in_group_num))
#         # in_group_dists = sorted(in_group_dists, key=lambda x: x[0])
#         # add_dists = in_group_dists[: env.L - 3]
#         # add_point_ids = [p[1] for p in add_dists]
#         add_point_ids = []

#         # グループ外の2点
#         add_ex_group_num = env.L - len(add_point_ids) - 1
#         ex_point_ids = []
#         for _, ex_v_num in all_graph[v_num][:30]:
#             if ex_v_num in used:
#                 continue
#             ex_point_ids.append(ex_v_num)
#             if len(ex_point_ids) == add_ex_group_num:
#                 break

#         if len(ex_point_ids) < add_ex_group_num:
#             continue

#         next_group = [v_num] + add_point_ids + ex_point_ids
#         group_que.append(next_group)
#         query_vs.append(next_group)
#         used.update(next_group)

# %%
constrains = set()
random_vs = set()
for query_v in query_vs:
    edges = env.query(query_v)
    graph = construct_graph_from_edges(edges, query_v)
    for e in edges:
        group_vs1, group_vs2 = cut_graph(graph, e)
        for v1 in group_vs1:
            for v2 in group_vs2:
                sv1, sv2 = sort_pair((v1, v2))
                if e == (sv1, sv2):
                    continue
                constrains.add((e, (sv1, sv2)))
constrains = list(constrains)
random_vs = list(used)

# %%
print(len(query_vs), len(constrains), len(random_vs), len(constrains) / len(query_vs))
# Out:
# 398 796 797 2.0

# %%
# max_d_list = []
# for i, (l, r, t, b) in enumerate(env.rectangles):
#     dx = r - l
#     dy = b - t
#     max_d_list.append((i, dx + dy))  # あえて辺の合計にする
# max_d_list.sort(key=lambda x: x[1], reverse=True)

# all_graph: dict[int, list[tuple[int, int]]] = construct_graph({i: p for i, p in enumerate(env.cneter_points)})

# max_d_list = []
# for i, (l, r, t, b) in enumerate(env.rectangles):
#     dx = r - l
#     dy = b - t
#     max_d_list.append((i, dx + dy))  # あえて辺の合計にする
# max_d_list.sort(key=lambda x: x[1], reverse=True)

# constrains = set()
# random_vs = set()
# for big_v, _ in max_d_list[: env.Q]:
#     other_points = all_graph[big_v][: env.L * 2]
#     other_points = [p for d, p in other_points]
#     other_points = sorted(other_points, key=lambda x: max_d_list[x], reverse=True)
#     other_points = other_points[: env.L - 1]

#     tmp_random_vs = [big_v] + other_points

#     edges = env.query(tmp_random_vs)
#     graph = construct_graph_from_edges(edges, tmp_random_vs)

#     for e in edges:
#         group_vs1, group_vs2 = cut_graph(graph, e)
#         for v1 in group_vs1:
#             for v2 in group_vs2:
#                 sv1, sv2 = sort_pair((v1, v2))
#                 if e == (sv1, sv2):
#                     continue
#                 constrains.add((e, (sv1, sv2)))
#     random_vs.update(tmp_random_vs)

# constrains = list(constrains)
# random_vs = list(random_vs)

# %%
vid_to_constid = defaultdict(set)
for i, const in enumerate(constrains):
    (p1, p2), (q1, q2) = const
    vid_to_constid[p1].add(i)
    vid_to_constid[p2].add(i)
    vid_to_constid[q1].add(i)
    vid_to_constid[q2].add(i)

# %%
x_bests = []
for _ in range(1):
    x_best, cost_best = simulated_annealing(
        x0=env.cneter_points,
        t0=10.0,
        t1=1.0,
        constrains=constrains,
        rectangles=env.rectangles,
        target_vs=random_vs,
        vid_to_constid=vid_to_constid,
        max_time=30,
        display=True,
    )
    x_bests.append(x_best)
# Out:
# i: 5000, cost_now: 1686, best_cost: 1675, temp: 9.97, good_cnt: 464/5000
# i: 10000, cost_now: 137, best_cost: 113, temp: 9.94, good_cnt: 584/10000
# i: 15000, cost_now: 116, best_cost: 84, temp: 9.91, good_cnt: 658/15000
# i: 20000, cost_now: 57, best_cost: 42, temp: 9.89, good_cnt: 746/20000
# i: 25000, cost_now: 129, best_cost: 26, temp: 9.86, good_cnt: 809/25000
# i: 30000, cost_now: 100, best_cost: 26, temp: 9.83, good_cnt: 884/30000
# i: 35000, cost_now: 46, best_cost: 23, temp: 9.81, good_cnt: 963/35000
# i: 40000, cost_now: 106, best_cost: 23, temp: 9.78, good_cnt: 1049/40000
# i: 45000, cost_now: 37, best_cost: 13, temp: 9.76, good_cnt: 1113/45000
# i: 50000, cost_now: 108, best_cost: 13, temp: 9.74, good_cnt: 1180/50000
# i: 55000, cost_now: 59, best_cost: 13, temp: 9.71, good_cnt: 1253/55000
# i: 60000, cost_now: 123, best_cost: 13, temp: 9.69, good_cnt: 1328/60000
# i: 65000, cost_now: 152, best_cost: 13, temp: 9.67, good_cnt: 1396/65000
# i: 70000, cost_now: 191, best_cost: 13, temp: 9.65, good_cnt: 1485/70000
# i: 75000, cost_now: 125, best_cost: 13, temp: 9.62, good_cnt: 1562/75000
# i: 80000, cost_now: 70, best_cost: 13, temp: 9.59, good_cnt: 1632/80000
# i: 85000, cost_now: 90, best_cost: 13, temp: 9.57, good_cnt: 1703/85000
# i: 90000, cost_now: 87, best_cost: 13, temp: 9.54, good_cnt: 1764/90000
# i: 95000, cost_now: 63, best_cost: 13, temp: 9.52, good_cnt: 1826/95000
# i: 100000, cost_now: 40, best_cost: 11, temp: 9.50, good_cnt: 1899/100000
# i: 105000, cost_now: 56, best_cost: 11, temp: 9.47, good_cnt: 1958/105000
# i: 110000, cost_now: 113, best_cost: 11, temp: 9.45, good_cnt: 2018/110000
# i: 115000, cost_now: 130, best_cost: 11, temp: 9.43, good_cnt: 2091/115000
# i: 120000, cost_now: 82, best_cost: 11, temp: 9.40, good_cnt: 2174/120000
# i: 125000, cost_now: 136, best_cost: 11, temp: 9.38, good_cnt: 2246/125000
# i: 130000, cost_now: 77, best_cost: 11, temp: 9.35, good_cnt: 2327/130000
# i: 135000, cost_now: 68, best_cost: 11, temp: 9.33, good_cnt: 2384/135000
# i: 140000, cost_now: 158, best_cost: 11, temp: 9.31, good_cnt: 2439/140000
# i: 145000, cost_now: 73, best_cost: 11, temp: 9.28, good_cnt: 2517/145000
# i: 150000, cost_now: 126, best_cost: 11, temp: 9.26, good_cnt: 2600/150000
# i: 155000, cost_now: 61, best_cost: 11, temp: 9.24, good_cnt: 2665/155000
# i: 160000, cost_now: 110, best_cost: 11, temp: 9.22, good_cnt: 2743/160000
# i: 165000, cost_now: 122, best_cost: 11, temp: 9.20, good_cnt: 2828/165000
# i: 170000, cost_now: 120, best_cost: 11, temp: 9.18, good_cnt: 2903/170000
# i: 175000, cost_now: 104, best_cost: 11, temp: 9.16, good_cnt: 2968/175000
# i: 180000, cost_now: 61, best_cost: 11, temp: 9.14, good_cnt: 3036/180000
# i: 185000, cost_now: 57, best_cost: 11, temp: 9.11, good_cnt: 3102/185000
# i: 190000, cost_now: 142, best_cost: 11, temp: 9.09, good_cnt: 3175/190000
# i: 195000, cost_now: 162, best_cost: 6, temp: 9.06, good_cnt: 3239/195000
# i: 200000, cost_now: 108, best_cost: 6, temp: 9.04, good_cnt: 3325/200000
# i: 205000, cost_now: 64, best_cost: 6, temp: 9.01, good_cnt: 3391/205000
# i: 210000, cost_now: 95, best_cost: 6, temp: 8.98, good_cnt: 3464/210000
# i: 215000, cost_now: 86, best_cost: 6, temp: 8.95, good_cnt: 3535/215000
# i: 220000, cost_now: 48, best_cost: 6, temp: 8.93, good_cnt: 3602/220000
# i: 225000, cost_now: 94, best_cost: 6, temp: 8.91, good_cnt: 3673/225000
# i: 230000, cost_now: 55, best_cost: 6, temp: 8.88, good_cnt: 3744/230000
# i: 235000, cost_now: 124, best_cost: 6, temp: 8.86, good_cnt: 3823/235000
# i: 240000, cost_now: 107, best_cost: 6, temp: 8.84, good_cnt: 3901/240000
# i: 245000, cost_now: 60, best_cost: 6, temp: 8.82, good_cnt: 3967/245000
# i: 250000, cost_now: 59, best_cost: 6, temp: 8.80, good_cnt: 4030/250000
# i: 255000, cost_now: 151, best_cost: 6, temp: 8.77, good_cnt: 4097/255000
# i: 260000, cost_now: 119, best_cost: 6, temp: 8.75, good_cnt: 4163/260000
# i: 265000, cost_now: 85, best_cost: 6, temp: 8.73, good_cnt: 4235/265000
# i: 270000, cost_now: 56, best_cost: 6, temp: 8.71, good_cnt: 4311/270000
# i: 275000, cost_now: 62, best_cost: 6, temp: 8.69, good_cnt: 4380/275000
# i: 280000, cost_now: 107, best_cost: 6, temp: 8.67, good_cnt: 4462/280000
# i: 285000, cost_now: 96, best_cost: 6, temp: 8.65, good_cnt: 4523/285000
# i: 290000, cost_now: 80, best_cost: 6, temp: 8.63, good_cnt: 4581/290000
# i: 295000, cost_now: 120, best_cost: 6, temp: 8.61, good_cnt: 4661/295000
# i: 300000, cost_now: 26, best_cost: 6, temp: 8.59, good_cnt: 4731/300000
# i: 305000, cost_now: 94, best_cost: 6, temp: 8.57, good_cnt: 4789/305000
# i: 310000, cost_now: 52, best_cost: 6, temp: 8.55, good_cnt: 4855/310000
# i: 315000, cost_now: 42, best_cost: 6, temp: 8.53, good_cnt: 4924/315000
# i: 320000, cost_now: 57, best_cost: 6, temp: 8.51, good_cnt: 4970/320000
# i: 325000, cost_now: 77, best_cost: 6, temp: 8.50, good_cnt: 5030/325000
# i: 330000, cost_now: 123, best_cost: 6, temp: 8.48, good_cnt: 5094/330000
# i: 335000, cost_now: 16, best_cost: 6, temp: 8.46, good_cnt: 5159/335000
# i: 340000, cost_now: 48, best_cost: 2, temp: 8.44, good_cnt: 5213/340000
# i: 345000, cost_now: 102, best_cost: 2, temp: 8.42, good_cnt: 5263/345000
# i: 350000, cost_now: 95, best_cost: 2, temp: 8.40, good_cnt: 5329/350000
# i: 355000, cost_now: 106, best_cost: 2, temp: 8.38, good_cnt: 5395/355000
# i: 360000, cost_now: 85, best_cost: 2, temp: 8.36, good_cnt: 5467/360000
# i: 365000, cost_now: 97, best_cost: 2, temp: 8.34, good_cnt: 5528/365000
# i: 370000, cost_now: 81, best_cost: 2, temp: 8.32, good_cnt: 5592/370000
# i: 375000, cost_now: 90, best_cost: 2, temp: 8.30, good_cnt: 5670/375000
# i: 380000, cost_now: 111, best_cost: 2, temp: 8.28, good_cnt: 5744/380000
# i: 385000, cost_now: 30, best_cost: 2, temp: 8.26, good_cnt: 5813/385000
# i: 390000, cost_now: 31, best_cost: 2, temp: 8.24, good_cnt: 5876/390000
# i: 395000, cost_now: 70, best_cost: 2, temp: 8.23, good_cnt: 5929/395000
# i: 400000, cost_now: 82, best_cost: 2, temp: 8.21, good_cnt: 5983/400000
# i: 405000, cost_now: 86, best_cost: 2, temp: 8.18, good_cnt: 6059/405000
# i: 410000, cost_now: 58, best_cost: 2, temp: 8.16, good_cnt: 6115/410000
# i: 415000, cost_now: 26, best_cost: 2, temp: 8.14, good_cnt: 6185/415000
# i: 420000, cost_now: 68, best_cost: 2, temp: 8.12, good_cnt: 6238/420000
# i: 425000, cost_now: 49, best_cost: 2, temp: 8.11, good_cnt: 6304/425000
# i: 430000, cost_now: 59, best_cost: 2, temp: 8.09, good_cnt: 6354/430000
# i: 435000, cost_now: 99, best_cost: 2, temp: 8.07, good_cnt: 6416/435000
# i: 440000, cost_now: 112, best_cost: 2, temp: 8.05, good_cnt: 6477/440000
# i: 445000, cost_now: 71, best_cost: 2, temp: 8.03, good_cnt: 6546/445000
# i: 450000, cost_now: 74, best_cost: 0, temp: 8.01, good_cnt: 6591/450000
# i: 455000, cost_now: 120, best_cost: 0, temp: 7.99, good_cnt: 6650/455000
# i: 460000, cost_now: 102, best_cost: 0, temp: 7.98, good_cnt: 6720/460000
# i: 465000, cost_now: 24, best_cost: 0, temp: 7.96, good_cnt: 6797/465000
# i: 470000, cost_now: 74, best_cost: 0, temp: 7.94, good_cnt: 6854/470000
# i: 475000, cost_now: 59, best_cost: 0, temp: 7.91, good_cnt: 6900/475000
# i: 480000, cost_now: 76, best_cost: 0, temp: 7.90, good_cnt: 6941/480000
# i: 485000, cost_now: 173, best_cost: 0, temp: 7.88, good_cnt: 6990/485000
# i: 490000, cost_now: 132, best_cost: 0, temp: 7.86, good_cnt: 7061/490000
# i: 495000, cost_now: 68, best_cost: 0, temp: 7.84, good_cnt: 7117/495000
# i: 500000, cost_now: 81, best_cost: 0, temp: 7.82, good_cnt: 7184/500000
# i: 505000, cost_now: 60, best_cost: 0, temp: 7.81, good_cnt: 7251/505000
# i: 510000, cost_now: 108, best_cost: 0, temp: 7.79, good_cnt: 7305/510000
# i: 515000, cost_now: 75, best_cost: 0, temp: 7.77, good_cnt: 7374/515000
# i: 520000, cost_now: 32, best_cost: 0, temp: 7.75, good_cnt: 7438/520000
# i: 525000, cost_now: 25, best_cost: 0, temp: 7.73, good_cnt: 7484/525000
# i: 530000, cost_now: 43, best_cost: 0, temp: 7.71, good_cnt: 7537/530000
# i: 535000, cost_now: 39, best_cost: 0, temp: 7.68, good_cnt: 7600/535000
# i: 540000, cost_now: 100, best_cost: 0, temp: 7.67, good_cnt: 7665/540000
# i: 545000, cost_now: 56, best_cost: 0, temp: 7.65, good_cnt: 7728/545000
# i: 550000, cost_now: 58, best_cost: 0, temp: 7.63, good_cnt: 7782/550000
# i: 555000, cost_now: 58, best_cost: 0, temp: 7.61, good_cnt: 7827/555000
# i: 560000, cost_now: 99, best_cost: 0, temp: 7.59, good_cnt: 7879/560000
# i: 565000, cost_now: 26, best_cost: 0, temp: 7.57, good_cnt: 7946/565000
# i: 570000, cost_now: 22, best_cost: 0, temp: 7.55, good_cnt: 8011/570000
# i: 575000, cost_now: 16, best_cost: 0, temp: 7.53, good_cnt: 8070/575000
# i: 580000, cost_now: 82, best_cost: 0, temp: 7.51, good_cnt: 8131/580000
# i: 585000, cost_now: 62, best_cost: 0, temp: 7.50, good_cnt: 8184/585000
# i: 590000, cost_now: 50, best_cost: 0, temp: 7.48, good_cnt: 8255/590000
# i: 595000, cost_now: 44, best_cost: 0, temp: 7.46, good_cnt: 8322/595000
# i: 600000, cost_now: 92, best_cost: 0, temp: 7.44, good_cnt: 8388/600000
# i: 605000, cost_now: 82, best_cost: 0, temp: 7.43, good_cnt: 8439/605000
# i: 610000, cost_now: 27, best_cost: 0, temp: 7.41, good_cnt: 8500/610000
# i: 615000, cost_now: 63, best_cost: 0, temp: 7.39, good_cnt: 8560/615000
# i: 620000, cost_now: 19, best_cost: 0, temp: 7.38, good_cnt: 8618/620000
# i: 625000, cost_now: 40, best_cost: 0, temp: 7.36, good_cnt: 8674/625000
# i: 630000, cost_now: 25, best_cost: 0, temp: 7.34, good_cnt: 8728/630000
# i: 635000, cost_now: 49, best_cost: 0, temp: 7.33, good_cnt: 8778/635000
# i: 640000, cost_now: 85, best_cost: 0, temp: 7.31, good_cnt: 8835/640000
# i: 645000, cost_now: 38, best_cost: 0, temp: 7.29, good_cnt: 8905/645000
# i: 650000, cost_now: 50, best_cost: 0, temp: 7.28, good_cnt: 8959/650000
# i: 655000, cost_now: 110, best_cost: 0, temp: 7.26, good_cnt: 9006/655000
# i: 660000, cost_now: 28, best_cost: 0, temp: 7.25, good_cnt: 9057/660000
# i: 665000, cost_now: 88, best_cost: 0, temp: 7.23, good_cnt: 9105/665000
# i: 670000, cost_now: 53, best_cost: 0, temp: 7.21, good_cnt: 9158/670000
# i: 675000, cost_now: 46, best_cost: 0, temp: 7.20, good_cnt: 9216/675000
# i: 680000, cost_now: 62, best_cost: 0, temp: 7.18, good_cnt: 9269/680000
# i: 685000, cost_now: 53, best_cost: 0, temp: 7.16, good_cnt: 9317/685000
# i: 690000, cost_now: 120, best_cost: 0, temp: 7.15, good_cnt: 9386/690000
# i: 695000, cost_now: 35, best_cost: 0, temp: 7.13, good_cnt: 9442/695000
# i: 700000, cost_now: 26, best_cost: 0, temp: 7.12, good_cnt: 9498/700000
# i: 705000, cost_now: 61, best_cost: 0, temp: 7.10, good_cnt: 9566/705000
# i: 710000, cost_now: 54, best_cost: 0, temp: 7.08, good_cnt: 9634/710000
# i: 715000, cost_now: 73, best_cost: 0, temp: 7.07, good_cnt: 9693/715000
# i: 720000, cost_now: 50, best_cost: 0, temp: 7.05, good_cnt: 9735/720000
# i: 725000, cost_now: 101, best_cost: 0, temp: 7.03, good_cnt: 9800/725000
# i: 730000, cost_now: 55, best_cost: 0, temp: 7.02, good_cnt: 9849/730000
# i: 735000, cost_now: 70, best_cost: 0, temp: 7.00, good_cnt: 9893/735000
# i: 740000, cost_now: 73, best_cost: 0, temp: 6.99, good_cnt: 9947/740000
# i: 745000, cost_now: 38, best_cost: 0, temp: 6.97, good_cnt: 10011/745000
# i: 750000, cost_now: 25, best_cost: 0, temp: 6.95, good_cnt: 10056/750000
# i: 755000, cost_now: 52, best_cost: 0, temp: 6.94, good_cnt: 10110/755000
# i: 760000, cost_now: 39, best_cost: 0, temp: 6.92, good_cnt: 10163/760000
# i: 765000, cost_now: 52, best_cost: 0, temp: 6.91, good_cnt: 10206/765000
# i: 770000, cost_now: 19, best_cost: 0, temp: 6.89, good_cnt: 10249/770000
# i: 775000, cost_now: 41, best_cost: 0, temp: 6.88, good_cnt: 10296/775000
# i: 780000, cost_now: 35, best_cost: 0, temp: 6.86, good_cnt: 10349/780000
# i: 785000, cost_now: 43, best_cost: 0, temp: 6.84, good_cnt: 10394/785000
# i: 790000, cost_now: 33, best_cost: 0, temp: 6.82, good_cnt: 10457/790000
# i: 795000, cost_now: 90, best_cost: 0, temp: 6.81, good_cnt: 10510/795000
# i: 800000, cost_now: 8, best_cost: 0, temp: 6.79, good_cnt: 10557/800000
# i: 805000, cost_now: 81, best_cost: 0, temp: 6.77, good_cnt: 10620/805000
# i: 810000, cost_now: 51, best_cost: 0, temp: 6.75, good_cnt: 10678/810000
# i: 815000, cost_now: 19, best_cost: 0, temp: 6.74, good_cnt: 10718/815000
# i: 820000, cost_now: 64, best_cost: 0, temp: 6.72, good_cnt: 10776/820000
# i: 825000, cost_now: 34, best_cost: 0, temp: 6.71, good_cnt: 10842/825000
# i: 830000, cost_now: 85, best_cost: 0, temp: 6.69, good_cnt: 10903/830000
# i: 835000, cost_now: 54, best_cost: 0, temp: 6.68, good_cnt: 10960/835000
# i: 840000, cost_now: 40, best_cost: 0, temp: 6.66, good_cnt: 11010/840000
# i: 845000, cost_now: 98, best_cost: 0, temp: 6.65, good_cnt: 11061/845000
# i: 850000, cost_now: 29, best_cost: 0, temp: 6.63, good_cnt: 11117/850000
# i: 855000, cost_now: 55, best_cost: 0, temp: 6.62, good_cnt: 11182/855000
# i: 860000, cost_now: 49, best_cost: 0, temp: 6.60, good_cnt: 11228/860000
# i: 865000, cost_now: 114, best_cost: 0, temp: 6.59, good_cnt: 11280/865000
# i: 870000, cost_now: 41, best_cost: 0, temp: 6.57, good_cnt: 11327/870000
# i: 875000, cost_now: 87, best_cost: 0, temp: 6.56, good_cnt: 11387/875000
# i: 880000, cost_now: 0, best_cost: 0, temp: 6.54, good_cnt: 11444/880000
# i: 885000, cost_now: 92, best_cost: 0, temp: 6.53, good_cnt: 11487/885000
# i: 890000, cost_now: 83, best_cost: 0, temp: 6.51, good_cnt: 11545/890000
# i: 895000, cost_now: 63, best_cost: 0, temp: 6.50, good_cnt: 11609/895000
# i: 900000, cost_now: 91, best_cost: 0, temp: 6.48, good_cnt: 11661/900000
# i: 905000, cost_now: 40, best_cost: 0, temp: 6.47, good_cnt: 11716/905000
# i: 910000, cost_now: 33, best_cost: 0, temp: 6.45, good_cnt: 11755/910000
# i: 915000, cost_now: 16, best_cost: 0, temp: 6.44, good_cnt: 11803/915000
# i: 920000, cost_now: 21, best_cost: 0, temp: 6.43, good_cnt: 11852/920000
# i: 925000, cost_now: 37, best_cost: 0, temp: 6.41, good_cnt: 11903/925000
# i: 930000, cost_now: 89, best_cost: 0, temp: 6.39, good_cnt: 11958/930000
# i: 935000, cost_now: 10, best_cost: 0, temp: 6.38, good_cnt: 12008/935000
# i: 940000, cost_now: 56, best_cost: 0, temp: 6.36, good_cnt: 12040/940000
# i: 945000, cost_now: 46, best_cost: 0, temp: 6.34, good_cnt: 12077/945000
# i: 950000, cost_now: 60, best_cost: 0, temp: 6.33, good_cnt: 12136/950000
# i: 955000, cost_now: 45, best_cost: 0, temp: 6.31, good_cnt: 12173/955000
# i: 960000, cost_now: 105, best_cost: 0, temp: 6.30, good_cnt: 12225/960000
# i: 965000, cost_now: 43, best_cost: 0, temp: 6.29, good_cnt: 12281/965000
# i: 970000, cost_now: 24, best_cost: 0, temp: 6.27, good_cnt: 12318/970000
# i: 975000, cost_now: 65, best_cost: 0, temp: 6.26, good_cnt: 12358/975000
# i: 980000, cost_now: 39, best_cost: 0, temp: 6.24, good_cnt: 12405/980000
# i: 985000, cost_now: 65, best_cost: 0, temp: 6.23, good_cnt: 12459/985000
# i: 990000, cost_now: 44, best_cost: 0, temp: 6.22, good_cnt: 12523/990000
# i: 995000, cost_now: 101, best_cost: 0, temp: 6.20, good_cnt: 12573/995000
# i: 1000000, cost_now: 69, best_cost: 0, temp: 6.19, good_cnt: 12630/1000000
# i: 1005000, cost_now: 40, best_cost: 0, temp: 6.17, good_cnt: 12670/1005000
# i: 1010000, cost_now: 41, best_cost: 0, temp: 6.16, good_cnt: 12720/1010000
# i: 1015000, cost_now: 71, best_cost: 0, temp: 6.15, good_cnt: 12773/1015000
# i: 1020000, cost_now: 37, best_cost: 0, temp: 6.13, good_cnt: 12818/1020000
# i: 1025000, cost_now: 42, best_cost: 0, temp: 6.12, good_cnt: 12874/1025000
# i: 1030000, cost_now: 57, best_cost: 0, temp: 6.11, good_cnt: 12915/1030000
# i: 1035000, cost_now: 51, best_cost: 0, temp: 6.09, good_cnt: 12967/1035000
# i: 1040000, cost_now: 65, best_cost: 0, temp: 6.08, good_cnt: 13007/1040000
# i: 1045000, cost_now: 30, best_cost: 0, temp: 6.07, good_cnt: 13050/1045000
# i: 1050000, cost_now: 31, best_cost: 0, temp: 6.05, good_cnt: 13092/1050000
# i: 1055000, cost_now: 31, best_cost: 0, temp: 6.04, good_cnt: 13132/1055000
# i: 1060000, cost_now: 26, best_cost: 0, temp: 6.02, good_cnt: 13181/1060000
# i: 1065000, cost_now: 66, best_cost: 0, temp: 6.01, good_cnt: 13215/1065000
# i: 1070000, cost_now: 23, best_cost: 0, temp: 5.99, good_cnt: 13246/1070000
# i: 1075000, cost_now: 68, best_cost: 0, temp: 5.98, good_cnt: 13297/1075000
# i: 1080000, cost_now: 97, best_cost: 0, temp: 5.97, good_cnt: 13349/1080000
# i: 1085000, cost_now: 22, best_cost: 0, temp: 5.96, good_cnt: 13390/1085000
# i: 1090000, cost_now: 47, best_cost: 0, temp: 5.94, good_cnt: 13439/1090000
# i: 1095000, cost_now: 41, best_cost: 0, temp: 5.93, good_cnt: 13491/1095000
# i: 1100000, cost_now: 76, best_cost: 0, temp: 5.92, good_cnt: 13538/1100000
# i: 1105000, cost_now: 39, best_cost: 0, temp: 5.90, good_cnt: 13581/1105000
# i: 1110000, cost_now: 10, best_cost: 0, temp: 5.89, good_cnt: 13622/1110000
# i: 1115000, cost_now: 20, best_cost: 0, temp: 5.88, good_cnt: 13671/1115000
# i: 1120000, cost_now: 21, best_cost: 0, temp: 5.86, good_cnt: 13717/1120000
# i: 1125000, cost_now: 28, best_cost: 0, temp: 5.85, good_cnt: 13758/1125000
# i: 1130000, cost_now: 27, best_cost: 0, temp: 5.84, good_cnt: 13808/1130000
# i: 1135000, cost_now: 12, best_cost: 0, temp: 5.82, good_cnt: 13847/1135000
# i: 1140000, cost_now: 49, best_cost: 0, temp: 5.81, good_cnt: 13894/1140000
# i: 1145000, cost_now: 15, best_cost: 0, temp: 5.80, good_cnt: 13934/1145000
# i: 1150000, cost_now: 22, best_cost: 0, temp: 5.78, good_cnt: 13965/1150000
# i: 1155000, cost_now: 34, best_cost: 0, temp: 5.77, good_cnt: 14003/1155000
# i: 1160000, cost_now: 34, best_cost: 0, temp: 5.76, good_cnt: 14051/1160000
# i: 1165000, cost_now: 26, best_cost: 0, temp: 5.75, good_cnt: 14109/1165000
# i: 1170000, cost_now: 21, best_cost: 0, temp: 5.73, good_cnt: 14154/1170000
# i: 1175000, cost_now: 26, best_cost: 0, temp: 5.72, good_cnt: 14210/1175000
# i: 1180000, cost_now: 32, best_cost: 0, temp: 5.71, good_cnt: 14248/1180000
# i: 1185000, cost_now: 15, best_cost: 0, temp: 5.69, good_cnt: 14282/1185000
# i: 1190000, cost_now: 7, best_cost: 0, temp: 5.68, good_cnt: 14321/1190000
# i: 1195000, cost_now: 29, best_cost: 0, temp: 5.66, good_cnt: 14354/1195000
# i: 1200000, cost_now: 30, best_cost: 0, temp: 5.65, good_cnt: 14388/1200000
# i: 1205000, cost_now: 27, best_cost: 0, temp: 5.64, good_cnt: 14423/1205000
# i: 1210000, cost_now: 23, best_cost: 0, temp: 5.62, good_cnt: 14460/1210000
# i: 1215000, cost_now: 42, best_cost: 0, temp: 5.61, good_cnt: 14501/1215000
# i: 1220000, cost_now: 29, best_cost: 0, temp: 5.59, good_cnt: 14552/1220000
# i: 1225000, cost_now: 5, best_cost: 0, temp: 5.58, good_cnt: 14589/1225000
# i: 1230000, cost_now: 47, best_cost: 0, temp: 5.57, good_cnt: 14624/1230000
# i: 1235000, cost_now: 33, best_cost: 0, temp: 5.55, good_cnt: 14665/1235000
# i: 1240000, cost_now: 16, best_cost: 0, temp: 5.54, good_cnt: 14708/1240000
# i: 1245000, cost_now: 17, best_cost: 0, temp: 5.53, good_cnt: 14752/1245000
# i: 1250000, cost_now: 71, best_cost: 0, temp: 5.52, good_cnt: 14795/1250000
# i: 1255000, cost_now: 32, best_cost: 0, temp: 5.50, good_cnt: 14836/1255000
# i: 1260000, cost_now: 21, best_cost: 0, temp: 5.49, good_cnt: 14879/1260000
# i: 1265000, cost_now: 30, best_cost: 0, temp: 5.48, good_cnt: 14920/1265000
# i: 1270000, cost_now: 36, best_cost: 0, temp: 5.46, good_cnt: 14961/1270000
# i: 1275000, cost_now: 29, best_cost: 0, temp: 5.45, good_cnt: 15003/1275000
# i: 1280000, cost_now: 23, best_cost: 0, temp: 5.44, good_cnt: 15044/1280000
# i: 1285000, cost_now: 18, best_cost: 0, temp: 5.43, good_cnt: 15081/1285000
# i: 1290000, cost_now: 27, best_cost: 0, temp: 5.42, good_cnt: 15116/1290000
# i: 1295000, cost_now: 9, best_cost: 0, temp: 5.40, good_cnt: 15161/1295000
# i: 1300000, cost_now: 47, best_cost: 0, temp: 5.39, good_cnt: 15196/1300000
# i: 1305000, cost_now: 73, best_cost: 0, temp: 5.38, good_cnt: 15243/1305000
# i: 1310000, cost_now: 23, best_cost: 0, temp: 5.36, good_cnt: 15293/1310000
# i: 1315000, cost_now: 34, best_cost: 0, temp: 5.35, good_cnt: 15349/1315000
# i: 1320000, cost_now: 43, best_cost: 0, temp: 5.34, good_cnt: 15381/1320000
# i: 1325000, cost_now: 29, best_cost: 0, temp: 5.33, good_cnt: 15419/1325000
# i: 1330000, cost_now: 14, best_cost: 0, temp: 5.31, good_cnt: 15469/1330000
# i: 1335000, cost_now: 24, best_cost: 0, temp: 5.30, good_cnt: 15503/1335000
# i: 1340000, cost_now: 14, best_cost: 0, temp: 5.28, good_cnt: 15544/1340000
# i: 1345000, cost_now: 57, best_cost: 0, temp: 5.27, good_cnt: 15579/1345000
# i: 1350000, cost_now: 50, best_cost: 0, temp: 5.26, good_cnt: 15619/1350000
# i: 1355000, cost_now: 25, best_cost: 0, temp: 5.24, good_cnt: 15660/1355000
# i: 1360000, cost_now: 62, best_cost: 0, temp: 5.23, good_cnt: 15705/1360000
# i: 1365000, cost_now: 10, best_cost: 0, temp: 5.22, good_cnt: 15745/1365000
# i: 1370000, cost_now: 55, best_cost: 0, temp: 5.21, good_cnt: 15778/1370000
# i: 1375000, cost_now: 27, best_cost: 0, temp: 5.19, good_cnt: 15825/1375000
# i: 1380000, cost_now: 60, best_cost: 0, temp: 5.18, good_cnt: 15857/1380000
# i: 1385000, cost_now: 24, best_cost: 0, temp: 5.17, good_cnt: 15890/1385000
# i: 1390000, cost_now: 19, best_cost: 0, temp: 5.15, good_cnt: 15923/1390000
# i: 1395000, cost_now: 24, best_cost: 0, temp: 5.14, good_cnt: 15962/1395000
# i: 1400000, cost_now: 61, best_cost: 0, temp: 5.13, good_cnt: 16001/1400000
# i: 1405000, cost_now: 45, best_cost: 0, temp: 5.12, good_cnt: 16027/1405000
# i: 1410000, cost_now: 48, best_cost: 0, temp: 5.10, good_cnt: 16059/1410000
# i: 1415000, cost_now: 49, best_cost: 0, temp: 5.09, good_cnt: 16093/1415000
# i: 1420000, cost_now: 16, best_cost: 0, temp: 5.08, good_cnt: 16124/1420000
# i: 1425000, cost_now: 28, best_cost: 0, temp: 5.07, good_cnt: 16153/1425000
# i: 1430000, cost_now: 23, best_cost: 0, temp: 5.06, good_cnt: 16200/1430000
# i: 1435000, cost_now: 5, best_cost: 0, temp: 5.04, good_cnt: 16236/1435000
# i: 1440000, cost_now: 8, best_cost: 0, temp: 5.03, good_cnt: 16272/1440000
# i: 1445000, cost_now: 13, best_cost: 0, temp: 5.02, good_cnt: 16297/1445000
# i: 1450000, cost_now: 17, best_cost: 0, temp: 5.01, good_cnt: 16338/1450000
# i: 1455000, cost_now: 40, best_cost: 0, temp: 4.99, good_cnt: 16368/1455000
# i: 1460000, cost_now: 18, best_cost: 0, temp: 4.98, good_cnt: 16410/1460000
# i: 1465000, cost_now: 19, best_cost: 0, temp: 4.97, good_cnt: 16452/1465000
# i: 1470000, cost_now: 21, best_cost: 0, temp: 4.96, good_cnt: 16492/1470000
# i: 1475000, cost_now: 21, best_cost: 0, temp: 4.95, good_cnt: 16536/1475000
# i: 1480000, cost_now: 15, best_cost: 0, temp: 4.94, good_cnt: 16572/1480000
# i: 1485000, cost_now: 6, best_cost: 0, temp: 4.92, good_cnt: 16609/1485000
# i: 1490000, cost_now: 27, best_cost: 0, temp: 4.91, good_cnt: 16636/1490000
# i: 1495000, cost_now: 36, best_cost: 0, temp: 4.90, good_cnt: 16669/1495000
# i: 1500000, cost_now: 29, best_cost: 0, temp: 4.89, good_cnt: 16707/1500000
# i: 1505000, cost_now: 6, best_cost: 0, temp: 4.88, good_cnt: 16745/1505000
# i: 1510000, cost_now: 51, best_cost: 0, temp: 4.86, good_cnt: 16775/1510000
# i: 1515000, cost_now: 62, best_cost: 0, temp: 4.85, good_cnt: 16804/1515000
# i: 1520000, cost_now: 29, best_cost: 0, temp: 4.84, good_cnt: 16853/1520000
# i: 1525000, cost_now: 10, best_cost: 0, temp: 4.83, good_cnt: 16888/1525000
# i: 1530000, cost_now: 27, best_cost: 0, temp: 4.81, good_cnt: 16929/1530000
# i: 1535000, cost_now: 35, best_cost: 0, temp: 4.80, good_cnt: 16964/1535000
# i: 1540000, cost_now: 12, best_cost: 0, temp: 4.79, good_cnt: 17012/1540000
# i: 1545000, cost_now: 29, best_cost: 0, temp: 4.78, good_cnt: 17044/1545000
# i: 1550000, cost_now: 3, best_cost: 0, temp: 4.77, good_cnt: 17072/1550000
# i: 1555000, cost_now: 10, best_cost: 0, temp: 4.76, good_cnt: 17102/1555000
# i: 1560000, cost_now: 13, best_cost: 0, temp: 4.74, good_cnt: 17138/1560000
# i: 1565000, cost_now: 29, best_cost: 0, temp: 4.73, good_cnt: 17159/1565000
# i: 1570000, cost_now: 33, best_cost: 0, temp: 4.72, good_cnt: 17193/1570000
# i: 1575000, cost_now: 17, best_cost: 0, temp: 4.71, good_cnt: 17231/1575000
# i: 1580000, cost_now: 30, best_cost: 0, temp: 4.70, good_cnt: 17257/1580000
# i: 1585000, cost_now: 32, best_cost: 0, temp: 4.69, good_cnt: 17283/1585000
# i: 1590000, cost_now: 14, best_cost: 0, temp: 4.68, good_cnt: 17310/1590000
# i: 1595000, cost_now: 7, best_cost: 0, temp: 4.67, good_cnt: 17343/1595000
# i: 1600000, cost_now: 26, best_cost: 0, temp: 4.66, good_cnt: 17387/1600000
# i: 1605000, cost_now: 39, best_cost: 0, temp: 4.65, good_cnt: 17416/1605000
# i: 1610000, cost_now: 13, best_cost: 0, temp: 4.64, good_cnt: 17452/1610000
# i: 1615000, cost_now: 19, best_cost: 0, temp: 4.62, good_cnt: 17491/1615000
# i: 1620000, cost_now: 19, best_cost: 0, temp: 4.61, good_cnt: 17515/1620000
# i: 1625000, cost_now: 17, best_cost: 0, temp: 4.60, good_cnt: 17556/1625000
# i: 1630000, cost_now: 30, best_cost: 0, temp: 4.59, good_cnt: 17584/1630000
# i: 1635000, cost_now: 42, best_cost: 0, temp: 4.58, good_cnt: 17627/1635000
# i: 1640000, cost_now: 28, best_cost: 0, temp: 4.57, good_cnt: 17663/1640000
# i: 1645000, cost_now: 26, best_cost: 0, temp: 4.56, good_cnt: 17693/1645000
# i: 1650000, cost_now: 56, best_cost: 0, temp: 4.55, good_cnt: 17729/1650000
# i: 1655000, cost_now: 13, best_cost: 0, temp: 4.54, good_cnt: 17777/1655000
# i: 1660000, cost_now: 20, best_cost: 0, temp: 4.52, good_cnt: 17813/1660000
# i: 1665000, cost_now: 18, best_cost: 0, temp: 4.51, good_cnt: 17843/1665000
# i: 1670000, cost_now: 24, best_cost: 0, temp: 4.50, good_cnt: 17870/1670000
# i: 1675000, cost_now: 27, best_cost: 0, temp: 4.49, good_cnt: 17900/1675000
# i: 1680000, cost_now: 14, best_cost: 0, temp: 4.48, good_cnt: 17940/1680000
# i: 1685000, cost_now: 29, best_cost: 0, temp: 4.47, good_cnt: 17961/1685000
# i: 1690000, cost_now: 42, best_cost: 0, temp: 4.46, good_cnt: 18002/1690000
# i: 1695000, cost_now: 25, best_cost: 0, temp: 4.45, good_cnt: 18035/1695000
# i: 1700000, cost_now: 23, best_cost: 0, temp: 4.44, good_cnt: 18083/1700000
# i: 1705000, cost_now: 17, best_cost: 0, temp: 4.43, good_cnt: 18118/1705000
# i: 1710000, cost_now: 8, best_cost: 0, temp: 4.42, good_cnt: 18159/1710000
# i: 1715000, cost_now: 56, best_cost: 0, temp: 4.41, good_cnt: 18193/1715000
# i: 1720000, cost_now: 28, best_cost: 0, temp: 4.40, good_cnt: 18228/1720000
# i: 1725000, cost_now: 54, best_cost: 0, temp: 4.39, good_cnt: 18255/1725000
# i: 1730000, cost_now: 6, best_cost: 0, temp: 4.38, good_cnt: 18296/1730000
# i: 1735000, cost_now: 30, best_cost: 0, temp: 4.37, good_cnt: 18327/1735000
# i: 1740000, cost_now: 2, best_cost: 0, temp: 4.36, good_cnt: 18362/1740000
# i: 1745000, cost_now: 27, best_cost: 0, temp: 4.35, good_cnt: 18379/1745000
# i: 1750000, cost_now: 38, best_cost: 0, temp: 4.34, good_cnt: 18403/1750000
# i: 1755000, cost_now: 59, best_cost: 0, temp: 4.33, good_cnt: 18426/1755000
# i: 1760000, cost_now: 0, best_cost: 0, temp: 4.32, good_cnt: 18460/1760000
# i: 1765000, cost_now: 12, best_cost: 0, temp: 4.31, good_cnt: 18480/1765000
# i: 1770000, cost_now: 31, best_cost: 0, temp: 4.30, good_cnt: 18520/1770000
# i: 1775000, cost_now: 24, best_cost: 0, temp: 4.29, good_cnt: 18549/1775000
# i: 1780000, cost_now: 38, best_cost: 0, temp: 4.28, good_cnt: 18577/1780000
# i: 1785000, cost_now: 19, best_cost: 0, temp: 4.27, good_cnt: 18608/1785000
# i: 1790000, cost_now: 22, best_cost: 0, temp: 4.26, good_cnt: 18633/1790000
# i: 1795000, cost_now: 12, best_cost: 0, temp: 4.26, good_cnt: 18661/1795000
# i: 1800000, cost_now: 34, best_cost: 0, temp: 4.25, good_cnt: 18687/1800000
# i: 1805000, cost_now: 31, best_cost: 0, temp: 4.24, good_cnt: 18718/1805000
# i: 1810000, cost_now: 24, best_cost: 0, temp: 4.23, good_cnt: 18744/1810000
# i: 1815000, cost_now: 17, best_cost: 0, temp: 4.22, good_cnt: 18783/1815000
# i: 1820000, cost_now: 9, best_cost: 0, temp: 4.21, good_cnt: 18808/1820000
# i: 1825000, cost_now: 17, best_cost: 0, temp: 4.20, good_cnt: 18836/1825000
# i: 1830000, cost_now: 15, best_cost: 0, temp: 4.19, good_cnt: 18867/1830000
# i: 1835000, cost_now: 9, best_cost: 0, temp: 4.18, good_cnt: 18895/1835000
# i: 1840000, cost_now: 3, best_cost: 0, temp: 4.17, good_cnt: 18923/1840000
# i: 1845000, cost_now: 6, best_cost: 0, temp: 4.16, good_cnt: 18946/1845000
# i: 1850000, cost_now: 36, best_cost: 0, temp: 4.15, good_cnt: 18963/1850000
# i: 1855000, cost_now: 71, best_cost: 0, temp: 4.14, good_cnt: 18999/1855000
# i: 1860000, cost_now: 4, best_cost: 0, temp: 4.13, good_cnt: 19040/1860000
# i: 1865000, cost_now: 28, best_cost: 0, temp: 4.13, good_cnt: 19077/1865000
# i: 1870000, cost_now: 16, best_cost: 0, temp: 4.12, good_cnt: 19100/1870000
# i: 1875000, cost_now: 28, best_cost: 0, temp: 4.11, good_cnt: 19125/1875000
# i: 1880000, cost_now: 14, best_cost: 0, temp: 4.10, good_cnt: 19150/1880000
# i: 1885000, cost_now: 41, best_cost: 0, temp: 4.09, good_cnt: 19169/1885000
# i: 1890000, cost_now: 6, best_cost: 0, temp: 4.08, good_cnt: 19201/1890000
# i: 1895000, cost_now: 5, best_cost: 0, temp: 4.07, good_cnt: 19230/1895000
# i: 1900000, cost_now: 13, best_cost: 0, temp: 4.06, good_cnt: 19253/1900000
# i: 1905000, cost_now: 27, best_cost: 0, temp: 4.05, good_cnt: 19276/1905000
# i: 1910000, cost_now: 44, best_cost: 0, temp: 4.04, good_cnt: 19302/1910000
# i: 1915000, cost_now: 33, best_cost: 0, temp: 4.03, good_cnt: 19331/1915000
# i: 1920000, cost_now: 22, best_cost: 0, temp: 4.02, good_cnt: 19366/1920000
# i: 1925000, cost_now: 33, best_cost: 0, temp: 4.01, good_cnt: 19402/1925000
# i: 1930000, cost_now: 18, best_cost: 0, temp: 4.00, good_cnt: 19445/1930000
# i: 1935000, cost_now: 22, best_cost: 0, temp: 4.00, good_cnt: 19474/1935000
# i: 1940000, cost_now: 22, best_cost: 0, temp: 3.99, good_cnt: 19511/1940000
# i: 1945000, cost_now: 48, best_cost: 0, temp: 3.98, good_cnt: 19544/1945000
# i: 1950000, cost_now: 6, best_cost: 0, temp: 3.97, good_cnt: 19571/1950000
# i: 1955000, cost_now: 7, best_cost: 0, temp: 3.96, good_cnt: 19600/1955000
# i: 1960000, cost_now: 19, best_cost: 0, temp: 3.95, good_cnt: 19634/1960000
# i: 1965000, cost_now: 26, best_cost: 0, temp: 3.94, good_cnt: 19664/1965000
# i: 1970000, cost_now: 22, best_cost: 0, temp: 3.93, good_cnt: 19696/1970000
# i: 1975000, cost_now: 9, best_cost: 0, temp: 3.93, good_cnt: 19728/1975000
# i: 1980000, cost_now: 32, best_cost: 0, temp: 3.92, good_cnt: 19755/1980000
# i: 1985000, cost_now: 45, best_cost: 0, temp: 3.91, good_cnt: 19788/1985000
# i: 1990000, cost_now: 17, best_cost: 0, temp: 3.90, good_cnt: 19809/1990000
# i: 1995000, cost_now: 7, best_cost: 0, temp: 3.89, good_cnt: 19835/1995000
# i: 2000000, cost_now: 20, best_cost: 0, temp: 3.88, good_cnt: 19870/2000000
# i: 2005000, cost_now: 21, best_cost: 0, temp: 3.87, good_cnt: 19891/2005000
# i: 2010000, cost_now: 2, best_cost: 0, temp: 3.87, good_cnt: 19921/2010000
# i: 2015000, cost_now: 19, best_cost: 0, temp: 3.86, good_cnt: 19943/2015000
# i: 2020000, cost_now: 34, best_cost: 0, temp: 3.85, good_cnt: 19971/2020000
# i: 2025000, cost_now: 2, best_cost: 0, temp: 3.84, good_cnt: 19997/2025000
# i: 2030000, cost_now: 26, best_cost: 0, temp: 3.83, good_cnt: 20024/2030000
# i: 2035000, cost_now: 33, best_cost: 0, temp: 3.82, good_cnt: 20050/2035000
# i: 2040000, cost_now: 20, best_cost: 0, temp: 3.81, good_cnt: 20087/2040000
# i: 2045000, cost_now: 1, best_cost: 0, temp: 3.80, good_cnt: 20107/2045000
# i: 2050000, cost_now: 13, best_cost: 0, temp: 3.79, good_cnt: 20132/2050000
# i: 2055000, cost_now: 4, best_cost: 0, temp: 3.78, good_cnt: 20165/2055000
# i: 2060000, cost_now: 4, best_cost: 0, temp: 3.78, good_cnt: 20193/2060000
# i: 2065000, cost_now: 4, best_cost: 0, temp: 3.77, good_cnt: 20215/2065000
# i: 2070000, cost_now: 2, best_cost: 0, temp: 3.76, good_cnt: 20243/2070000
# i: 2075000, cost_now: 2, best_cost: 0, temp: 3.75, good_cnt: 20268/2075000
# i: 2080000, cost_now: 52, best_cost: 0, temp: 3.74, good_cnt: 20297/2080000
# i: 2085000, cost_now: 14, best_cost: 0, temp: 3.73, good_cnt: 20321/2085000
# i: 2090000, cost_now: 17, best_cost: 0, temp: 3.73, good_cnt: 20346/2090000
# i: 2095000, cost_now: 30, best_cost: 0, temp: 3.72, good_cnt: 20376/2095000
# i: 2100000, cost_now: 0, best_cost: 0, temp: 3.71, good_cnt: 20405/2100000
# i: 2105000, cost_now: 19, best_cost: 0, temp: 3.70, good_cnt: 20432/2105000
# i: 2110000, cost_now: 14, best_cost: 0, temp: 3.69, good_cnt: 20460/2110000
# i: 2115000, cost_now: 5, best_cost: 0, temp: 3.68, good_cnt: 20490/2115000
# i: 2120000, cost_now: 19, best_cost: 0, temp: 3.67, good_cnt: 20514/2120000
# i: 2125000, cost_now: 20, best_cost: 0, temp: 3.67, good_cnt: 20539/2125000
# i: 2130000, cost_now: 27, best_cost: 0, temp: 3.66, good_cnt: 20562/2130000
# i: 2135000, cost_now: 13, best_cost: 0, temp: 3.65, good_cnt: 20592/2135000
# i: 2140000, cost_now: 0, best_cost: 0, temp: 3.64, good_cnt: 20617/2140000
# i: 2145000, cost_now: 23, best_cost: 0, temp: 3.63, good_cnt: 20638/2145000
# i: 2150000, cost_now: 21, best_cost: 0, temp: 3.63, good_cnt: 20672/2150000
# i: 2155000, cost_now: 3, best_cost: 0, temp: 3.62, good_cnt: 20701/2155000
# i: 2160000, cost_now: 15, best_cost: 0, temp: 3.61, good_cnt: 20720/2160000
# i: 2165000, cost_now: 9, best_cost: 0, temp: 3.60, good_cnt: 20743/2165000
# i: 2170000, cost_now: 8, best_cost: 0, temp: 3.59, good_cnt: 20768/2170000
# i: 2175000, cost_now: 10, best_cost: 0, temp: 3.59, good_cnt: 20794/2175000
# i: 2180000, cost_now: 2, best_cost: 0, temp: 3.58, good_cnt: 20815/2180000
# i: 2185000, cost_now: 20, best_cost: 0, temp: 3.57, good_cnt: 20845/2185000
# i: 2190000, cost_now: 18, best_cost: 0, temp: 3.56, good_cnt: 20882/2190000
# i: 2195000, cost_now: 7, best_cost: 0, temp: 3.55, good_cnt: 20907/2195000
# i: 2200000, cost_now: 18, best_cost: 0, temp: 3.54, good_cnt: 20927/2200000
# i: 2205000, cost_now: 24, best_cost: 0, temp: 3.54, good_cnt: 20962/2205000
# i: 2210000, cost_now: 9, best_cost: 0, temp: 3.53, good_cnt: 20992/2210000
# i: 2215000, cost_now: 30, best_cost: 0, temp: 3.52, good_cnt: 21018/2215000
# i: 2220000, cost_now: 9, best_cost: 0, temp: 3.51, good_cnt: 21048/2220000
# i: 2225000, cost_now: 1, best_cost: 0, temp: 3.50, good_cnt: 21066/2225000
# i: 2230000, cost_now: 0, best_cost: 0, temp: 3.50, good_cnt: 21095/2230000
# i: 2235000, cost_now: 7, best_cost: 0, temp: 3.49, good_cnt: 21114/2235000
# i: 2240000, cost_now: 42, best_cost: 0, temp: 3.48, good_cnt: 21138/2240000
# i: 2245000, cost_now: 26, best_cost: 0, temp: 3.47, good_cnt: 21165/2245000
# i: 2250000, cost_now: 14, best_cost: 0, temp: 3.46, good_cnt: 21187/2250000
# i: 2255000, cost_now: 9, best_cost: 0, temp: 3.46, good_cnt: 21207/2255000
# i: 2260000, cost_now: 10, best_cost: 0, temp: 3.45, good_cnt: 21235/2260000
# i: 2265000, cost_now: 49, best_cost: 0, temp: 3.44, good_cnt: 21265/2265000
# i: 2270000, cost_now: 6, best_cost: 0, temp: 3.43, good_cnt: 21302/2270000
# i: 2275000, cost_now: 11, best_cost: 0, temp: 3.42, good_cnt: 21323/2275000
# i: 2280000, cost_now: 4, best_cost: 0, temp: 3.42, good_cnt: 21338/2280000
# i: 2285000, cost_now: 25, best_cost: 0, temp: 3.41, good_cnt: 21360/2285000
# i: 2290000, cost_now: 7, best_cost: 0, temp: 3.40, good_cnt: 21381/2290000
# i: 2295000, cost_now: 14, best_cost: 0, temp: 3.39, good_cnt: 21408/2295000
# i: 2300000, cost_now: 0, best_cost: 0, temp: 3.38, good_cnt: 21430/2300000
# i: 2305000, cost_now: 5, best_cost: 0, temp: 3.38, good_cnt: 21452/2305000
# i: 2310000, cost_now: 26, best_cost: 0, temp: 3.37, good_cnt: 21480/2310000
# i: 2315000, cost_now: 23, best_cost: 0, temp: 3.36, good_cnt: 21512/2315000
# i: 2320000, cost_now: 1, best_cost: 0, temp: 3.35, good_cnt: 21529/2320000
# i: 2325000, cost_now: 31, best_cost: 0, temp: 3.35, good_cnt: 21559/2325000
# i: 2330000, cost_now: 13, best_cost: 0, temp: 3.34, good_cnt: 21579/2330000
# i: 2335000, cost_now: 3, best_cost: 0, temp: 3.33, good_cnt: 21603/2335000
# i: 2340000, cost_now: 17, best_cost: 0, temp: 3.32, good_cnt: 21621/2340000
# i: 2345000, cost_now: 11, best_cost: 0, temp: 3.31, good_cnt: 21649/2345000
# i: 2350000, cost_now: 14, best_cost: 0, temp: 3.31, good_cnt: 21668/2350000
# i: 2355000, cost_now: 14, best_cost: 0, temp: 3.30, good_cnt: 21686/2355000
# i: 2360000, cost_now: 26, best_cost: 0, temp: 3.29, good_cnt: 21715/2360000
# i: 2365000, cost_now: 4, best_cost: 0, temp: 3.28, good_cnt: 21731/2365000
# i: 2370000, cost_now: 0, best_cost: 0, temp: 3.28, good_cnt: 21747/2370000
# i: 2375000, cost_now: 11, best_cost: 0, temp: 3.27, good_cnt: 21761/2375000
# i: 2380000, cost_now: 21, best_cost: 0, temp: 3.26, good_cnt: 21783/2380000
# i: 2385000, cost_now: 10, best_cost: 0, temp: 3.25, good_cnt: 21802/2385000
# i: 2390000, cost_now: 15, best_cost: 0, temp: 3.25, good_cnt: 21825/2390000
# i: 2395000, cost_now: 19, best_cost: 0, temp: 3.24, good_cnt: 21852/2395000
# i: 2400000, cost_now: 8, best_cost: 0, temp: 3.23, good_cnt: 21878/2400000
# i: 2405000, cost_now: 2, best_cost: 0, temp: 3.22, good_cnt: 21902/2405000
# i: 2410000, cost_now: 6, best_cost: 0, temp: 3.22, good_cnt: 21913/2410000
# i: 2415000, cost_now: 18, best_cost: 0, temp: 3.21, good_cnt: 21933/2415000
# i: 2420000, cost_now: 35, best_cost: 0, temp: 3.20, good_cnt: 21952/2420000
# i: 2425000, cost_now: 4, best_cost: 0, temp: 3.19, good_cnt: 21980/2425000
# i: 2430000, cost_now: 24, best_cost: 0, temp: 3.18, good_cnt: 22005/2430000
# i: 2435000, cost_now: 27, best_cost: 0, temp: 3.18, good_cnt: 22038/2435000
# i: 2440000, cost_now: 3, best_cost: 0, temp: 3.17, good_cnt: 22055/2440000
# i: 2445000, cost_now: 5, best_cost: 0, temp: 3.16, good_cnt: 22083/2445000
# i: 2450000, cost_now: 1, best_cost: 0, temp: 3.16, good_cnt: 22098/2450000
# i: 2455000, cost_now: 20, best_cost: 0, temp: 3.15, good_cnt: 22119/2455000
# i: 2460000, cost_now: 22, best_cost: 0, temp: 3.14, good_cnt: 22140/2460000
# i: 2465000, cost_now: 6, best_cost: 0, temp: 3.13, good_cnt: 22158/2465000
# i: 2470000, cost_now: 3, best_cost: 0, temp: 3.13, good_cnt: 22184/2470000
# i: 2475000, cost_now: 15, best_cost: 0, temp: 3.12, good_cnt: 22204/2475000
# i: 2480000, cost_now: 10, best_cost: 0, temp: 3.11, good_cnt: 22230/2480000
# i: 2485000, cost_now: 20, best_cost: 0, temp: 3.11, good_cnt: 22252/2485000
# i: 2490000, cost_now: 15, best_cost: 0, temp: 3.10, good_cnt: 22281/2490000
# i: 2495000, cost_now: 13, best_cost: 0, temp: 3.09, good_cnt: 22303/2495000
# i: 2500000, cost_now: 17, best_cost: 0, temp: 3.09, good_cnt: 22328/2500000
# i: 2505000, cost_now: 3, best_cost: 0, temp: 3.08, good_cnt: 22348/2505000
# i: 2510000, cost_now: 22, best_cost: 0, temp: 3.07, good_cnt: 22362/2510000
# i: 2515000, cost_now: 3, best_cost: 0, temp: 3.06, good_cnt: 22394/2515000
# i: 2520000, cost_now: 5, best_cost: 0, temp: 3.06, good_cnt: 22420/2520000
# i: 2525000, cost_now: 9, best_cost: 0, temp: 3.05, good_cnt: 22442/2525000
# i: 2530000, cost_now: 8, best_cost: 0, temp: 3.04, good_cnt: 22465/2530000
# i: 2535000, cost_now: 17, best_cost: 0, temp: 3.04, good_cnt: 22489/2535000
# i: 2540000, cost_now: 1, best_cost: 0, temp: 3.03, good_cnt: 22511/2540000
# i: 2545000, cost_now: 7, best_cost: 0, temp: 3.02, good_cnt: 22520/2545000
# i: 2550000, cost_now: 9, best_cost: 0, temp: 3.02, good_cnt: 22543/2550000
# i: 2555000, cost_now: 12, best_cost: 0, temp: 3.01, good_cnt: 22558/2555000
# i: 2560000, cost_now: 9, best_cost: 0, temp: 3.00, good_cnt: 22580/2560000
# i: 2565000, cost_now: 2, best_cost: 0, temp: 3.00, good_cnt: 22595/2565000
# i: 2570000, cost_now: 7, best_cost: 0, temp: 2.99, good_cnt: 22611/2570000
# i: 2575000, cost_now: 3, best_cost: 0, temp: 2.98, good_cnt: 22637/2575000
# i: 2580000, cost_now: 4, best_cost: 0, temp: 2.97, good_cnt: 22664/2580000
# i: 2585000, cost_now: 10, best_cost: 0, temp: 2.96, good_cnt: 22684/2585000
# i: 2590000, cost_now: 24, best_cost: 0, temp: 2.96, good_cnt: 22704/2590000
# i: 2595000, cost_now: 0, best_cost: 0, temp: 2.95, good_cnt: 22726/2595000
# i: 2600000, cost_now: 14, best_cost: 0, temp: 2.94, good_cnt: 22741/2600000
# i: 2605000, cost_now: 1, best_cost: 0, temp: 2.94, good_cnt: 22762/2605000
# i: 2610000, cost_now: 16, best_cost: 0, temp: 2.93, good_cnt: 22783/2610000
# i: 2615000, cost_now: 17, best_cost: 0, temp: 2.92, good_cnt: 22800/2615000
# i: 2620000, cost_now: 12, best_cost: 0, temp: 2.91, good_cnt: 22827/2620000
# i: 2625000, cost_now: 11, best_cost: 0, temp: 2.91, good_cnt: 22841/2625000
# i: 2630000, cost_now: 19, best_cost: 0, temp: 2.90, good_cnt: 22861/2630000
# i: 2635000, cost_now: 10, best_cost: 0, temp: 2.89, good_cnt: 22883/2635000
# i: 2640000, cost_now: 2, best_cost: 0, temp: 2.89, good_cnt: 22896/2640000
# i: 2645000, cost_now: 5, best_cost: 0, temp: 2.88, good_cnt: 22909/2645000
# i: 2650000, cost_now: 12, best_cost: 0, temp: 2.87, good_cnt: 22928/2650000
# i: 2655000, cost_now: 8, best_cost: 0, temp: 2.87, good_cnt: 22946/2655000
# i: 2660000, cost_now: 2, best_cost: 0, temp: 2.86, good_cnt: 22963/2660000
# i: 2665000, cost_now: 15, best_cost: 0, temp: 2.86, good_cnt: 22979/2665000
# i: 2670000, cost_now: 19, best_cost: 0, temp: 2.85, good_cnt: 23001/2670000
# i: 2675000, cost_now: 14, best_cost: 0, temp: 2.84, good_cnt: 23028/2675000
# i: 2680000, cost_now: 5, best_cost: 0, temp: 2.84, good_cnt: 23044/2680000
# i: 2685000, cost_now: 11, best_cost: 0, temp: 2.83, good_cnt: 23060/2685000
# i: 2690000, cost_now: 15, best_cost: 0, temp: 2.82, good_cnt: 23083/2690000
# i: 2695000, cost_now: 3, best_cost: 0, temp: 2.82, good_cnt: 23107/2695000
# i: 2700000, cost_now: 8, best_cost: 0, temp: 2.81, good_cnt: 23136/2700000
# i: 2705000, cost_now: 0, best_cost: 0, temp: 2.80, good_cnt: 23152/2705000
# i: 2710000, cost_now: 16, best_cost: 0, temp: 2.80, good_cnt: 23169/2710000
# i: 2715000, cost_now: 10, best_cost: 0, temp: 2.79, good_cnt: 23188/2715000
# i: 2720000, cost_now: 11, best_cost: 0, temp: 2.79, good_cnt: 23209/2720000
# i: 2725000, cost_now: 7, best_cost: 0, temp: 2.78, good_cnt: 23227/2725000
# i: 2730000, cost_now: 4, best_cost: 0, temp: 2.77, good_cnt: 23254/2730000
# i: 2735000, cost_now: 12, best_cost: 0, temp: 2.76, good_cnt: 23269/2735000
# i: 2740000, cost_now: 4, best_cost: 0, temp: 2.76, good_cnt: 23291/2740000
# i: 2745000, cost_now: 4, best_cost: 0, temp: 2.75, good_cnt: 23308/2745000
# i: 2750000, cost_now: 6, best_cost: 0, temp: 2.74, good_cnt: 23328/2750000
# i: 2755000, cost_now: 14, best_cost: 0, temp: 2.74, good_cnt: 23342/2755000
# i: 2760000, cost_now: 12, best_cost: 0, temp: 2.73, good_cnt: 23358/2760000
# i: 2765000, cost_now: 4, best_cost: 0, temp: 2.73, good_cnt: 23374/2765000
# i: 2770000, cost_now: 1, best_cost: 0, temp: 2.72, good_cnt: 23390/2770000
# i: 2775000, cost_now: 4, best_cost: 0, temp: 2.71, good_cnt: 23402/2775000
# i: 2780000, cost_now: 3, best_cost: 0, temp: 2.71, good_cnt: 23422/2780000
# i: 2785000, cost_now: 8, best_cost: 0, temp: 2.70, good_cnt: 23439/2785000
# i: 2790000, cost_now: 17, best_cost: 0, temp: 2.69, good_cnt: 23461/2790000
# i: 2795000, cost_now: 0, best_cost: 0, temp: 2.69, good_cnt: 23483/2795000
# i: 2800000, cost_now: 2, best_cost: 0, temp: 2.68, good_cnt: 23501/2800000
# i: 2805000, cost_now: 4, best_cost: 0, temp: 2.67, good_cnt: 23525/2805000
# i: 2810000, cost_now: 3, best_cost: 0, temp: 2.67, good_cnt: 23542/2810000
# i: 2815000, cost_now: 8, best_cost: 0, temp: 2.66, good_cnt: 23558/2815000
# i: 2820000, cost_now: 9, best_cost: 0, temp: 2.65, good_cnt: 23573/2820000
# i: 2825000, cost_now: 14, best_cost: 0, temp: 2.65, good_cnt: 23585/2825000
# i: 2830000, cost_now: 10, best_cost: 0, temp: 2.64, good_cnt: 23604/2830000
# i: 2835000, cost_now: 18, best_cost: 0, temp: 2.64, good_cnt: 23626/2835000
# i: 2840000, cost_now: 6, best_cost: 0, temp: 2.63, good_cnt: 23649/2840000
# i: 2845000, cost_now: 5, best_cost: 0, temp: 2.62, good_cnt: 23666/2845000
# i: 2850000, cost_now: 0, best_cost: 0, temp: 2.62, good_cnt: 23679/2850000
# i: 2855000, cost_now: 13, best_cost: 0, temp: 2.61, good_cnt: 23695/2855000
# i: 2860000, cost_now: 5, best_cost: 0, temp: 2.61, good_cnt: 23714/2860000
# i: 2865000, cost_now: 7, best_cost: 0, temp: 2.60, good_cnt: 23727/2865000
# i: 2870000, cost_now: 6, best_cost: 0, temp: 2.59, good_cnt: 23744/2870000
# i: 2875000, cost_now: 1, best_cost: 0, temp: 2.59, good_cnt: 23757/2875000
# i: 2880000, cost_now: 2, best_cost: 0, temp: 2.58, good_cnt: 23774/2880000
# i: 2885000, cost_now: 10, best_cost: 0, temp: 2.58, good_cnt: 23792/2885000
# i: 2890000, cost_now: 4, best_cost: 0, temp: 2.57, good_cnt: 23812/2890000
# i: 2895000, cost_now: 12, best_cost: 0, temp: 2.57, good_cnt: 23835/2895000
# i: 2900000, cost_now: 2, best_cost: 0, temp: 2.56, good_cnt: 23851/2900000
# i: 2905000, cost_now: 0, best_cost: 0, temp: 2.55, good_cnt: 23862/2905000
# i: 2910000, cost_now: 8, best_cost: 0, temp: 2.55, good_cnt: 23874/2910000
# i: 2915000, cost_now: 13, best_cost: 0, temp: 2.54, good_cnt: 23893/2915000
# i: 2920000, cost_now: 14, best_cost: 0, temp: 2.54, good_cnt: 23913/2920000
# i: 2925000, cost_now: 3, best_cost: 0, temp: 2.53, good_cnt: 23932/2925000
# i: 2930000, cost_now: 6, best_cost: 0, temp: 2.52, good_cnt: 23952/2930000
# i: 2935000, cost_now: 5, best_cost: 0, temp: 2.52, good_cnt: 23973/2935000
# i: 2940000, cost_now: 7, best_cost: 0, temp: 2.51, good_cnt: 23981/2940000
# i: 2945000, cost_now: 11, best_cost: 0, temp: 2.51, good_cnt: 24001/2945000
# i: 2950000, cost_now: 8, best_cost: 0, temp: 2.50, good_cnt: 24020/2950000
# i: 2955000, cost_now: 11, best_cost: 0, temp: 2.50, good_cnt: 24041/2955000
# i: 2960000, cost_now: 1, best_cost: 0, temp: 2.49, good_cnt: 24064/2960000
# i: 2965000, cost_now: 5, best_cost: 0, temp: 2.48, good_cnt: 24075/2965000
# i: 2970000, cost_now: 4, best_cost: 0, temp: 2.48, good_cnt: 24097/2970000
# i: 2975000, cost_now: 6, best_cost: 0, temp: 2.47, good_cnt: 24109/2975000
# i: 2980000, cost_now: 8, best_cost: 0, temp: 2.47, good_cnt: 24126/2980000
# i: 2985000, cost_now: 8, best_cost: 0, temp: 2.46, good_cnt: 24139/2985000
# i: 2990000, cost_now: 6, best_cost: 0, temp: 2.45, good_cnt: 24153/2990000
# i: 2995000, cost_now: 1, best_cost: 0, temp: 2.45, good_cnt: 24176/2995000
# i: 3000000, cost_now: 2, best_cost: 0, temp: 2.44, good_cnt: 24188/3000000
# i: 3005000, cost_now: 6, best_cost: 0, temp: 2.44, good_cnt: 24201/3005000
# i: 3010000, cost_now: 1, best_cost: 0, temp: 2.43, good_cnt: 24215/3010000
# i: 3015000, cost_now: 8, best_cost: 0, temp: 2.43, good_cnt: 24232/3015000
# i: 3020000, cost_now: 2, best_cost: 0, temp: 2.42, good_cnt: 24243/3020000
# i: 3025000, cost_now: 9, best_cost: 0, temp: 2.42, good_cnt: 24249/3025000
# i: 3030000, cost_now: 27, best_cost: 0, temp: 2.41, good_cnt: 24266/3030000
# i: 3035000, cost_now: 10, best_cost: 0, temp: 2.41, good_cnt: 24284/3035000
# i: 3040000, cost_now: 0, best_cost: 0, temp: 2.40, good_cnt: 24298/3040000
# i: 3045000, cost_now: 14, best_cost: 0, temp: 2.39, good_cnt: 24309/3045000
# i: 3050000, cost_now: 6, best_cost: 0, temp: 2.39, good_cnt: 24337/3050000
# i: 3055000, cost_now: 13, best_cost: 0, temp: 2.38, good_cnt: 24356/3055000
# i: 3060000, cost_now: 4, best_cost: 0, temp: 2.38, good_cnt: 24376/3060000
# i: 3065000, cost_now: 2, best_cost: 0, temp: 2.37, good_cnt: 24395/3065000
# i: 3070000, cost_now: 1, best_cost: 0, temp: 2.37, good_cnt: 24413/3070000
# i: 3075000, cost_now: 9, best_cost: 0, temp: 2.36, good_cnt: 24431/3075000
# i: 3080000, cost_now: 11, best_cost: 0, temp: 2.36, good_cnt: 24447/3080000
# i: 3085000, cost_now: 7, best_cost: 0, temp: 2.35, good_cnt: 24464/3085000
# i: 3090000, cost_now: 2, best_cost: 0, temp: 2.35, good_cnt: 24477/3090000
# i: 3095000, cost_now: 3, best_cost: 0, temp: 2.34, good_cnt: 24493/3095000
# i: 3100000, cost_now: 13, best_cost: 0, temp: 2.34, good_cnt: 24505/3100000
# i: 3105000, cost_now: 7, best_cost: 0, temp: 2.33, good_cnt: 24522/3105000
# i: 3110000, cost_now: 14, best_cost: 0, temp: 2.33, good_cnt: 24537/3110000
# i: 3115000, cost_now: 12, best_cost: 0, temp: 2.32, good_cnt: 24558/3115000
# i: 3120000, cost_now: 0, best_cost: 0, temp: 2.32, good_cnt: 24568/3120000
# i: 3125000, cost_now: 3, best_cost: 0, temp: 2.31, good_cnt: 24584/3125000
# i: 3130000, cost_now: 1, best_cost: 0, temp: 2.30, good_cnt: 24599/3130000
# i: 3135000, cost_now: 11, best_cost: 0, temp: 2.30, good_cnt: 24616/3135000
# i: 3140000, cost_now: 1, best_cost: 0, temp: 2.29, good_cnt: 24635/3140000
# i: 3145000, cost_now: 8, best_cost: 0, temp: 2.29, good_cnt: 24645/3145000
# i: 3150000, cost_now: 0, best_cost: 0, temp: 2.28, good_cnt: 24660/3150000
# i: 3155000, cost_now: 3, best_cost: 0, temp: 2.28, good_cnt: 24669/3155000
# i: 3160000, cost_now: 13, best_cost: 0, temp: 2.27, good_cnt: 24684/3160000
# i: 3165000, cost_now: 0, best_cost: 0, temp: 2.27, good_cnt: 24698/3165000
# i: 3170000, cost_now: 4, best_cost: 0, temp: 2.26, good_cnt: 24709/3170000
# i: 3175000, cost_now: 8, best_cost: 0, temp: 2.25, good_cnt: 24727/3175000
# i: 3180000, cost_now: 3, best_cost: 0, temp: 2.25, good_cnt: 24746/3180000
# i: 3185000, cost_now: 13, best_cost: 0, temp: 2.25, good_cnt: 24763/3185000
# i: 3190000, cost_now: 4, best_cost: 0, temp: 2.24, good_cnt: 24782/3190000
# i: 3195000, cost_now: 12, best_cost: 0, temp: 2.23, good_cnt: 24792/3195000
# i: 3200000, cost_now: 9, best_cost: 0, temp: 2.23, good_cnt: 24805/3200000
# ...
# i: 3860000, cost_now: 0, best_cost: 0, temp: 1.65, good_cnt: 26449/3860000
# i: 3865000, cost_now: 3, best_cost: 0, temp: 1.64, good_cnt: 26452/3865000
# i: 3870000, cost_now: 3, best_cost: 0, temp: 1.64, good_cnt: 26459/3870000
# i: 3875000, cost_now: 2, best_cost: 0, temp: 1.64, good_cnt: 26469/3875000
# i: 3880000, cost_now: 1, best_cost: 0, temp: 1.63, good_cnt: 26476/3880000
# i: 3885000, cost_now: 0, best_cost: 0, temp: 1.63, good_cnt: 26485/3885000
# i: 3890000, cost_now: 0, best_cost: 0, temp: 1.63, good_cnt: 26496/3890000
# i: 3895000, cost_now: 5, best_cost: 0, temp: 1.62, good_cnt: 26505/3895000
# i: 3900000, cost_now: 0, best_cost: 0, temp: 1.62, good_cnt: 26517/3900000
# i: 3905000, cost_now: 5, best_cost: 0, temp: 1.61, good_cnt: 26523/3905000
# i: 3910000, cost_now: 7, best_cost: 0, temp: 1.61, good_cnt: 26536/3910000
# i: 3915000, cost_now: 5, best_cost: 0, temp: 1.61, good_cnt: 26547/3915000
# i: 3920000, cost_now: 1, best_cost: 0, temp: 1.60, good_cnt: 26558/3920000
# i: 3925000, cost_now: 7, best_cost: 0, temp: 1.60, good_cnt: 26572/3925000
# i: 3930000, cost_now: 0, best_cost: 0, temp: 1.59, good_cnt: 26584/3930000
# i: 3935000, cost_now: 3, best_cost: 0, temp: 1.59, good_cnt: 26592/3935000
# i: 3940000, cost_now: 2, best_cost: 0, temp: 1.59, good_cnt: 26599/3940000
# i: 3945000, cost_now: 0, best_cost: 0, temp: 1.58, good_cnt: 26605/3945000
# i: 3950000, cost_now: 5, best_cost: 0, temp: 1.58, good_cnt: 26611/3950000
# i: 3955000, cost_now: 2, best_cost: 0, temp: 1.58, good_cnt: 26625/3955000
# i: 3960000, cost_now: 9, best_cost: 0, temp: 1.57, good_cnt: 26630/3960000
# i: 3965000, cost_now: 0, best_cost: 0, temp: 1.57, good_cnt: 26639/3965000
# i: 3970000, cost_now: 3, best_cost: 0, temp: 1.57, good_cnt: 26647/3970000
# i: 3975000, cost_now: 4, best_cost: 0, temp: 1.56, good_cnt: 26658/3975000
# i: 3980000, cost_now: 0, best_cost: 0, temp: 1.56, good_cnt: 26666/3980000
# i: 3985000, cost_now: 0, best_cost: 0, temp: 1.55, good_cnt: 26677/3985000
# i: 3990000, cost_now: 5, best_cost: 0, temp: 1.55, good_cnt: 26687/3990000
# i: 3995000, cost_now: 3, best_cost: 0, temp: 1.55, good_cnt: 26703/3995000
# i: 4000000, cost_now: 6, best_cost: 0, temp: 1.54, good_cnt: 26714/4000000
# i: 4005000, cost_now: 2, best_cost: 0, temp: 1.54, good_cnt: 26725/4005000
# i: 4010000, cost_now: 1, best_cost: 0, temp: 1.54, good_cnt: 26730/4010000
# i: 4015000, cost_now: 0, best_cost: 0, temp: 1.53, good_cnt: 26740/4015000
# i: 4020000, cost_now: 0, best_cost: 0, temp: 1.53, good_cnt: 26747/4020000
# i: 4025000, cost_now: 3, best_cost: 0, temp: 1.52, good_cnt: 26751/4025000
# i: 4030000, cost_now: 1, best_cost: 0, temp: 1.52, good_cnt: 26768/4030000
# i: 4035000, cost_now: 1, best_cost: 0, temp: 1.52, good_cnt: 26773/4035000
# i: 4040000, cost_now: 7, best_cost: 0, temp: 1.51, good_cnt: 26785/4040000
# i: 4045000, cost_now: 1, best_cost: 0, temp: 1.51, good_cnt: 26794/4045000
# i: 4050000, cost_now: 3, best_cost: 0, temp: 1.50, good_cnt: 26805/4050000
# i: 4055000, cost_now: 3, best_cost: 0, temp: 1.50, good_cnt: 26812/4055000
# i: 4060000, cost_now: 4, best_cost: 0, temp: 1.50, good_cnt: 26817/4060000
# i: 4065000, cost_now: 2, best_cost: 0, temp: 1.49, good_cnt: 26826/4065000
# i: 4070000, cost_now: 0, best_cost: 0, temp: 1.49, good_cnt: 26828/4070000
# i: 4075000, cost_now: 5, best_cost: 0, temp: 1.49, good_cnt: 26835/4075000
# i: 4080000, cost_now: 4, best_cost: 0, temp: 1.48, good_cnt: 26842/4080000
# i: 4085000, cost_now: 0, best_cost: 0, temp: 1.48, good_cnt: 26853/4085000
# i: 4090000, cost_now: 0, best_cost: 0, temp: 1.48, good_cnt: 26860/4090000
# i: 4095000, cost_now: 0, best_cost: 0, temp: 1.47, good_cnt: 26866/4095000
# i: 4100000, cost_now: 2, best_cost: 0, temp: 1.47, good_cnt: 26874/4100000
# i: 4105000, cost_now: 2, best_cost: 0, temp: 1.47, good_cnt: 26883/4105000
# i: 4110000, cost_now: 1, best_cost: 0, temp: 1.46, good_cnt: 26889/4110000
# i: 4115000, cost_now: 0, best_cost: 0, temp: 1.46, good_cnt: 26896/4115000
# i: 4120000, cost_now: 0, best_cost: 0, temp: 1.46, good_cnt: 26899/4120000
# i: 4125000, cost_now: 3, best_cost: 0, temp: 1.45, good_cnt: 26910/4125000
# i: 4130000, cost_now: 10, best_cost: 0, temp: 1.45, good_cnt: 26921/4130000
# i: 4135000, cost_now: 0, best_cost: 0, temp: 1.45, good_cnt: 26931/4135000
# i: 4140000, cost_now: 1, best_cost: 0, temp: 1.44, good_cnt: 26937/4140000
# i: 4145000, cost_now: 1, best_cost: 0, temp: 1.44, good_cnt: 26948/4145000
# i: 4150000, cost_now: 1, best_cost: 0, temp: 1.44, good_cnt: 26956/4150000
# i: 4155000, cost_now: 2, best_cost: 0, temp: 1.43, good_cnt: 26960/4155000
# i: 4160000, cost_now: 0, best_cost: 0, temp: 1.43, good_cnt: 26969/4160000
# i: 4165000, cost_now: 2, best_cost: 0, temp: 1.43, good_cnt: 26983/4165000
# i: 4170000, cost_now: 2, best_cost: 0, temp: 1.42, good_cnt: 26988/4170000
# i: 4175000, cost_now: 0, best_cost: 0, temp: 1.42, good_cnt: 27001/4175000
# i: 4180000, cost_now: 3, best_cost: 0, temp: 1.42, good_cnt: 27015/4180000
# i: 4185000, cost_now: 7, best_cost: 0, temp: 1.41, good_cnt: 27019/4185000
# i: 4190000, cost_now: 2, best_cost: 0, temp: 1.41, good_cnt: 27025/4190000
# i: 4195000, cost_now: 0, best_cost: 0, temp: 1.41, good_cnt: 27036/4195000
# i: 4200000, cost_now: 4, best_cost: 0, temp: 1.40, good_cnt: 27044/4200000
# i: 4205000, cost_now: 2, best_cost: 0, temp: 1.40, good_cnt: 27050/4205000
# i: 4210000, cost_now: 0, best_cost: 0, temp: 1.40, good_cnt: 27056/4210000
# i: 4215000, cost_now: 2, best_cost: 0, temp: 1.39, good_cnt: 27064/4215000
# i: 4220000, cost_now: 0, best_cost: 0, temp: 1.39, good_cnt: 27069/4220000
# i: 4225000, cost_now: 0, best_cost: 0, temp: 1.39, good_cnt: 27078/4225000
# i: 4230000, cost_now: 0, best_cost: 0, temp: 1.38, good_cnt: 27083/4230000
# i: 4235000, cost_now: 2, best_cost: 0, temp: 1.38, good_cnt: 27087/4235000
# i: 4240000, cost_now: 3, best_cost: 0, temp: 1.38, good_cnt: 27095/4240000
# i: 4245000, cost_now: 1, best_cost: 0, temp: 1.37, good_cnt: 27108/4245000
# i: 4250000, cost_now: 1, best_cost: 0, temp: 1.37, good_cnt: 27117/4250000
# i: 4255000, cost_now: 1, best_cost: 0, temp: 1.37, good_cnt: 27120/4255000
# i: 4260000, cost_now: 2, best_cost: 0, temp: 1.36, good_cnt: 27130/4260000
# i: 4265000, cost_now: 0, best_cost: 0, temp: 1.36, good_cnt: 27138/4265000
# i: 4270000, cost_now: 4, best_cost: 0, temp: 1.36, good_cnt: 27147/4270000
# i: 4275000, cost_now: 4, best_cost: 0, temp: 1.35, good_cnt: 27159/4275000
# i: 4280000, cost_now: 3, best_cost: 0, temp: 1.35, good_cnt: 27171/4280000
# i: 4285000, cost_now: 3, best_cost: 0, temp: 1.35, good_cnt: 27181/4285000
# i: 4290000, cost_now: 7, best_cost: 0, temp: 1.34, good_cnt: 27188/4290000
# i: 4295000, cost_now: 0, best_cost: 0, temp: 1.34, good_cnt: 27195/4295000
# i: 4300000, cost_now: 2, best_cost: 0, temp: 1.34, good_cnt: 27198/4300000
# i: 4305000, cost_now: 6, best_cost: 0, temp: 1.34, good_cnt: 27207/4305000
# i: 4310000, cost_now: 0, best_cost: 0, temp: 1.33, good_cnt: 27213/4310000
# i: 4315000, cost_now: 2, best_cost: 0, temp: 1.33, good_cnt: 27222/4315000
# i: 4320000, cost_now: 5, best_cost: 0, temp: 1.33, good_cnt: 27230/4320000
# i: 4325000, cost_now: 17, best_cost: 0, temp: 1.32, good_cnt: 27239/4325000
# i: 4330000, cost_now: 4, best_cost: 0, temp: 1.32, good_cnt: 27254/4330000
# i: 4335000, cost_now: 1, best_cost: 0, temp: 1.32, good_cnt: 27262/4335000
# i: 4340000, cost_now: 2, best_cost: 0, temp: 1.31, good_cnt: 27267/4340000
# i: 4345000, cost_now: 0, best_cost: 0, temp: 1.31, good_cnt: 27274/4345000
# i: 4350000, cost_now: 1, best_cost: 0, temp: 1.31, good_cnt: 27277/4350000
# i: 4355000, cost_now: 0, best_cost: 0, temp: 1.30, good_cnt: 27286/4355000
# i: 4360000, cost_now: 0, best_cost: 0, temp: 1.30, good_cnt: 27293/4360000
# i: 4365000, cost_now: 2, best_cost: 0, temp: 1.30, good_cnt: 27298/4365000
# i: 4370000, cost_now: 5, best_cost: 0, temp: 1.30, good_cnt: 27304/4370000
# i: 4375000, cost_now: 0, best_cost: 0, temp: 1.29, good_cnt: 27310/4375000
# i: 4380000, cost_now: 0, best_cost: 0, temp: 1.29, good_cnt: 27313/4380000
# i: 4385000, cost_now: 0, best_cost: 0, temp: 1.29, good_cnt: 27315/4385000
# i: 4390000, cost_now: 0, best_cost: 0, temp: 1.28, good_cnt: 27321/4390000
# i: 4395000, cost_now: 0, best_cost: 0, temp: 1.28, good_cnt: 27326/4395000
# i: 4400000, cost_now: 0, best_cost: 0, temp: 1.28, good_cnt: 27331/4400000
# i: 4405000, cost_now: 2, best_cost: 0, temp: 1.27, good_cnt: 27337/4405000
# i: 4410000, cost_now: 5, best_cost: 0, temp: 1.27, good_cnt: 27344/4410000
# i: 4415000, cost_now: 0, best_cost: 0, temp: 1.27, good_cnt: 27359/4415000
# i: 4420000, cost_now: 2, best_cost: 0, temp: 1.26, good_cnt: 27365/4420000
# i: 4425000, cost_now: 3, best_cost: 0, temp: 1.26, good_cnt: 27372/4425000
# i: 4430000, cost_now: 0, best_cost: 0, temp: 1.26, good_cnt: 27380/4430000
# i: 4435000, cost_now: 2, best_cost: 0, temp: 1.25, good_cnt: 27384/4435000
# i: 4440000, cost_now: 3, best_cost: 0, temp: 1.25, good_cnt: 27390/4440000
# i: 4445000, cost_now: 2, best_cost: 0, temp: 1.25, good_cnt: 27397/4445000
# i: 4450000, cost_now: 1, best_cost: 0, temp: 1.25, good_cnt: 27402/4450000
# i: 4455000, cost_now: 0, best_cost: 0, temp: 1.24, good_cnt: 27407/4455000
# i: 4460000, cost_now: 0, best_cost: 0, temp: 1.24, good_cnt: 27411/4460000
# i: 4465000, cost_now: 0, best_cost: 0, temp: 1.24, good_cnt: 27413/4465000
# i: 4470000, cost_now: 1, best_cost: 0, temp: 1.23, good_cnt: 27420/4470000
# i: 4475000, cost_now: 3, best_cost: 0, temp: 1.23, good_cnt: 27430/4475000
# i: 4480000, cost_now: 0, best_cost: 0, temp: 1.23, good_cnt: 27436/4480000
# i: 4485000, cost_now: 2, best_cost: 0, temp: 1.23, good_cnt: 27442/4485000
# i: 4490000, cost_now: 0, best_cost: 0, temp: 1.22, good_cnt: 27448/4490000
# i: 4495000, cost_now: 2, best_cost: 0, temp: 1.22, good_cnt: 27454/4495000
# i: 4500000, cost_now: 0, best_cost: 0, temp: 1.22, good_cnt: 27459/4500000
# i: 4505000, cost_now: 5, best_cost: 0, temp: 1.21, good_cnt: 27466/4505000
# i: 4510000, cost_now: 1, best_cost: 0, temp: 1.21, good_cnt: 27474/4510000
# i: 4515000, cost_now: 0, best_cost: 0, temp: 1.21, good_cnt: 27477/4515000
# i: 4520000, cost_now: 3, best_cost: 0, temp: 1.21, good_cnt: 27484/4520000
# i: 4525000, cost_now: 0, best_cost: 0, temp: 1.20, good_cnt: 27489/4525000
# i: 4530000, cost_now: 0, best_cost: 0, temp: 1.20, good_cnt: 27493/4530000
# i: 4535000, cost_now: 0, best_cost: 0, temp: 1.20, good_cnt: 27499/4535000
# i: 4540000, cost_now: 2, best_cost: 0, temp: 1.20, good_cnt: 27502/4540000
# i: 4545000, cost_now: 2, best_cost: 0, temp: 1.19, good_cnt: 27507/4545000
# i: 4550000, cost_now: 0, best_cost: 0, temp: 1.19, good_cnt: 27512/4550000
# i: 4555000, cost_now: 0, best_cost: 0, temp: 1.19, good_cnt: 27517/4555000
# i: 4560000, cost_now: 0, best_cost: 0, temp: 1.18, good_cnt: 27519/4560000
# i: 4565000, cost_now: 0, best_cost: 0, temp: 1.18, good_cnt: 27526/4565000
# i: 4570000, cost_now: 3, best_cost: 0, temp: 1.18, good_cnt: 27532/4570000
# i: 4575000, cost_now: 4, best_cost: 0, temp: 1.18, good_cnt: 27537/4575000
# i: 4580000, cost_now: 2, best_cost: 0, temp: 1.17, good_cnt: 27544/4580000
# i: 4585000, cost_now: 0, best_cost: 0, temp: 1.17, good_cnt: 27547/4585000
# i: 4590000, cost_now: 0, best_cost: 0, temp: 1.17, good_cnt: 27551/4590000
# i: 4595000, cost_now: 0, best_cost: 0, temp: 1.17, good_cnt: 27554/4595000
# i: 4600000, cost_now: 1, best_cost: 0, temp: 1.16, good_cnt: 27558/4600000
# i: 4605000, cost_now: 2, best_cost: 0, temp: 1.16, good_cnt: 27566/4605000
# i: 4610000, cost_now: 0, best_cost: 0, temp: 1.16, good_cnt: 27569/4610000
# i: 4615000, cost_now: 0, best_cost: 0, temp: 1.15, good_cnt: 27574/4615000
# i: 4620000, cost_now: 9, best_cost: 0, temp: 1.15, good_cnt: 27581/4620000
# i: 4625000, cost_now: 0, best_cost: 0, temp: 1.15, good_cnt: 27589/4625000
# i: 4630000, cost_now: 0, best_cost: 0, temp: 1.15, good_cnt: 27596/4630000
# i: 4635000, cost_now: 0, best_cost: 0, temp: 1.14, good_cnt: 27600/4635000
# i: 4640000, cost_now: 2, best_cost: 0, temp: 1.14, good_cnt: 27604/4640000
# i: 4645000, cost_now: 2, best_cost: 0, temp: 1.14, good_cnt: 27609/4645000
# i: 4650000, cost_now: 3, best_cost: 0, temp: 1.14, good_cnt: 27613/4650000
# i: 4655000, cost_now: 0, best_cost: 0, temp: 1.13, good_cnt: 27616/4655000
# i: 4660000, cost_now: 1, best_cost: 0, temp: 1.13, good_cnt: 27622/4660000
# i: 4665000, cost_now: 2, best_cost: 0, temp: 1.13, good_cnt: 27626/4665000
# i: 4670000, cost_now: 0, best_cost: 0, temp: 1.12, good_cnt: 27633/4670000
# i: 4675000, cost_now: 0, best_cost: 0, temp: 1.12, good_cnt: 27641/4675000
# i: 4680000, cost_now: 0, best_cost: 0, temp: 1.12, good_cnt: 27643/4680000
# i: 4685000, cost_now: 2, best_cost: 0, temp: 1.12, good_cnt: 27645/4685000
# i: 4690000, cost_now: 2, best_cost: 0, temp: 1.11, good_cnt: 27647/4690000
# i: 4695000, cost_now: 0, best_cost: 0, temp: 1.11, good_cnt: 27654/4695000
# i: 4700000, cost_now: 2, best_cost: 0, temp: 1.11, good_cnt: 27655/4700000
# i: 4705000, cost_now: 0, best_cost: 0, temp: 1.11, good_cnt: 27658/4705000
# i: 4710000, cost_now: 6, best_cost: 0, temp: 1.10, good_cnt: 27661/4710000
# i: 4715000, cost_now: 5, best_cost: 0, temp: 1.10, good_cnt: 27669/4715000
# i: 4720000, cost_now: 6, best_cost: 0, temp: 1.10, good_cnt: 27679/4720000
# i: 4725000, cost_now: 1, best_cost: 0, temp: 1.10, good_cnt: 27687/4725000
# i: 4730000, cost_now: 0, best_cost: 0, temp: 1.09, good_cnt: 27692/4730000
# i: 4735000, cost_now: 0, best_cost: 0, temp: 1.09, good_cnt: 27697/4735000
# i: 4740000, cost_now: 0, best_cost: 0, temp: 1.09, good_cnt: 27703/4740000
# i: 4745000, cost_now: 2, best_cost: 0, temp: 1.09, good_cnt: 27707/4745000
# i: 4750000, cost_now: 4, best_cost: 0, temp: 1.08, good_cnt: 27710/4750000
# i: 4755000, cost_now: 3, best_cost: 0, temp: 1.08, good_cnt: 27716/4755000
# i: 4760000, cost_now: 3, best_cost: 0, temp: 1.08, good_cnt: 27721/4760000
# i: 4765000, cost_now: 4, best_cost: 0, temp: 1.08, good_cnt: 27728/4765000
# i: 4770000, cost_now: 0, best_cost: 0, temp: 1.07, good_cnt: 27739/4770000
# i: 4775000, cost_now: 1, best_cost: 0, temp: 1.07, good_cnt: 27745/4775000
# i: 4780000, cost_now: 0, best_cost: 0, temp: 1.07, good_cnt: 27751/4780000
# i: 4785000, cost_now: 6, best_cost: 0, temp: 1.07, good_cnt: 27763/4785000
# i: 4790000, cost_now: 5, best_cost: 0, temp: 1.06, good_cnt: 27773/4790000
# i: 4795000, cost_now: 0, best_cost: 0, temp: 1.06, good_cnt: 27783/4795000
# i: 4800000, cost_now: 0, best_cost: 0, temp: 1.06, good_cnt: 27789/4800000
# i: 4805000, cost_now: 0, best_cost: 0, temp: 1.06, good_cnt: 27791/4805000
# i: 4810000, cost_now: 2, best_cost: 0, temp: 1.05, good_cnt: 27798/4810000
# i: 4815000, cost_now: 2, best_cost: 0, temp: 1.05, good_cnt: 27807/4815000
# i: 4820000, cost_now: 4, best_cost: 0, temp: 1.05, good_cnt: 27813/4820000
# i: 4825000, cost_now: 0, best_cost: 0, temp: 1.05, good_cnt: 27822/4825000
# i: 4830000, cost_now: 0, best_cost: 0, temp: 1.04, good_cnt: 27826/4830000
# i: 4835000, cost_now: 1, best_cost: 0, temp: 1.04, good_cnt: 27830/4835000
# i: 4840000, cost_now: 0, best_cost: 0, temp: 1.04, good_cnt: 27834/4840000
# i: 4845000, cost_now: 3, best_cost: 0, temp: 1.04, good_cnt: 27839/4845000
# i: 4850000, cost_now: 2, best_cost: 0, temp: 1.03, good_cnt: 27846/4850000
# i: 4855000, cost_now: 1, best_cost: 0, temp: 1.03, good_cnt: 27849/4855000
# i: 4860000, cost_now: 0, best_cost: 0, temp: 1.03, good_cnt: 27855/4860000
# i: 4865000, cost_now: 1, best_cost: 0, temp: 1.03, good_cnt: 27860/4865000
# i: 4870000, cost_now: 2, best_cost: 0, temp: 1.03, good_cnt: 27861/4870000
# i: 4875000, cost_now: 7, best_cost: 0, temp: 1.02, good_cnt: 27872/4875000
# i: 4880000, cost_now: 3, best_cost: 0, temp: 1.02, good_cnt: 27875/4880000
# i: 4885000, cost_now: 2, best_cost: 0, temp: 1.02, good_cnt: 27883/4885000
# i: 4890000, cost_now: 1, best_cost: 0, temp: 1.02, good_cnt: 27884/4890000
# i: 4895000, cost_now: 0, best_cost: 0, temp: 1.01, good_cnt: 27893/4895000
# i: 4900000, cost_now: 0, best_cost: 0, temp: 1.01, good_cnt: 27899/4900000
# i: 4905000, cost_now: 0, best_cost: 0, temp: 1.01, good_cnt: 27902/4905000
# i: 4910000, cost_now: 4, best_cost: 0, temp: 1.01, good_cnt: 27906/4910000
# i: 4915000, cost_now: 5, best_cost: 0, temp: 1.00, good_cnt: 27908/4915000
# i: 4920000, cost_now: 0, best_cost: 0, temp: 1.00, good_cnt: 27916/4920000

# %%
x_best_mean = [tuple() for _ in range(env.N)]
for i in range(env.N):
    total_x = 0
    total_y = 0
    for j in range(len(x_bests)):
        total_x += x_bests[j][i][0]
        total_y += x_bests[j][i][1]
    total_x //= len(x_bests)
    total_y //= len(x_bests)
    x_best_mean[i] = (total_x, total_y)

# %%
def calc_greedy_answer(
    env: Env,
    target_points: list[tuple[int, int]],
):
    graph = construct_dist_matrix(target_points)

    groups = [(i, g) for i, g in enumerate(env.G)]
    groups = sorted(groups, key=lambda x: x[1], reverse=True)

    ans_edges = [None for _ in range(len(groups))]
    ans_v = [None for _ in range(len(groups))]
    ans_costs = [None for _ in range(len(groups))]

    now_used: set = set()
    not_used: set = set(range(env.N))
    for group_n, group_size in groups:
        v = not_used.pop()
        prim_edges, prim_v, prim_cost = prim_k(graph, v, group_size, now_used, env.N)
        ans_edges[group_n] = prim_edges
        ans_v[group_n] = prim_v
        ans_costs[group_n] = prim_cost
        now_used.update(prim_v)
        not_used.difference_update(prim_v)

    return ans_v, ans_edges, ans_costs

# %%
ans_v, ans_edges, _ = calc_greedy_answer(env, x_best_mean)
env.answer(ans_v, ans_edges)
# Out:
# query: 398
# 597738.0

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


def get_color(i):
    # colors = list(matplotlib.colors.CSS4_COLORS.values())
    colors = matplotlib.cm.tab20.colors
    return colors[i % len(colors)]


point_inds = list(range(env.N))  # longs_points[:]
corrects_np = np.array(env.coordinates)[point_inds]
estimates_np = np.array(x_best)[point_inds]
rectangles = np.array([env.rectangles[i] for i in range(env.N)])[point_inds]

# 四角形と、四角形内の正解点と予測点を描画
plt.figure(figsize=(10, 10))
ax = plt.gca()
# for i, rect in enumerate(rectangles):
#     l, r, t, b = rect
#     ax.add_patch(matplotlib.patches.Rectangle((l, t), r - l, b - t, alpha=0.1))
ax.scatter(corrects_np[:, 0], corrects_np[:, 1], color="green", label="correct", s=20, marker="*")
ax.scatter(estimates_np[:, 0], estimates_np[:, 1], color="red", label="estimate", s=5, marker="o")
for point_ind in range(len(corrects_np)):
    ax.plot(
        (corrects_np[point_ind, 0], estimates_np[point_ind, 0]),
        (corrects_np[point_ind, 1], estimates_np[point_ind, 1]),
        color="gray",
        label="correct path",
    )
plt.show()
